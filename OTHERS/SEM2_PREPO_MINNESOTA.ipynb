# %% [markdown]
# import pandas as pd

# %%
review_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/MinnesotaReview/review-Minnesota.json"
review_df = pd.read_json(review_path, lines = True)
review_df
# Out:
#               user_id                    name           time  rating  \
# 0        1.163883e+20               T Freeman  1593495298731     5.0
# 1        1.089889e+20          Sarah Westfall  1520893715113     5.0
# 2        1.117122e+20  Wayne Anthony Cullinan  1504541471455     5.0
# 3        1.024779e+20                  Judy E  1437677732701     4.0
# 4        1.175789e+20            Kelly Murphy  1521731566365     5.0
# ...               ...                     ...            ...     ...
# 9520253  1.002569e+20             Jessica Lee  1518600909205     2.0
# 9520254  1.019770e+20           Drew Landaeta  1504919358911     3.0
# 9520255  1.065794e+20                   Annie  1539711044354     5.0
# 9520256  1.043962e+20                      김집  1562226423561     3.0
# 9520257  1.177670e+20         Darlene Jenison  1497629144080     5.0
#
#                                                       text  pics  resp  \
# 0        Dr king saved me from suggested back surgery. ...  None  None
# 1        I have been going to see DR.King for years wou...  None  None
# 2        I have seen Dr. Warren King for over 30 years ...  None  None
# 3        I have been seeing Dr King as my body needs wo...  None  None
# 4        Absolutely amazing results! No more Cortisone ...  None  None
# ...                                                    ...   ...   ...
# 9520253                                               None  None  None
# 9520254                                               None  None  None
# 9520255                                               None  None  None
# 9520256                                               None  None  None
# 9520257                                               None  None  None
#
#                                        gmap_id
# 0        0x52b3311bcc443159:0xa157dd0155d0d910
# 1        0x52b3311bcc443159:0xa157dd0155d0d910
# 2        0x52b3311bcc443159:0xa157dd0155d0d910
# 3        0x52b3311bcc443159:0xa157dd0155d0d910
# 4        0x52b3311bcc443159:0xa157dd0155d0d910
# ...                                        ...
# 9520253  0x87f61945862e55c3:0x407cf06a98ff5e7c
# 9520254  0x87f61945862e55c3:0x407cf06a98ff5e7c
# 9520255  0x87f61945862e55c3:0x407cf06a98ff5e7c
# 9520256  0x87f61945862e55c3:0x407cf06a98ff5e7c
# 9520257  0x87f61945862e55c3:0x407cf06a98ff5e7c
#
# [9520258 rows x 8 columns]

# %%
business_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/MinnesotaMeta/meta-Minnesota.json"
business_df = pd.read_json(business_path, lines = True)
business_df
# Out:
#                                name  \
# 0         Quantum Chiropractic Arts
# 1                 Superlock Storage
# 2      MDR Design-Build-Remodel LLC
# 3            River Grove Harbor Inc
# 4                    Public Storage
# ...                             ...
# 80959               Just Rite Foods
# 80960                  First Avenue
# 80961           Eden Prairie Liquor
# 80962                  Chino Latino
# 80963          Prairie Village Mall
#
#                                                  address  \
# 0      Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...
# 1      Superlock Storage, 14541 Glenda Dr, Apple Vall...
# 2                                                   None
# 3      River Grove Harbor Inc, 3985 102nd St E, Inver...
# 4      Public Storage, 5900 148th St W, Apple Valley,...
# ...                                                  ...
# 80959  Just Rite Foods, 211 6th Ave SW, Rochester, MN...
# 80960  First Avenue, 701 N 1st Ave, Minneapolis, MN 5...
# 80961  Eden Prairie Liquor, 8018 Den Rd, Eden Prairie...
# 80962  Chino Latino, 2916 Hennepin Ave S, Minneapolis...
# 80963  Prairie Village Mall, 16500 W 78th St, Eden Pr...
#
#                                      gmap_id  \
# 0      0x52b3311bcc443159:0xa157dd0155d0d910
# 1      0x87f630d649635d65:0x57b17f6d51a91c8b
# 2      0x87f63603d615bf3d:0x5607969c2ca6dfe6
# 3      0x87f7cdfad98478cf:0xe3d7b93175d0115c
# 4      0x87f63153b086f7cd:0xaae8b76b32c38948
# ...                                      ...
# 80959  0x87f75f6fc3034f7b:0xb6eb13c0d6d907b7
# 80960  0x52b332917cb8a83f:0xadb920377f253346
# 80961  0x87f618a171ec3e5d:0x1e7534fac52a4211
# 80962  0x87f6277f588deb7d:0x91d1e8613c1a4d35
# 80963  0x87f61945862e55c3:0x407cf06a98ff5e7c
#
#                                              description   latitude  \
# 0                                                   None  45.056980
# 1                                                   None  44.737101
# 2                                                   None  44.745911
# 3                                                   None  44.802032
# 4                                                   None  44.734450
# ...                                                  ...        ...
# 80959                                               None  44.021164
# 80960  Since 1970, this rock venue & tiny side bar in...  44.978531
# 80961                                               None  44.858504
# 80962  Sleek space with a global menu highlighting sp...  44.948699
# 80963                                               None  44.863592
#
#        longitude                                           category  \
# 0     -93.324951                                     [Chiropractor]
# 1     -93.219598                            [Self-storage facility]
# 2     -93.080026  [General contractor, Bathroom remodeler, Cabin...
# 3     -93.025398                                           [Marina]
# 4     -93.184399  [Self-storage facility, Automobile storage fac...
# ...          ...                                                ...
# 80959 -92.471722                                    [Grocery store]
# 80960 -93.275998  [Live music venue, Bar, Concert hall, Event ve...
# 80961 -93.423692                                     [Liquor store]
# 80962 -93.298552  [Asian fusion restaurant, Bar, Fusion restaura...
# 80963 -93.487325                                    [Shopping mall]
#
#        avg_rating  num_of_reviews price  \
# 0             4.7               7  None
# 1             4.8              18  None
# 2             5.0              18  None
# 3             4.6              18  None
# 4             4.9             257  None
# ...           ...             ...   ...
# 80959         5.0               6  None
# 80960         4.7            3555    $$
# 80961         4.3             435  None
# 80962         4.3            1804    $$
# 80963         4.3             327  None
#
#                                                    hours  \
# 0                                                   None
# 1      [[Thursday, 8:30AM–5:30PM], [Friday, 8:30AM–5:...
# 2      [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 3                                                   None
# 4      [[Thursday, 9:30AM–6PM], [Friday, 9:30AM–6PM],...
# ...                                                  ...
# 80959  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 80960  [[Thursday, 10AM–6:30PM], [Friday, 10AM–6:30PM...
# 80961  [[Wednesday, 9AM–10PM], [Thursday, 9AM–10PM], ...
# 80962  [[Wednesday, 4:30–10PM], [Thursday, 4:30–10PM]...
# 80963  [[Wednesday, Closed], [Thursday, Closed], [Fri...
#
#                                                     MISC  \
# 0      {'Accessibility': ['Wheelchair accessible entr...
# 1      {'From the business': ['Identifies as veteran-...
# 2                                                   None
# 3      {'Accessibility': ['Wheelchair accessible entr...
# 4      {'Accessibility': ['Wheelchair accessible entr...
# ...                                                  ...
# 80959                                               None
# 80960  {'Highlights': ['Live performances'], 'Accessi...
# 80961  {'Service options': ['In-store shopping', 'Del...
# 80962  {'Service options': ['Curbside pickup', 'Deliv...
# 80963  {'Service options': ['In-store shopping'], 'Ac...
#
#                        state  \
# 0                       None
# 1      Closed ⋅ Opens 8:30AM
# 2           Opens soon ⋅ 8AM
# 3                       None
# 4      Closed ⋅ Opens 9:30AM
# ...                      ...
# 80959                    NaN
# 80960                    NaN
# 80961                    NaN
# 80962                    NaN
# 80963                    NaN
#
#                                         relative_results  \
# 0      [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 1      [0x87f6313351b6e907:0xedc1c3862a0a8270, 0x87f6...
# 2      [0x87f63152479d1e8d:0x5e89ad54db734241, 0x87f6...
# 3      [0x87f7d17cc22fd59f:0xff8bab9e15ce2eaa, 0x87f7...
# 4      [0x87f630d649635d65:0x57b17f6d51a91c8b, 0x87f6...
# ...                                                  ...
# 80959  [0x87f75f871a56a6bb:0x2eb93522e1c95bbf, 0x87f7...
# 80960  [0x52b3328ffbc640dd:0x988a0fc3fd8b94e1, 0x52b3...
# 80961  [0x87f622f43ef0873f:0xd1b435162b8e76ce, 0x87f6...
# 80962  [0x87f6278004171969:0x6070b301597a2fd9, 0x87f6...
# 80963  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 80959  https://www.google.com/maps/place//data=!4m2!3...
# 80960  https://www.google.com/maps/place//data=!4m2!3...
# 80961  https://www.google.com/maps/place//data=!4m2!3...
# 80962  https://www.google.com/maps/place//data=!4m2!3...
# 80963  https://www.google.com/maps/place//data=!4m2!3...
#
# [80964 rows x 15 columns]

# %%
# Aggregate business metadata by gmap_id before merging
business_agg = business_df.groupby("gmap_id", as_index=False).agg({
    "name": "first",  # Keep first occurrence (assumes same name per gmap_id)
    "address": "first",
    "description": "first",
    "latitude": "first",
    "longitude": "first",
    "category": lambda x: list(set(x.sum())) if x.apply(lambda v: isinstance(v, list)).any() else list(set(x)),
    "avg_rating": "mean",  # Use mean rating if multiple exist
    "num_of_reviews": "sum",
    "price": "first",
    "hours": "first",
    "MISC": "first",
    "state": "first",
    "relative_results": "first",
    "url": "first"
})

# Check if aggregation worked
print(business_agg.head())
# Out:
#                                  gmap_id  \
# 0                 0x0:0x39c22a81eac08b18
# 1                 0x0:0xfe45df54958d4bbc
# 2   0x405420ab282b2e7d:0xc211d43a1946e5a
# 3  0x4054272f645ba2b3:0xa92d280d661a14b2
# 4  0x40542730543c4daf:0x5d985d6213611784
#
#                                                 name  \
# 0  National Insurance Brokers: Greg Young Insuran...
# 1                                  Mora Auto Service
# 2                     Winthrop City Hall and Library
# 3                                       Indigo Salon
# 4                                Red Wing Food Shelf
#
#                                              address description   latitude  \
# 0  National Insurance Brokers: Greg Young Insuran...        None  45.147174
# 1  Mora Auto Service, 824 S Union St, Mora, MN 55051        None  45.866899
# 2  Winthrop City Hall and Library, 305 Main St N,...        None  44.542307
# 3     Indigo Salon, 425 W 3rd St, Red Wing, MN 55066        None  44.564507
# 4  Red Wing Food Shelf, 1755 Old W Main St, Red W...        None  44.563036
#
#    longitude                                           category  avg_rating  \
# 0 -92.999236                                 [Insurance agency]         5.0
# 1 -93.296550                                             [None]         4.4
# 2 -94.363923                                        [City Hall]         4.0
# 3 -92.534614  [Hair salon, Facial spa, Day spa, Hairdresser,...         4.9
# 4 -92.553141               [Non-profit organization, Food bank]         4.4
#
#    num_of_reviews price                                              hours  \
# 0               4  None  [[Thursday, 8:30AM–5PM], [Friday, 8:30AM–4:30P...
# 1               8  None  [[Tuesday, 8AM–5PM], [Wednesday, 8AM–5PM], [Th...
# 2               1  None                                               None
# 3              64  None  [[Saturday, 8AM–3PM], [Sunday, Closed], [Monda...
# 4              26  None  [[Saturday, Closed], [Sunday, Closed], [Monday...
#
#                                                 MISC  \
# 0                                               None
# 1                                               None
# 2  {'Accessibility': ['Wheelchair accessible entr...
# 3  {'Accessibility': ['Wheelchair accessible entr...
# 4  {'Service options': ['Delivery'], 'Accessibili...
#
#                        state  \
# 0  Closed ⋅ Opens 8:30AM Fri
# 1         Permanently closed
# 2                       None
# 3     Closed ⋅ Opens 8AM Tue
# 4     Closed ⋅ Opens 4PM Tue
#
#                                     relative_results  \
# 0  [0x52b2e7a6ddd1046f:0xdc076e3a13d43861, 0x52b3...
# 1  [0x52b3b7328216e2c7:0x8278b6f3312a8593, 0x52b3...
# 2  [0x87f5a72e7d04c319:0xeadfb746bb955461, 0x87f5...
# 3  [0x87f78ed9ceed0c73:0x5c4170b7e403204d, 0x87f7...
# 4  [0x87f7a53aa9e9e56f:0x35fedc4a2e212b9f, 0x87f7...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Merge with aggregated business data
merged_df = review_df.merge(business_agg, on="gmap_id", how="left")
merged_df
# Out:
#               user_id                  name_x           time  rating  \
# 0        1.163883e+20               T Freeman  1593495298731     5.0
# 1        1.089889e+20          Sarah Westfall  1520893715113     5.0
# 2        1.117122e+20  Wayne Anthony Cullinan  1504541471455     5.0
# 3        1.024779e+20                  Judy E  1437677732701     4.0
# 4        1.175789e+20            Kelly Murphy  1521731566365     5.0
# ...               ...                     ...            ...     ...
# 9520253  1.002569e+20             Jessica Lee  1518600909205     2.0
# 9520254  1.019770e+20           Drew Landaeta  1504919358911     3.0
# 9520255  1.065794e+20                   Annie  1539711044354     5.0
# 9520256  1.043962e+20                      김집  1562226423561     3.0
# 9520257  1.177670e+20         Darlene Jenison  1497629144080     5.0
#
#                                                       text  pics  resp  \
# 0        Dr king saved me from suggested back surgery. ...  None  None
# 1        I have been going to see DR.King for years wou...  None  None
# 2        I have seen Dr. Warren King for over 30 years ...  None  None
# 3        I have been seeing Dr King as my body needs wo...  None  None
# 4        Absolutely amazing results! No more Cortisone ...  None  None
# ...                                                    ...   ...   ...
# 9520253                                               None  None  None
# 9520254                                               None  None  None
# 9520255                                               None  None  None
# 9520256                                               None  None  None
# 9520257                                               None  None  None
#
#                                        gmap_id                     name_y  \
# 0        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 1        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 2        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 3        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 4        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# ...                                        ...                        ...
# 9520253  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520254  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520255  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520256  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520257  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
#
#                                                    address  ...  longitude  \
# 0        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 1        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 2        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 3        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 4        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# ...                                                    ...  ...        ...
# 9520253  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520254  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520255  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520256  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520257  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
#
#                 category  avg_rating num_of_reviews  price  \
# 0         [Chiropractor]         4.7             14   None
# 1         [Chiropractor]         4.7             14   None
# 2         [Chiropractor]         4.7             14   None
# 3         [Chiropractor]         4.7             14   None
# 4         [Chiropractor]         4.7             14   None
# ...                  ...         ...            ...    ...
# 9520253  [Shopping mall]         4.3            327   None
# 9520254  [Shopping mall]         4.3            327   None
# 9520255  [Shopping mall]         4.3            327   None
# 9520256  [Shopping mall]         4.3            327   None
# 9520257  [Shopping mall]         4.3            327   None
#
#                                                      hours  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9520253  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520254  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520255  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520256  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520257  [[Wednesday, Closed], [Thursday, Closed], [Fri...
#
#                                                       MISC state  \
# 0        {'Accessibility': ['Wheelchair accessible entr...  None
# 1        {'Accessibility': ['Wheelchair accessible entr...  None
# 2        {'Accessibility': ['Wheelchair accessible entr...  None
# 3        {'Accessibility': ['Wheelchair accessible entr...  None
# 4        {'Accessibility': ['Wheelchair accessible entr...  None
# ...                                                    ...   ...
# 9520253  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520254  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520255  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520256  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520257  {'Service options': ['In-store shopping'], 'Ac...  None
#
#                                           relative_results  \
# 0        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 1        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 2        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 3        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 4        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# ...                                                    ...
# 9520253  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520254  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520255  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520256  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520257  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 9520253  https://www.google.com/maps/place//data=!4m2!3...
# 9520254  https://www.google.com/maps/place//data=!4m2!3...
# 9520255  https://www.google.com/maps/place//data=!4m2!3...
# 9520256  https://www.google.com/maps/place//data=!4m2!3...
# 9520257  https://www.google.com/maps/place//data=!4m2!3...
#
# [9520258 rows x 22 columns]

# %%
unmatched = review_df[~review_df['gmap_id'].isin(business_agg['gmap_id'])]
print(f"Unmatched rows: {len(unmatched)}")
print("Unique gmap_id in review_df:", review_df['gmap_id'].nunique())
print("Unique gmap_id in business_agg:", business_agg['gmap_id'].nunique())
# Out:
# Unmatched rows: 0
# Unique gmap_id in review_df: 80586
# Unique gmap_id in business_agg: 80586

# %%
#check if null values in 'text' column exist
print(merged_df['text'].isna().sum())
# Out:
# 3975858

# %%
#remove rows/records where 'text' is null
merged_df = merged_df.dropna(subset = ['text'])
merged_df
# Out:
#               user_id                  name_x           time  rating  \
# 0        1.163883e+20               T Freeman  1593495298731     5.0
# 1        1.089889e+20          Sarah Westfall  1520893715113     5.0
# 2        1.117122e+20  Wayne Anthony Cullinan  1504541471455     5.0
# 3        1.024779e+20                  Judy E  1437677732701     4.0
# 4        1.175789e+20            Kelly Murphy  1521731566365     5.0
# ...               ...                     ...            ...     ...
# 9520040  1.144411e+20           Tito Perfecto  1488124580000     4.0
# 9520041  1.160426e+20            Alisa Matter  1487181475360     4.0
# 9520042  1.117451e+20         Amy Frederiksen  1503433113370     3.0
# 9520043  1.094093e+20            Brian Hanson  1464299805235     3.0
# 9520044  1.054000e+20            Vagif Abiyev  1512029944693     5.0
#
#                                                       text  pics  resp  \
# 0        Dr king saved me from suggested back surgery. ...  None  None
# 1        I have been going to see DR.King for years wou...  None  None
# 2        I have seen Dr. Warren King for over 30 years ...  None  None
# 3        I have been seeing Dr King as my body needs wo...  None  None
# 4        Absolutely amazing results! No more Cortisone ...  None  None
# ...                                                    ...   ...   ...
# 9520040                                      Classy place.  None  None
# 9520041                 Eden Prarie mall is a great mall!!  None  None
# 9520042                            Nice little strip mall.  None  None
# 9520043  Extremely small mall in fact you probably woul...  None  None
# 9520044  (Translated by Google) We are satisfied with t...  None  None
#
#                                        gmap_id                     name_y  \
# 0        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 1        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 2        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 3        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 4        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# ...                                        ...                        ...
# 9520040  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520041  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520042  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520043  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520044  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
#
#                                                    address  ...  longitude  \
# 0        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 1        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 2        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 3        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# 4        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...  ... -93.324951
# ...                                                    ...  ...        ...
# 9520040  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520041  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520042  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520043  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
# 9520044  Prairie Village Mall, 16500 W 78th St, Eden Pr...  ... -93.487325
#
#                 category  avg_rating num_of_reviews  price  \
# 0         [Chiropractor]         4.7             14   None
# 1         [Chiropractor]         4.7             14   None
# 2         [Chiropractor]         4.7             14   None
# 3         [Chiropractor]         4.7             14   None
# 4         [Chiropractor]         4.7             14   None
# ...                  ...         ...            ...    ...
# 9520040  [Shopping mall]         4.3            327   None
# 9520041  [Shopping mall]         4.3            327   None
# 9520042  [Shopping mall]         4.3            327   None
# 9520043  [Shopping mall]         4.3            327   None
# 9520044  [Shopping mall]         4.3            327   None
#
#                                                      hours  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9520040  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520041  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520042  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520043  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520044  [[Wednesday, Closed], [Thursday, Closed], [Fri...
#
#                                                       MISC state  \
# 0        {'Accessibility': ['Wheelchair accessible entr...  None
# 1        {'Accessibility': ['Wheelchair accessible entr...  None
# 2        {'Accessibility': ['Wheelchair accessible entr...  None
# 3        {'Accessibility': ['Wheelchair accessible entr...  None
# 4        {'Accessibility': ['Wheelchair accessible entr...  None
# ...                                                    ...   ...
# 9520040  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520041  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520042  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520043  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520044  {'Service options': ['In-store shopping'], 'Ac...  None
#
#                                           relative_results  \
# 0        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 1        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 2        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 3        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 4        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# ...                                                    ...
# 9520040  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520041  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520042  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520043  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520044  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 9520040  https://www.google.com/maps/place//data=!4m2!3...
# 9520041  https://www.google.com/maps/place//data=!4m2!3...
# 9520042  https://www.google.com/maps/place//data=!4m2!3...
# 9520043  https://www.google.com/maps/place//data=!4m2!3...
# 9520044  https://www.google.com/maps/place//data=!4m2!3...
#
# [5544400 rows x 22 columns]

# %%
#delete pics 
merged_df = merged_df.drop(columns = ['pics'])
merged_df
# Out:
#               user_id                  name_x           time  rating  \
# 0        1.163883e+20               T Freeman  1593495298731     5.0
# 1        1.089889e+20          Sarah Westfall  1520893715113     5.0
# 2        1.117122e+20  Wayne Anthony Cullinan  1504541471455     5.0
# 3        1.024779e+20                  Judy E  1437677732701     4.0
# 4        1.175789e+20            Kelly Murphy  1521731566365     5.0
# ...               ...                     ...            ...     ...
# 9520040  1.144411e+20           Tito Perfecto  1488124580000     4.0
# 9520041  1.160426e+20            Alisa Matter  1487181475360     4.0
# 9520042  1.117451e+20         Amy Frederiksen  1503433113370     3.0
# 9520043  1.094093e+20            Brian Hanson  1464299805235     3.0
# 9520044  1.054000e+20            Vagif Abiyev  1512029944693     5.0
#
#                                                       text  resp  \
# 0        Dr king saved me from suggested back surgery. ...  None
# 1        I have been going to see DR.King for years wou...  None
# 2        I have seen Dr. Warren King for over 30 years ...  None
# 3        I have been seeing Dr King as my body needs wo...  None
# 4        Absolutely amazing results! No more Cortisone ...  None
# ...                                                    ...   ...
# 9520040                                      Classy place.  None
# 9520041                 Eden Prarie mall is a great mall!!  None
# 9520042                            Nice little strip mall.  None
# 9520043  Extremely small mall in fact you probably woul...  None
# 9520044  (Translated by Google) We are satisfied with t...  None
#
#                                        gmap_id                     name_y  \
# 0        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 1        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 2        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 3        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 4        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# ...                                        ...                        ...
# 9520040  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520041  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520042  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520043  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520044  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
#
#                                                    address description  ...  \
# 0        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 1        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 2        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 3        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 4        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# ...                                                    ...         ...  ...
# 9520040  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520041  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520042  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520043  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520044  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
#
#          longitude         category avg_rating  num_of_reviews  price  \
# 0       -93.324951   [Chiropractor]        4.7              14   None
# 1       -93.324951   [Chiropractor]        4.7              14   None
# 2       -93.324951   [Chiropractor]        4.7              14   None
# 3       -93.324951   [Chiropractor]        4.7              14   None
# 4       -93.324951   [Chiropractor]        4.7              14   None
# ...            ...              ...        ...             ...    ...
# 9520040 -93.487325  [Shopping mall]        4.3             327   None
# 9520041 -93.487325  [Shopping mall]        4.3             327   None
# 9520042 -93.487325  [Shopping mall]        4.3             327   None
# 9520043 -93.487325  [Shopping mall]        4.3             327   None
# 9520044 -93.487325  [Shopping mall]        4.3             327   None
#
#                                                      hours  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9520040  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520041  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520042  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520043  [[Wednesday, Closed], [Thursday, Closed], [Fri...
# 9520044  [[Wednesday, Closed], [Thursday, Closed], [Fri...
#
#                                                       MISC state  \
# 0        {'Accessibility': ['Wheelchair accessible entr...  None
# 1        {'Accessibility': ['Wheelchair accessible entr...  None
# 2        {'Accessibility': ['Wheelchair accessible entr...  None
# 3        {'Accessibility': ['Wheelchair accessible entr...  None
# 4        {'Accessibility': ['Wheelchair accessible entr...  None
# ...                                                    ...   ...
# 9520040  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520041  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520042  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520043  {'Service options': ['In-store shopping'], 'Ac...  None
# 9520044  {'Service options': ['In-store shopping'], 'Ac...  None
#
#                                           relative_results  \
# 0        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 1        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 2        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 3        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# 4        [0x52b330b8b53b8971:0x27920296640feb7a, 0x52b3...
# ...                                                    ...
# 9520040  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520041  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520042  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520043  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
# 9520044  [0x87f6189f4b3c99bf:0x81cebce377cf9b2a, 0x87f6...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 9520040  https://www.google.com/maps/place//data=!4m2!3...
# 9520041  https://www.google.com/maps/place//data=!4m2!3...
# 9520042  https://www.google.com/maps/place//data=!4m2!3...
# 9520043  https://www.google.com/maps/place//data=!4m2!3...
# 9520044  https://www.google.com/maps/place//data=!4m2!3...
#
# [5544400 rows x 21 columns]

# %%
import ast

merged_df["category"] = merged_df["category"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Expand the list into separate columns
category_expanded = merged_df["category"].apply(pd.Series)

# Rename columns as 'category_1', 'category_2', etc.
category_expanded.columns = [f"category_{i+1}" for i in range(category_expanded.shape[1])]

# Concatenate with original dataset
merged_df = pd.concat([merged_df, category_expanded], axis=1)

# Drop original 'category' column
#cleaned_file.drop(columns=["category"], inplace=True)

merged_df
# Out:
#               user_id                  name_x           time  rating  \
# 0        1.163883e+20               T Freeman  1593495298731     5.0
# 1        1.089889e+20          Sarah Westfall  1520893715113     5.0
# 2        1.117122e+20  Wayne Anthony Cullinan  1504541471455     5.0
# 3        1.024779e+20                  Judy E  1437677732701     4.0
# 4        1.175789e+20            Kelly Murphy  1521731566365     5.0
# ...               ...                     ...            ...     ...
# 9520040  1.144411e+20           Tito Perfecto  1488124580000     4.0
# 9520041  1.160426e+20            Alisa Matter  1487181475360     4.0
# 9520042  1.117451e+20         Amy Frederiksen  1503433113370     3.0
# 9520043  1.094093e+20            Brian Hanson  1464299805235     3.0
# 9520044  1.054000e+20            Vagif Abiyev  1512029944693     5.0
#
#                                                       text  resp  \
# 0        Dr king saved me from suggested back surgery. ...  None
# 1        I have been going to see DR.King for years wou...  None
# 2        I have seen Dr. Warren King for over 30 years ...  None
# 3        I have been seeing Dr King as my body needs wo...  None
# 4        Absolutely amazing results! No more Cortisone ...  None
# ...                                                    ...   ...
# 9520040                                      Classy place.  None
# 9520041                 Eden Prarie mall is a great mall!!  None
# 9520042                            Nice little strip mall.  None
# 9520043  Extremely small mall in fact you probably woul...  None
# 9520044  (Translated by Google) We are satisfied with t...  None
#
#                                        gmap_id                     name_y  \
# 0        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 1        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 2        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 3        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 4        0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# ...                                        ...                        ...
# 9520040  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520041  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520042  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520043  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
# 9520044  0x87f61945862e55c3:0x407cf06a98ff5e7c       Prairie Village Mall
#
#                                                    address description  ...  \
# 0        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 1        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 2        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 3        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# 4        Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...        None  ...
# ...                                                    ...         ...  ...
# 9520040  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520041  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520042  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520043  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
# 9520044  Prairie Village Mall, 16500 W 78th St, Eden Pr...        None  ...
#
#          category_10  category_11 category_12  category_13  category_14  \
# 0                NaN          NaN         NaN          NaN          NaN
# 1                NaN          NaN         NaN          NaN          NaN
# 2                NaN          NaN         NaN          NaN          NaN
# 3                NaN          NaN         NaN          NaN          NaN
# 4                NaN          NaN         NaN          NaN          NaN
# ...              ...          ...         ...          ...          ...
# 9520040          NaN          NaN         NaN          NaN          NaN
# 9520041          NaN          NaN         NaN          NaN          NaN
# 9520042          NaN          NaN         NaN          NaN          NaN
# 9520043          NaN          NaN         NaN          NaN          NaN
# 9520044          NaN          NaN         NaN          NaN          NaN
#
#         category_15 category_16 category_17 category_18 category_19
# 0               NaN         NaN         NaN         NaN         NaN
# 1               NaN         NaN         NaN         NaN         NaN
# 2               NaN         NaN         NaN         NaN         NaN
# 3               NaN         NaN         NaN         NaN         NaN
# 4               NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 9520040         NaN         NaN         NaN         NaN         NaN
# 9520041         NaN         NaN         NaN         NaN         NaN
# 9520042         NaN         NaN         NaN         NaN         NaN
# 9520043         NaN         NaN         NaN         NaN         NaN
# 9520044         NaN         NaN         NaN         NaN         NaN
#
# [5544400 rows x 40 columns]

# %%
import re

from tqdm import tqdm
tqdm.pandas()

healthcare_categories = {
    "medical clinic", "women's health clinic", "home health care service", "internist", "allergist",
    "diabetes center", "doctor", "family practice physician", "optometrist", "pharmacy", "dentist",
    "medical supply store", "orthopedic surgeon", "surgeon", "psychotherapist", "dental clinic",
    "orthodontist", "physical therapist", "chiropractor", "hospital", "sleep clinic", "optician",
    "cancer treatment center", "medical center", "physical therapy clinic", "medical laboratory",
    "public health department", "psychologist", "radiologist", "podiatrist", "nursing home",
    "medical group", "x-ray lab", "dermatologist", "pediatrician", "massage therapist",
    "periodontist", "obstetrician-gynecologist", "sports medicine clinic", "psychiatric hospital",
    "orthotics & prosthetics service", "physical fitness program", "ophthalmologist", "hospice",
    "retirement home", "rehabilitation center", "pediatric dentist", "teeth whitening service",
    "dental hygienist", "endodontist", "dental implants periodontist", "cosmetic dentist",
    "emergency dental service", "urgent care center", "wellness center", "walk-in clinic",
    "general practitioner", "children's hospital", "mental health clinic", "otolaryngologist", "eye care center", 
    "ophthalmology clinic","lasik surgeon","blood donation center" ,
    "Addiction treatment center","denture care center","gym","fitness center","personal trainer", 
    "Psychiatrist", "Drug store","Vitamin & supplements store","weight loss service",
    "Pulmonologist","gymnastics center", "oral surgeon","Oral and maxillofacial surgeon","homeless service",
     "Alcoholism treatment program", "Homeless shelter", "child care agency","day care center",
     "Neurosurgeon","Vascular surgeon", "Cardiologist", "Laboratory", "Specialized clinic",
     "contact lenses supplier","massage spa","Reflexologist", "Rheumatologist", "Surgical center",
     "Mental health service", "Eating disorder treatment center", "Hair removal service", 
     "Skin care clinic","foot care","laser hair removal service","spa","medical spa",
     "sports nutrition store","pain control clinic","audiologist","plastic surgeon","pathologist",
     "Pediatric cardiologist","Sports medicine physician","Medical equipment supplier","nurse practitioner",
     "Counselor", "Family counselor", "Marriage or relationship counselor","facial spa",
     "Occupational medical physician","Urologist","Nephrologist","Endocrinologist",
     "Alternative medicine practitioner", "Holistic medicine practitioner",
     "health","massage","Dialysis center", "Local medical services", 
     "hand surgeon","Gastroenterologist","Thai massage therapist","Hearing aid store", "Hearing aid repair service"
                                        
}
# Function to check if a business belongs to the healthcare category
def classify_healthcare(row):
    for i in range(1, 16):  # Assuming category_1 to category_15 exist
        category_col = f"category_{i}"
        if category_col in row and isinstance(row[category_col], str):  # Check if column exists and is a string
            for keyword in healthcare_categories:
                if re.search(rf"\b{keyword}\b", row[category_col], re.IGNORECASE):  # Match whole word
                    return "Healthcare"  # Assign healthcare label
    return "Other"  # Default category if no match

# Apply the function to create a new 'general_labelling' column
merged_df["general_labelling"] = merged_df.progress_apply(classify_healthcare, axis=1)
# Out:
# 100%|██████████| 5544400/5544400 [3:38:23<00:00, 423.13it/s]

# %%
# Filter records where 'general_labelling' is "Healthcare"
healthcare_dataset = merged_df[merged_df["general_labelling"] == "Healthcare"]

# %%
minnesota_healthcare_dataset_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/minnesota_healthcare_dataset.csv"

# %%
healthcare_dataset.to_csv(minnesota_healthcare_dataset_path, index=False)

# %%
import pandas as pd
path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/minnesota_healthcare_dataset.csv"
minne_df = pd.read_csv(path)
minne_df
# Out:
# C:\Users\eliza\AppData\Local\Temp\ipykernel_39140\4132945850.py:3: DtypeWarning: Columns (18,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   minne_df = pd.read_csv(path)
#              user_id                     name_x           time  rating  \
# 0       1.163883e+20                  T Freeman  1593495298731     5.0
# 1       1.089889e+20             Sarah Westfall  1520893715113     5.0
# 2       1.117122e+20     Wayne Anthony Cullinan  1504541471455     5.0
# 3       1.024779e+20                     Judy E  1437677732701     4.0
# 4       1.175789e+20               Kelly Murphy  1521731566365     5.0
# ...              ...                        ...            ...     ...
# 340942  1.016955e+20  Ana Paula Perez Bessonart  1524587453485     4.0
# 340943  1.015213e+20             Pavel Kucherov  1501922710293     5.0
# 340944  1.055253e+20               Rocio Chavez  1520060095179     5.0
# 340945  1.015075e+20          Najla Abdulkareem  1583072374762     5.0
# 340946  1.154405e+20               FAHAD ALAZMI  1497479952147     5.0
#
#                                                      text resp  \
# 0       Dr king saved me from suggested back surgery. ...  NaN
# 1       I have been going to see DR.King for years wou...  NaN
# 2       I have seen Dr. Warren King for over 30 years ...  NaN
# 3       I have been seeing Dr King as my body needs wo...  NaN
# 4       Absolutely amazing results! No more Cortisone ...  NaN
# ...                                                   ...  ...
# 340942  (Translated by Google) It has good products th...  NaN
# 340943  (Translated by Google) A good liquor store wit...  NaN
# 340944  (Translated by Google) Good products, good pri...  NaN
# 340945                                                  👍  NaN
# 340946  (Translated by Google) One of the best stores\...  NaN
#
#                                       gmap_id                     name_y  \
# 0       0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 1       0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 2       0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 3       0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# 4       0x52b3311bcc443159:0xa157dd0155d0d910  Quantum Chiropractic Arts
# ...                                       ...                        ...
# 340942  0x87f75f37d5632e21:0xd4ae1b40659212ca               Trader Joe's
# 340943  0x87f75f37d5632e21:0xd4ae1b40659212ca               Trader Joe's
# 340944  0x87f75f37d5632e21:0xd4ae1b40659212ca               Trader Joe's
# 340945  0x87f75f37d5632e21:0xd4ae1b40659212ca               Trader Joe's
# 340946  0x87f75f37d5632e21:0xd4ae1b40659212ca               Trader Joe's
#
#                                                   address  \
# 0       Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...
# 1       Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...
# 2       Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...
# 3       Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...
# 4       Quantum Chiropractic Arts, 5615 Brooklyn Blvd ...
# ...                                                   ...
# 340942  Trader Joe's, 1200 16th St SW, Rochester, MN 5...
# 340943  Trader Joe's, 1200 16th St SW, Rochester, MN 5...
# 340944  Trader Joe's, 1200 16th St SW, Rochester, MN 5...
# 340945  Trader Joe's, 1200 16th St SW, Rochester, MN 5...
# 340946  Trader Joe's, 1200 16th St SW, Rochester, MN 5...
#
#                                               description  ...  category_11  \
# 0                                                     NaN  ...          NaN
# 1                                                     NaN  ...          NaN
# 2                                                     NaN  ...          NaN
# 3                                                     NaN  ...          NaN
# 4                                                     NaN  ...          NaN
# ...                                                   ...  ...          ...
# 340942  Grocery chain with a variety of signature item...  ...          NaN
# 340943  Grocery chain with a variety of signature item...  ...          NaN
# 340944  Grocery chain with a variety of signature item...  ...          NaN
# 340945  Grocery chain with a variety of signature item...  ...          NaN
# 340946  Grocery chain with a variety of signature item...  ...          NaN
#
#         category_12 category_13  category_14  category_15 category_16  \
# 0               NaN         NaN          NaN          NaN         NaN
# 1               NaN         NaN          NaN          NaN         NaN
# 2               NaN         NaN          NaN          NaN         NaN
# 3               NaN         NaN          NaN          NaN         NaN
# 4               NaN         NaN          NaN          NaN         NaN
# ...             ...         ...          ...          ...         ...
# 340942          NaN         NaN          NaN          NaN         NaN
# 340943          NaN         NaN          NaN          NaN         NaN
# 340944          NaN         NaN          NaN          NaN         NaN
# 340945          NaN         NaN          NaN          NaN         NaN
# 340946          NaN         NaN          NaN          NaN         NaN
#
#        category_17 category_18 category_19 general_labelling
# 0              NaN         NaN         NaN        Healthcare
# 1              NaN         NaN         NaN        Healthcare
# 2              NaN         NaN         NaN        Healthcare
# 3              NaN         NaN         NaN        Healthcare
# 4              NaN         NaN         NaN        Healthcare
# ...            ...         ...         ...               ...
# 340942         NaN         NaN         NaN        Healthcare
# 340943         NaN         NaN         NaN        Healthcare
# 340944         NaN         NaN         NaN        Healthcare
# 340945         NaN         NaN         NaN        Healthcare
# 340946         NaN         NaN         NaN        Healthcare
#
# [340947 rows x 41 columns]
