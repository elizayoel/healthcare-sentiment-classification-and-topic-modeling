# %%
import pandas as pd

# %%
review_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/OregonReview/review-Oregon.json"
review_df = pd.read_json(review_path, lines = True)
review_df
# Out:
#                user_id                name           time  rating  \
# 0         1.089908e+20     Richard Carroll  1604639688837     5.0
# 1         1.131780e+20     Matthew Schenck  1563021713865     5.0
# 2         1.089903e+20  Richard FranklinJr  1568391103458     5.0
# 3         1.074838e+20          Abel Sogaw  1568812857175     5.0
# 4         1.033674e+20     Michelle Gamlen  1572725240782     5.0
# ...                ...                 ...            ...     ...
# 11012165  1.084714e+20  Michael Vanderklis  1594946631906     5.0
# 11012166  1.074469e+20        Robert Bragg  1567472586741     5.0
# 11012167  1.068432e+20        Krista Eason  1599307257750     5.0
# 11012168  1.160691e+20         Ryan Gamble  1561852287727     4.0
# 11012169  1.120385e+20          Josh Akins  1569900766353     5.0
#
#                                                        text  pics  \
# 0         Fabulous food and amazing service.  Will be ba...  None
# 1         Great baked goods.  I recommend the cinnamon b...  None
# 2                                 Cinnamon buns are awesome  None
# 3                                                      None  None
# 4                                                      None  None
# ...                                                     ...   ...
# 11012165                                               None  None
# 11012166                                               None  None
# 11012167                                               None  None
# 11012168                                               None  None
# 11012169                                               None  None
#
#                                                        resp  \
# 0                                                      None
# 1         {'time': 1568392603217, 'text': 'Thank you so ...
# 2             {'time': 1568392542351, 'text': 'Thank you!'}
# 3                                                      None
# 4         {'time': 1572780122594, 'text': 'Thank you Mic...
# ...                                                     ...
# 11012165                                               None
# 11012166                                               None
# 11012167                                               None
# 11012168                                               None
# 11012169                                               None
#
#                                         gmap_id
# 0         0x80dce9997c8d25fd:0xc6c81c1983060cbc
# 1          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 2          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 3          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 4          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# ...                                         ...
# 11012165  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012166  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012167  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012168  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012169  0x54c5f293752506a3:0x89a72efa7aa6470c
#
# [11012170 rows x 8 columns]

# %%
business_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/OregonMeta/meta-Oregon.json"
business_df = pd.read_json(business_path, lines = True)
business_df
# Out:
#                                   name  \
# 0                    iPolish Nails Spa
# 1      Karens Country Confections, LLC
# 2        E & L General Contractors Inc
# 3                McDonald Orthodontics
# 4          Donatello's at Marion Forks
# ...                                ...
# 93471                   Calamity Janes
# 93472              Granny's Drive-Thru
# 93473                 Timberline Lodge
# 93474                      Blockbuster
# 93475           Rapid Pleasure Rafting
#
#                                                  address  \
# 0                                                   None
# 1                                                   None
# 2      E & L General Contractors Inc, 14161 S Redland...
# 3      McDonald Orthodontics, 1855 W Nob Hill St SE #...
# 4      Donatello's at Marion Forks, 34970 OR-22, Idan...
# ...                                                  ...
# 93471       Calamity Janes, 42015 US-26, Sandy, OR 97055
# 93472  Granny's Drive-Thru, 156 NW 6th Ave, Estacada,...
# 93473  Timberline Lodge, 27500 E Timberline Road, Gov...
# 93474     Blockbuster, 211 NE Revere Ave, Bend, OR 97701
# 93475  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...
#
#                                      gmap_id  \
# 0      0x80dce9997c8d25fd:0xc6c81c1983060cbc
# 1       0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 2      0x549576c32c7ce82d:0x166266dbfadf6660
# 3      0x54bfff5952aad583:0xad7afdc825730614
# 4      0x54bf0922053d25ed:0x73bbe9954ead56b2
# ...                                      ...
# 93471   0x549585717f9667b9:0x72e20b4ac67e7ad
# 93472  0x5495818c14edde8b:0xc1bd6f8ae8bb781e
# 93473  0x54be1eaaa37312a3:0x6738b4912b8ca4f2
# 93474   0x54b8c8a3c8ba7bf1:0xc928e1d42380f10
# 93475  0x54c5f293752506a3:0x89a72efa7aa6470c
#
#                                              description   latitude  \
# 0                                                   None  45.597767
# 1                                                   None  45.598021
# 2                                                   None  45.360527
# 3                                                   None  44.922504
# 4                                                   None  44.615250
# ...                                                  ...        ...
# 93471  Simple American meals & breakfast in an Old-We...  45.383681
# 93472                                               None  45.294446
# 93473  Ski retreat offering 1930s lodge rooms & rusti...  45.331128
# 93474                                               None  44.067311
# 93475                                               None  42.616713
#
#         longitude                                           category  \
# 0     -127.269699                [Nail salon, Service establishment]
# 1     -127.269639                    [Bakery, Service establishment]
# 2     -122.575448                              [Concrete contractor]
# 3     -123.043930                                     [Orthodontist]
# 4     -121.948546                                    [Pizza Takeout]
# ...           ...                                                ...
# 93471 -122.230658  [Hamburger restaurant, Bar, Pancake restaurant...
# 93472 -122.335637  [Restaurant, American restaurant, Diner, Hambu...
# 93473 -121.711006                                [Hotel, Ski resort]
# 93474 -121.303614                  [Movie rental store, Video store]
# 93475 -122.812796                              [Raft trip outfitter]
#
#        avg_rating  num_of_reviews price  \
# 0             5.0               1  None
# 1             5.0               4  None
# 2             5.0               6  None
# 3             4.9             198  None
# 4             4.5              27  None
# ...           ...             ...   ...
# 93471         4.3             888    $$
# 93472         4.2             577    $$
# 93473         4.6            7868  None
# 93474         4.9            3038     $
# 93475         4.8              93  None
#
#                                                    hours  \
# 0      [[Thursday, 10AM–7PM], [Friday, 10AM–7PM], [Sa...
# 1      [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2                                                   None
# 3      [[Thursday, 8AM–4:30PM], [Friday, Closed], [Sa...
# 4      [[Thursday, 11AM–7PM], [Friday, 11AM–7PM], [Sa...
# ...                                                  ...
# 93471  [[Wednesday, 12–7PM], [Thursday, 12–7PM], [Fri...
# 93472  [[Wednesday, 11AM–8PM], [Thursday, 11AM–8PM], ...
# 93473                                               None
# 93474  [[Wednesday, 11AM–8PM], [Thursday, 11AM–6PM], ...
# 93475  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
#
#                                                     MISC  \
# 0          {'Payments': ['Debit cards', 'Credit cards']}
# 1                      {'Service options': ['Delivery']}
# 2                                                   None
# 3      {'From the business': ['Identifies as veteran-...
# 4           {'Service options': ['Takeout', 'Delivery']}
# ...                                                  ...
# 93471  {'Service options': ['Delivery', 'Dine-in'], '...
# 93472  {'Service options': ['Outdoor seating', 'Curbs...
# 93473                                               None
# 93474  {'Service options': ['Curbside pickup', 'In-st...
# 93475  {'Accessibility': ['Wheelchair accessible entr...
#
#                         state  \
# 0           Open ⋅ Closes 7PM
# 1      Closed ⋅ Opens 9AM Sat
# 2                        None
# 3          Closed ⋅ Opens 8AM
# 4          Temporarily closed
# ...                       ...
# 93471                     NaN
# 93472                     NaN
# 93473                     NaN
# 93474                     NaN
# 93475                     NaN
#
#                                         relative_results  \
# 0      [0x80dce9aec70a4ee9:0xc7cf24c90e4b537f, 0x80dc...
# 1      [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 2      [0x54957451d00ee61b:0xe247a7cb0184f2e, 0x54957...
# 3      [0x54bfff5c0ef7b38b:0xa14bec68116fbe4a, 0x54bf...
# 4                                                   None
# ...                                                  ...
# 93471  [0x549585477718a6cd:0x33f142c9ac1d0316, 0x5495...
# 93472  [0x549581ed29e31b3b:0xb3cbd81f45851279, 0x5495...
# 93473                                               None
# 93474  [0x54b8cf2833b33cd3:0xa79c9cd0424b548c, 0x54b8...
# 93475  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 93471  https://www.google.com/maps/place//data=!4m2!3...
# 93472  https://www.google.com/maps/place//data=!4m2!3...
# 93473  https://www.google.com/maps/place//data=!4m2!3...
# 93474  https://www.google.com/maps/place//data=!4m2!3...
# 93475  https://www.google.com/maps/place//data=!4m2!3...
#
# [93476 rows x 15 columns]

# %%
# Aggregate business metadata by gmap_id before merging
business_agg = business_df.groupby("gmap_id", as_index=False).agg({
    "name": "first",  # Keep first occurrence (assumes same name per gmap_id)
    "address": "first",
    "description": "first",
    "latitude": "first",
    "longitude": "first",
    "category": lambda x: list(set(x.sum())) if x.apply(lambda v: isinstance(v, list)).any() else list(set(x)),
    "avg_rating": "mean",  # Use mean rating if multiple exist
    "num_of_reviews": "sum",
    "price": "first",
    "hours": "first",
    "MISC": "first",
    "state": "first",
    "relative_results": "first",
    "url": "first"
})

# Check if aggregation worked
print(business_agg.head())
# Out:
#                                  gmap_id                      name  \
# 0                 0x0:0x4e62f4d95b41bde4        Koeber's Interiors
# 1                 0x0:0x4f38ec34172d2732       Hillsboro Utilities
# 2  0x1412c9ec43d5b52b:0x1fd4b5bdaac18a0d          Sterling Academy
# 3  0x145e95d175990aed:0x304f031f3348982c              Façade Privé
# 4  0x14685a04bed49093:0x23a05a5280169185  Calla Lily Rose Boutique
#
#                                              address  \
# 0  Koeber's Interiors, 6710 SW 111th Ave, Beavert...
# 1  Hillsboro Utilities, 150 E Main St #1, Hillsbo...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                          description   latitude   longitude  \
# 0  Merchant since 1963 with a variety of soft & h...  45.471369 -122.789780
# 1                                               None  45.522032 -122.989072
# 2                                               None  45.598021 -127.269639
# 3                                               None  45.597767 -127.269699
# 4                                               None  45.597481 -127.269699
#
#                                             category  avg_rating  \
# 0  [Carpet store, Flooring store, Window treatmen...         4.9
# 1                            [Water utility company]         2.1
# 2                                  [Learning center]         4.5
# 3                                   [Make-up artist]         5.0
# 4  [Formal wear store, Boutique, Service establis...         4.9
#
#    num_of_reviews price                                              hours  \
# 0              38  None  [[Wednesday, 8AM–4PM], [Thursday, 8AM–4PM], [F...
# 1               8  None                                               None
# 2               2  None  [[Saturday, Closed], [Sunday, Closed], [Monday...
# 3               8  None  [[Sunday, Closed], [Monday, 10AM–6PM], [Tuesda...
# 4              27  None  [[Sunday, Closed], [Monday, 10:30AM–6PM], [Tue...
#
#                                                 MISC                    state  \
# 0  {'From the business': ['Identifies as women-le...   Closed ⋅ Opens 8AM Thu
# 1  {'Accessibility': ['Wheelchair accessible entr...                     None
# 2  {'Accessibility': ['Wheelchair accessible entr...   Closed ⋅ Opens 8AM Mon
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM Mon
# 4  {'Highlights': ['LGBTQ friendly'], 'Payments':...       Permanently closed
#
#                                     relative_results  \
# 0  [0x54950c004ac5e9c7:0x8d94cfab8f72a575, 0x5495...
# 1  [0x54951abcb1030061:0x3e984578bbcc5b98, 0x5495...
# 2  [0x88d9a83c8ad0c3ad:0xc6492295a4d40799, 0x88d9...
# 3  [0x8640c3dbdff0ffd9:0x72e565a5b3dfd7e, 0x8640c...
# 4  [0x88c2c1303a2dfa4f:0x3b690058a64888ad, 0x88c2...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Merge with aggregated business data
merged_df = review_df.merge(business_agg, on="gmap_id", how="left")
merged_df
# Out:
#                user_id              name_x           time  rating  \
# 0         1.089908e+20     Richard Carroll  1604639688837     5.0
# 1         1.131780e+20     Matthew Schenck  1563021713865     5.0
# 2         1.089903e+20  Richard FranklinJr  1568391103458     5.0
# 3         1.074838e+20          Abel Sogaw  1568812857175     5.0
# 4         1.033674e+20     Michelle Gamlen  1572725240782     5.0
# ...                ...                 ...            ...     ...
# 11012165  1.084714e+20  Michael Vanderklis  1594946631906     5.0
# 11012166  1.074469e+20        Robert Bragg  1567472586741     5.0
# 11012167  1.068432e+20        Krista Eason  1599307257750     5.0
# 11012168  1.160691e+20         Ryan Gamble  1561852287727     4.0
# 11012169  1.120385e+20          Josh Akins  1569900766353     5.0
#
#                                                        text  pics  \
# 0         Fabulous food and amazing service.  Will be ba...  None
# 1         Great baked goods.  I recommend the cinnamon b...  None
# 2                                 Cinnamon buns are awesome  None
# 3                                                      None  None
# 4                                                      None  None
# ...                                                     ...   ...
# 11012165                                               None  None
# 11012166                                               None  None
# 11012167                                               None  None
# 11012168                                               None  None
# 11012169                                               None  None
#
#                                                        resp  \
# 0                                                      None
# 1         {'time': 1568392603217, 'text': 'Thank you so ...
# 2             {'time': 1568392542351, 'text': 'Thank you!'}
# 3                                                      None
# 4         {'time': 1572780122594, 'text': 'Thank you Mic...
# ...                                                     ...
# 11012165                                               None
# 11012166                                               None
# 11012167                                               None
# 11012168                                               None
# 11012169                                               None
#
#                                         gmap_id  \
# 0         0x80dce9997c8d25fd:0xc6c81c1983060cbc
# 1          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 2          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 3          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 4          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# ...                                         ...
# 11012165  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012166  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012167  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012168  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012169  0x54c5f293752506a3:0x89a72efa7aa6470c
#
#                                    name_y  \
# 0                       iPolish Nails Spa
# 1         Karens Country Confections, LLC
# 2         Karens Country Confections, LLC
# 3         Karens Country Confections, LLC
# 4         Karens Country Confections, LLC
# ...                                   ...
# 11012165           Rapid Pleasure Rafting
# 11012166           Rapid Pleasure Rafting
# 11012167           Rapid Pleasure Rafting
# 11012168           Rapid Pleasure Rafting
# 11012169           Rapid Pleasure Rafting
#
#                                                     address  ...   longitude  \
# 0                                                      None  ... -127.269699
# 1                                                      None  ... -127.269639
# 2                                                      None  ... -127.269639
# 3                                                      None  ... -127.269639
# 4                                                      None  ... -127.269639
# ...                                                     ...  ...         ...
# 11012165  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012166  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012167  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012168  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012169  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
#
#                                      category  avg_rating num_of_reviews  \
# 0         [Nail salon, Service establishment]         5.0              2
# 1             [Bakery, Service establishment]         5.0              8
# 2             [Bakery, Service establishment]         5.0              8
# 3             [Bakery, Service establishment]         5.0              8
# 4             [Bakery, Service establishment]         5.0              8
# ...                                       ...         ...            ...
# 11012165                [Raft trip outfitter]         4.8             93
# 11012166                [Raft trip outfitter]         4.8             93
# 11012167                [Raft trip outfitter]         4.8             93
# 11012168                [Raft trip outfitter]         4.8             93
# 11012169                [Raft trip outfitter]         4.8             93
#
#           price                                              hours  \
# 0          None  [[Thursday, 10AM–7PM], [Friday, 10AM–7PM], [Sa...
# 1          None  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2          None  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 3          None  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 4          None  [[Thursday, Closed], [Friday, Closed], [Saturd...
# ...         ...                                                ...
# 11012165   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012166   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012167   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012168   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012169   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
#
#                                                        MISC  \
# 0             {'Payments': ['Debit cards', 'Credit cards']}
# 1                         {'Service options': ['Delivery']}
# 2                         {'Service options': ['Delivery']}
# 3                         {'Service options': ['Delivery']}
# 4                         {'Service options': ['Delivery']}
# ...                                                     ...
# 11012165  {'Accessibility': ['Wheelchair accessible entr...
# 11012166  {'Accessibility': ['Wheelchair accessible entr...
# 11012167  {'Accessibility': ['Wheelchair accessible entr...
# 11012168  {'Accessibility': ['Wheelchair accessible entr...
# 11012169  {'Accessibility': ['Wheelchair accessible entr...
#
#                            state  \
# 0              Open ⋅ Closes 7PM
# 1         Closed ⋅ Opens 9AM Sat
# 2         Closed ⋅ Opens 9AM Sat
# 3         Closed ⋅ Opens 9AM Sat
# 4         Closed ⋅ Opens 9AM Sat
# ...                          ...
# 11012165                    None
# 11012166                    None
# 11012167                    None
# 11012168                    None
# 11012169                    None
#
#                                            relative_results  \
# 0         [0x80dce9aec70a4ee9:0xc7cf24c90e4b537f, 0x80dc...
# 1         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 2         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 3         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 4         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# ...                                                     ...
# 11012165  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012166  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012167  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012168  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012169  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 2         https://www.google.com/maps/place//data=!4m2!3...
# 3         https://www.google.com/maps/place//data=!4m2!3...
# 4         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 11012165  https://www.google.com/maps/place//data=!4m2!3...
# 11012166  https://www.google.com/maps/place//data=!4m2!3...
# 11012167  https://www.google.com/maps/place//data=!4m2!3...
# 11012168  https://www.google.com/maps/place//data=!4m2!3...
# 11012169  https://www.google.com/maps/place//data=!4m2!3...
#
# [11012170 rows x 22 columns]

# %%
unmatched = review_df[~review_df['gmap_id'].isin(business_agg['gmap_id'])]
print(f"Unmatched rows: {len(unmatched)}")
print("Unique gmap_id in review_df:", review_df['gmap_id'].nunique())
print("Unique gmap_id in business_agg:", business_agg['gmap_id'].nunique())
# Out:
# Unmatched rows: 0
# Unique gmap_id in review_df: 93006
# Unique gmap_id in business_agg: 93006

# %%
#check if null values in 'text' column exist
print(merged_df['text'].isna().sum())
# Out:
# 4252264

# %%
#remove rows/records where 'text' is null
merged_df = merged_df.dropna(subset = ['text'])
merged_df
# Out:
#                user_id              name_x           time  rating  \
# 0         1.089908e+20     Richard Carroll  1604639688837     5.0
# 1         1.131780e+20     Matthew Schenck  1563021713865     5.0
# 2         1.089903e+20  Richard FranklinJr  1568391103458     5.0
# 5         1.089879e+20       Alan Martinez  1568530547167     5.0
# 6         1.060079e+20         Nicole Sime  1461891541675     5.0
# ...                ...                 ...            ...     ...
# 11012133  1.020084e+20         Liam Larsen  1563823527577     5.0
# 11012134  1.097044e+20         eileen lark  1535574173445     4.0
# 11012135  1.103217e+20      Eileen Collins  1537059253363     5.0
# 11012136  1.033860e+20     VRi Justin Marx  1495396947629     5.0
# 11012137  1.050566e+20      James McDaniel  1505344049376     5.0
#
#                                                        text  pics  \
# 0         Fabulous food and amazing service.  Will be ba...  None
# 1         Great baked goods.  I recommend the cinnamon b...  None
# 2                                 Cinnamon buns are awesome  None
# 5                                Good people. Good workers.  None
# 6         The work they do at E & L unprecedented, the c...  None
# ...                                                     ...   ...
# 11012133                                            fun fun  None
# 11012134                                 Very professional.  None
# 11012135                                     Great service!  None
# 11012136                                Use them every year  None
# 11012137  I look forward to rafting the Rogue River with...  None
#
#                                                        resp  \
# 0                                                      None
# 1         {'time': 1568392603217, 'text': 'Thank you so ...
# 2             {'time': 1568392542351, 'text': 'Thank you!'}
# 5                                                      None
# 6                                                      None
# ...                                                     ...
# 11012133                                               None
# 11012134                                               None
# 11012135                                               None
# 11012136                                               None
# 11012137                                               None
#
#                                         gmap_id  \
# 0         0x80dce9997c8d25fd:0xc6c81c1983060cbc
# 1          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 2          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 5         0x549576c32c7ce82d:0x166266dbfadf6660
# 6         0x549576c32c7ce82d:0x166266dbfadf6660
# ...                                         ...
# 11012133  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012134  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012135  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012136  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012137  0x54c5f293752506a3:0x89a72efa7aa6470c
#
#                                    name_y  \
# 0                       iPolish Nails Spa
# 1         Karens Country Confections, LLC
# 2         Karens Country Confections, LLC
# 5           E & L General Contractors Inc
# 6           E & L General Contractors Inc
# ...                                   ...
# 11012133           Rapid Pleasure Rafting
# 11012134           Rapid Pleasure Rafting
# 11012135           Rapid Pleasure Rafting
# 11012136           Rapid Pleasure Rafting
# 11012137           Rapid Pleasure Rafting
#
#                                                     address  ...   longitude  \
# 0                                                      None  ... -127.269699
# 1                                                      None  ... -127.269639
# 2                                                      None  ... -127.269639
# 5         E & L General Contractors Inc, 14161 S Redland...  ... -122.575448
# 6         E & L General Contractors Inc, 14161 S Redland...  ... -122.575448
# ...                                                     ...  ...         ...
# 11012133  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012134  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012135  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012136  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
# 11012137  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...  ... -122.812796
#
#                                      category  avg_rating num_of_reviews  \
# 0         [Nail salon, Service establishment]         5.0              2
# 1             [Bakery, Service establishment]         5.0              8
# 2             [Bakery, Service establishment]         5.0              8
# 5                       [Concrete contractor]         5.0             12
# 6                       [Concrete contractor]         5.0             12
# ...                                       ...         ...            ...
# 11012133                [Raft trip outfitter]         4.8             93
# 11012134                [Raft trip outfitter]         4.8             93
# 11012135                [Raft trip outfitter]         4.8             93
# 11012136                [Raft trip outfitter]         4.8             93
# 11012137                [Raft trip outfitter]         4.8             93
#
#           price                                              hours  \
# 0          None  [[Thursday, 10AM–7PM], [Friday, 10AM–7PM], [Sa...
# 1          None  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2          None  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 5          None                                               None
# 6          None                                               None
# ...         ...                                                ...
# 11012133   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012134   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012135   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012136   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012137   None  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
#
#                                                        MISC  \
# 0             {'Payments': ['Debit cards', 'Credit cards']}
# 1                         {'Service options': ['Delivery']}
# 2                         {'Service options': ['Delivery']}
# 5                                                      None
# 6                                                      None
# ...                                                     ...
# 11012133  {'Accessibility': ['Wheelchair accessible entr...
# 11012134  {'Accessibility': ['Wheelchair accessible entr...
# 11012135  {'Accessibility': ['Wheelchair accessible entr...
# 11012136  {'Accessibility': ['Wheelchair accessible entr...
# 11012137  {'Accessibility': ['Wheelchair accessible entr...
#
#                            state  \
# 0              Open ⋅ Closes 7PM
# 1         Closed ⋅ Opens 9AM Sat
# 2         Closed ⋅ Opens 9AM Sat
# 5                           None
# 6                           None
# ...                          ...
# 11012133                    None
# 11012134                    None
# 11012135                    None
# 11012136                    None
# 11012137                    None
#
#                                            relative_results  \
# 0         [0x80dce9aec70a4ee9:0xc7cf24c90e4b537f, 0x80dc...
# 1         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 2         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 5         [0x54957451d00ee61b:0xe247a7cb0184f2e, 0x54957...
# 6         [0x54957451d00ee61b:0xe247a7cb0184f2e, 0x54957...
# ...                                                     ...
# 11012133  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012134  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012135  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012136  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012137  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 2         https://www.google.com/maps/place//data=!4m2!3...
# 5         https://www.google.com/maps/place//data=!4m2!3...
# 6         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 11012133  https://www.google.com/maps/place//data=!4m2!3...
# 11012134  https://www.google.com/maps/place//data=!4m2!3...
# 11012135  https://www.google.com/maps/place//data=!4m2!3...
# 11012136  https://www.google.com/maps/place//data=!4m2!3...
# 11012137  https://www.google.com/maps/place//data=!4m2!3...
#
# [6759906 rows x 22 columns]

# %%
#delete pics 
merged_df = merged_df.drop(columns = ['pics'])
merged_df
# Out:
#                user_id              name_x           time  rating  \
# 0         1.089908e+20     Richard Carroll  1604639688837     5.0
# 1         1.131780e+20     Matthew Schenck  1563021713865     5.0
# 2         1.089903e+20  Richard FranklinJr  1568391103458     5.0
# 5         1.089879e+20       Alan Martinez  1568530547167     5.0
# 6         1.060079e+20         Nicole Sime  1461891541675     5.0
# ...                ...                 ...            ...     ...
# 11012133  1.020084e+20         Liam Larsen  1563823527577     5.0
# 11012134  1.097044e+20         eileen lark  1535574173445     4.0
# 11012135  1.103217e+20      Eileen Collins  1537059253363     5.0
# 11012136  1.033860e+20     VRi Justin Marx  1495396947629     5.0
# 11012137  1.050566e+20      James McDaniel  1505344049376     5.0
#
#                                                        text  \
# 0         Fabulous food and amazing service.  Will be ba...
# 1         Great baked goods.  I recommend the cinnamon b...
# 2                                 Cinnamon buns are awesome
# 5                                Good people. Good workers.
# 6         The work they do at E & L unprecedented, the c...
# ...                                                     ...
# 11012133                                            fun fun
# 11012134                                 Very professional.
# 11012135                                     Great service!
# 11012136                                Use them every year
# 11012137  I look forward to rafting the Rogue River with...
#
#                                                        resp  \
# 0                                                      None
# 1         {'time': 1568392603217, 'text': 'Thank you so ...
# 2             {'time': 1568392542351, 'text': 'Thank you!'}
# 5                                                      None
# 6                                                      None
# ...                                                     ...
# 11012133                                               None
# 11012134                                               None
# 11012135                                               None
# 11012136                                               None
# 11012137                                               None
#
#                                         gmap_id  \
# 0         0x80dce9997c8d25fd:0xc6c81c1983060cbc
# 1          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 2          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 5         0x549576c32c7ce82d:0x166266dbfadf6660
# 6         0x549576c32c7ce82d:0x166266dbfadf6660
# ...                                         ...
# 11012133  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012134  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012135  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012136  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012137  0x54c5f293752506a3:0x89a72efa7aa6470c
#
#                                    name_y  \
# 0                       iPolish Nails Spa
# 1         Karens Country Confections, LLC
# 2         Karens Country Confections, LLC
# 5           E & L General Contractors Inc
# 6           E & L General Contractors Inc
# ...                                   ...
# 11012133           Rapid Pleasure Rafting
# 11012134           Rapid Pleasure Rafting
# 11012135           Rapid Pleasure Rafting
# 11012136           Rapid Pleasure Rafting
# 11012137           Rapid Pleasure Rafting
#
#                                                     address description  ...  \
# 0                                                      None        None  ...
# 1                                                      None        None  ...
# 2                                                      None        None  ...
# 5         E & L General Contractors Inc, 14161 S Redland...        None  ...
# 6         E & L General Contractors Inc, 14161 S Redland...        None  ...
# ...                                                     ...         ...  ...
# 11012133  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012134  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012135  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012136  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012137  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
#
#            longitude                             category avg_rating  \
# 0        -127.269699  [Nail salon, Service establishment]        5.0
# 1        -127.269639      [Bakery, Service establishment]        5.0
# 2        -127.269639      [Bakery, Service establishment]        5.0
# 5        -122.575448                [Concrete contractor]        5.0
# 6        -122.575448                [Concrete contractor]        5.0
# ...              ...                                  ...        ...
# 11012133 -122.812796                [Raft trip outfitter]        4.8
# 11012134 -122.812796                [Raft trip outfitter]        4.8
# 11012135 -122.812796                [Raft trip outfitter]        4.8
# 11012136 -122.812796                [Raft trip outfitter]        4.8
# 11012137 -122.812796                [Raft trip outfitter]        4.8
#
#           num_of_reviews  price  \
# 0                      2   None
# 1                      8   None
# 2                      8   None
# 5                     12   None
# 6                     12   None
# ...                  ...    ...
# 11012133              93   None
# 11012134              93   None
# 11012135              93   None
# 11012136              93   None
# 11012137              93   None
#
#                                                       hours  \
# 0         [[Thursday, 10AM–7PM], [Friday, 10AM–7PM], [Sa...
# 1         [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2         [[Thursday, Closed], [Friday, Closed], [Saturd...
# 5                                                      None
# 6                                                      None
# ...                                                     ...
# 11012133  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012134  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012135  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012136  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 11012137  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
#
#                                                        MISC  \
# 0             {'Payments': ['Debit cards', 'Credit cards']}
# 1                         {'Service options': ['Delivery']}
# 2                         {'Service options': ['Delivery']}
# 5                                                      None
# 6                                                      None
# ...                                                     ...
# 11012133  {'Accessibility': ['Wheelchair accessible entr...
# 11012134  {'Accessibility': ['Wheelchair accessible entr...
# 11012135  {'Accessibility': ['Wheelchair accessible entr...
# 11012136  {'Accessibility': ['Wheelchair accessible entr...
# 11012137  {'Accessibility': ['Wheelchair accessible entr...
#
#                            state  \
# 0              Open ⋅ Closes 7PM
# 1         Closed ⋅ Opens 9AM Sat
# 2         Closed ⋅ Opens 9AM Sat
# 5                           None
# 6                           None
# ...                          ...
# 11012133                    None
# 11012134                    None
# 11012135                    None
# 11012136                    None
# 11012137                    None
#
#                                            relative_results  \
# 0         [0x80dce9aec70a4ee9:0xc7cf24c90e4b537f, 0x80dc...
# 1         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 2         [0x89d0ac763567481b:0x90e7c3d44df486ce, 0x89d0...
# 5         [0x54957451d00ee61b:0xe247a7cb0184f2e, 0x54957...
# 6         [0x54957451d00ee61b:0xe247a7cb0184f2e, 0x54957...
# ...                                                     ...
# 11012133  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012134  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012135  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012136  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
# 11012137  [0x54c5f2c227a5e54b:0xefcceb861f34c220, 0x54c5...
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 2         https://www.google.com/maps/place//data=!4m2!3...
# 5         https://www.google.com/maps/place//data=!4m2!3...
# 6         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 11012133  https://www.google.com/maps/place//data=!4m2!3...
# 11012134  https://www.google.com/maps/place//data=!4m2!3...
# 11012135  https://www.google.com/maps/place//data=!4m2!3...
# 11012136  https://www.google.com/maps/place//data=!4m2!3...
# 11012137  https://www.google.com/maps/place//data=!4m2!3...
#
# [6759906 rows x 21 columns]

# %%
import ast

merged_df["category"] = merged_df["category"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Expand the list into separate columns
category_expanded = merged_df["category"].apply(pd.Series)

# Rename columns as 'category_1', 'category_2', etc.
category_expanded.columns = [f"category_{i+1}" for i in range(category_expanded.shape[1])]

# Concatenate with original dataset
merged_df = pd.concat([merged_df, category_expanded], axis=1)

# Drop original 'category' column
#cleaned_file.drop(columns=["category"], inplace=True)

merged_df
# Out:
#                user_id              name_x           time  rating  \
# 0         1.089908e+20     Richard Carroll  1604639688837     5.0
# 1         1.131780e+20     Matthew Schenck  1563021713865     5.0
# 2         1.089903e+20  Richard FranklinJr  1568391103458     5.0
# 5         1.089879e+20       Alan Martinez  1568530547167     5.0
# 6         1.060079e+20         Nicole Sime  1461891541675     5.0
# ...                ...                 ...            ...     ...
# 11012133  1.020084e+20         Liam Larsen  1563823527577     5.0
# 11012134  1.097044e+20         eileen lark  1535574173445     4.0
# 11012135  1.103217e+20      Eileen Collins  1537059253363     5.0
# 11012136  1.033860e+20     VRi Justin Marx  1495396947629     5.0
# 11012137  1.050566e+20      James McDaniel  1505344049376     5.0
#
#                                                        text  \
# 0         Fabulous food and amazing service.  Will be ba...
# 1         Great baked goods.  I recommend the cinnamon b...
# 2                                 Cinnamon buns are awesome
# 5                                Good people. Good workers.
# 6         The work they do at E & L unprecedented, the c...
# ...                                                     ...
# 11012133                                            fun fun
# 11012134                                 Very professional.
# 11012135                                     Great service!
# 11012136                                Use them every year
# 11012137  I look forward to rafting the Rogue River with...
#
#                                                        resp  \
# 0                                                      None
# 1         {'time': 1568392603217, 'text': 'Thank you so ...
# 2             {'time': 1568392542351, 'text': 'Thank you!'}
# 5                                                      None
# 6                                                      None
# ...                                                     ...
# 11012133                                               None
# 11012134                                               None
# 11012135                                               None
# 11012136                                               None
# 11012137                                               None
#
#                                         gmap_id  \
# 0         0x80dce9997c8d25fd:0xc6c81c1983060cbc
# 1          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 2          0x89d0ba60af135b2f:0xd548538d7a3e2b8
# 5         0x549576c32c7ce82d:0x166266dbfadf6660
# 6         0x549576c32c7ce82d:0x166266dbfadf6660
# ...                                         ...
# 11012133  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012134  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012135  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012136  0x54c5f293752506a3:0x89a72efa7aa6470c
# 11012137  0x54c5f293752506a3:0x89a72efa7aa6470c
#
#                                    name_y  \
# 0                       iPolish Nails Spa
# 1         Karens Country Confections, LLC
# 2         Karens Country Confections, LLC
# 5           E & L General Contractors Inc
# 6           E & L General Contractors Inc
# ...                                   ...
# 11012133           Rapid Pleasure Rafting
# 11012134           Rapid Pleasure Rafting
# 11012135           Rapid Pleasure Rafting
# 11012136           Rapid Pleasure Rafting
# 11012137           Rapid Pleasure Rafting
#
#                                                     address description  ...  \
# 0                                                      None        None  ...
# 1                                                      None        None  ...
# 2                                                      None        None  ...
# 5         E & L General Contractors Inc, 14161 S Redland...        None  ...
# 6         E & L General Contractors Inc, 14161 S Redland...        None  ...
# ...                                                     ...         ...  ...
# 11012133  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012134  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012135  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012136  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
# 11012137  Rapid Pleasure Rafting, 125 Chaparral Dr, Shad...        None  ...
#
#           category_12  category_13 category_14  category_15  category_16  \
# 0                 NaN          NaN         NaN          NaN          NaN
# 1                 NaN          NaN         NaN          NaN          NaN
# 2                 NaN          NaN         NaN          NaN          NaN
# 5                 NaN          NaN         NaN          NaN          NaN
# 6                 NaN          NaN         NaN          NaN          NaN
# ...               ...          ...         ...          ...          ...
# 11012133          NaN          NaN         NaN          NaN          NaN
# 11012134          NaN          NaN         NaN          NaN          NaN
# 11012135          NaN          NaN         NaN          NaN          NaN
# 11012136          NaN          NaN         NaN          NaN          NaN
# 11012137          NaN          NaN         NaN          NaN          NaN
#
#          category_17 category_18 category_19 category_20 category_21
# 0                NaN         NaN         NaN         NaN         NaN
# 1                NaN         NaN         NaN         NaN         NaN
# 2                NaN         NaN         NaN         NaN         NaN
# 5                NaN         NaN         NaN         NaN         NaN
# 6                NaN         NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...         ...
# 11012133         NaN         NaN         NaN         NaN         NaN
# 11012134         NaN         NaN         NaN         NaN         NaN
# 11012135         NaN         NaN         NaN         NaN         NaN
# 11012136         NaN         NaN         NaN         NaN         NaN
# 11012137         NaN         NaN         NaN         NaN         NaN
#
# [6759906 rows x 42 columns]

# %%
import re

from tqdm import tqdm
tqdm.pandas()

healthcare_categories = {
    "medical clinic", "women's health clinic", "home health care service", "internist", "allergist",
    "diabetes center", "doctor", "family practice physician", "optometrist", "pharmacy", "dentist",
    "medical supply store", "orthopedic surgeon", "surgeon", "psychotherapist", "dental clinic",
    "orthodontist", "physical therapist", "chiropractor", "hospital", "sleep clinic", "optician",
    "cancer treatment center", "medical center", "physical therapy clinic", "medical laboratory",
    "public health department", "psychologist", "radiologist", "podiatrist", "nursing home",
    "medical group", "x-ray lab", "dermatologist", "pediatrician", "massage therapist",
    "periodontist", "obstetrician-gynecologist", "sports medicine clinic", "psychiatric hospital",
    "orthotics & prosthetics service", "physical fitness program", "ophthalmologist", "hospice",
    "retirement home", "rehabilitation center", "pediatric dentist", "teeth whitening service",
    "dental hygienist", "endodontist", "dental implants periodontist", "cosmetic dentist",
    "emergency dental service", "urgent care center", "wellness center", "walk-in clinic",
    "general practitioner", "children's hospital", "mental health clinic", "otolaryngologist", "eye care center", 
    "ophthalmology clinic","lasik surgeon","blood donation center" ,
    "Addiction treatment center","denture care center","gym","fitness center","personal trainer", 
    "Psychiatrist", "Drug store","Vitamin & supplements store","weight loss service",
    "Pulmonologist","gymnastics center", "oral surgeon","Oral and maxillofacial surgeon","homeless service",
     "Alcoholism treatment program", "Homeless shelter", "child care agency","day care center",
     "Neurosurgeon","Vascular surgeon", "Cardiologist", "Laboratory", "Specialized clinic",
     "contact lenses supplier","massage spa","Reflexologist", "Rheumatologist", "Surgical center",
     "Mental health service", "Eating disorder treatment center", "Hair removal service", 
     "Skin care clinic","foot care","laser hair removal service","spa","medical spa",
     "sports nutrition store","pain control clinic","audiologist","plastic surgeon","pathologist",
     "Pediatric cardiologist","Sports medicine physician","Medical equipment supplier","nurse practitioner",
     "Counselor", "Family counselor", "Marriage or relationship counselor","facial spa",
     "Occupational medical physician","Urologist","Nephrologist","Endocrinologist",
     "Alternative medicine practitioner", "Holistic medicine practitioner",
     "health","massage","Dialysis center", "Local medical services", 
     "hand surgeon","Gastroenterologist","Thai massage therapist","Hearing aid store", "Hearing aid repair service"
                                        
}
# Function to check if a business belongs to the healthcare category
def classify_healthcare(row):
    for i in range(1, 16):  # Assuming category_1 to category_15 exist
        category_col = f"category_{i}"
        if category_col in row and isinstance(row[category_col], str):  # Check if column exists and is a string
            for keyword in healthcare_categories:
                if re.search(rf"\b{keyword}\b", row[category_col], re.IGNORECASE):  # Match whole word
                    return "Healthcare"  # Assign healthcare label
    return "Other"  # Default category if no match

# Apply the function to create a new 'general_labelling' column
merged_df["general_labelling"] = merged_df.progress_apply(classify_healthcare, axis=1)
# Out:
# 100%|██████████| 6759906/6759906 [4:24:27<00:00, 426.02it/s]

# %%
# Filter records where 'general_labelling' is "Healthcare"
healthcare_dataset = merged_df[merged_df["general_labelling"] == "Healthcare"]

# %%
oregon_healthcare_dataset_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/oregon_healthcare_dataset.csv"

# %%
healthcare_dataset.to_csv(oregon_healthcare_dataset_path, index=False)

# %%
import pandas as pd
path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/oregon_healthcare_dataset.csv"
mass_df = pd.read_csv(path)
mass_df
# Out:
# C:\Users\eliza\AppData\Local\Temp\ipykernel_17448\71254673.py:3: DtypeWarning: Columns (18,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   mass_df = pd.read_csv(path)
#              user_id                      name_x           time  rating  \
# 0       1.123041e+20  Jaclyn McNabb-Langenwalter  1622668354810     5.0
# 1       1.073113e+20               Stover sports  1613508017173     5.0
# 2       1.051374e+20            Hannah Paysinger  1627848050851     1.0
# 3       1.089858e+20            Melissa Andersen  1606952544980     5.0
# 4       1.162386e+20                   Mike Alan  1607013385211     5.0
# ...              ...                         ...            ...     ...
# 394371  1.048103e+20          Floyd Mccorvey Jr.  1544062875489     5.0
# 394372  1.021208e+20                Aurora Clair  1507251386620     4.0
# 394373  1.073306e+20                  הוד אשכנזי  1520471569967     3.0
# 394374  1.125588e+20                   Mike Lamb  1500434216365     5.0
# 394375  1.063719e+20             Steven J Grundy  1506199032139     5.0
#
#                                                      text  \
# 0       Dr. McDonald and staff are the friendliest and...
# 1       This is the best orthodontics place in Salem w...
# 2       0 stars. I visited Dr McDonald for a consult i...
# 3       Can you love your orthodontist?  Um yes - we d...
# 4       Every staff member in this office is absolutel...
# ...                                                   ...
# 394371  (Translated by Google) THE BOOOOOMB\n\n(Origin...
# 394372    (Translated by Google) 82nd\n\n(Original)\n82nd
# 394373  (Translated by Google) Lacks a lot of products...
# 394374  (Translated by Google) Always love TJs!\n\n(Or...
# 394375  (Translated by Google) Love TJs!\n\n(Original)...
#
#                                                      resp  \
# 0       {'time': 1628046711072, 'text': 'Thanks Jaclyn...
# 1       {'time': 1613790051777, 'text': 'Thanks Jack, ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 394371                                                NaN
# 394372                                                NaN
# 394373                                                NaN
# 394374                                                NaN
# 394375                                                NaN
#
#                                       gmap_id                 name_y  \
# 0       0x54bfff5952aad583:0xad7afdc825730614  McDonald Orthodontics
# 1       0x54bfff5952aad583:0xad7afdc825730614  McDonald Orthodontics
# 2       0x54bfff5952aad583:0xad7afdc825730614  McDonald Orthodontics
# 3       0x54bfff5952aad583:0xad7afdc825730614  McDonald Orthodontics
# 4       0x54bfff5952aad583:0xad7afdc825730614  McDonald Orthodontics
# ...                                       ...                    ...
# 394371  0x54959fe0f868d65b:0xe98e05b308939807           Trader Joe's
# 394372  0x54959fe0f868d65b:0xe98e05b308939807           Trader Joe's
# 394373  0x54959fe0f868d65b:0xe98e05b308939807           Trader Joe's
# 394374  0x54959fe0f868d65b:0xe98e05b308939807           Trader Joe's
# 394375  0x54959fe0f868d65b:0xe98e05b308939807           Trader Joe's
#
#                                                   address  \
# 0       McDonald Orthodontics, 1855 W Nob Hill St SE #...
# 1       McDonald Orthodontics, 1855 W Nob Hill St SE #...
# 2       McDonald Orthodontics, 1855 W Nob Hill St SE #...
# 3       McDonald Orthodontics, 1855 W Nob Hill St SE #...
# 4       McDonald Orthodontics, 1855 W Nob Hill St SE #...
# ...                                                   ...
# 394371  Trader Joe's, 9345 SE 82nd Ave, Clackamas, OR ...
# 394372  Trader Joe's, 9345 SE 82nd Ave, Clackamas, OR ...
# 394373  Trader Joe's, 9345 SE 82nd Ave, Clackamas, OR ...
# 394374  Trader Joe's, 9345 SE 82nd Ave, Clackamas, OR ...
# 394375  Trader Joe's, 9345 SE 82nd Ave, Clackamas, OR ...
#
#                                               description  ...  category_13  \
# 0                                                     NaN  ...          NaN
# 1                                                     NaN  ...          NaN
# 2                                                     NaN  ...          NaN
# 3                                                     NaN  ...          NaN
# 4                                                     NaN  ...          NaN
# ...                                                   ...  ...          ...
# 394371  Grocery chain with a variety of signature item...  ...          NaN
# 394372  Grocery chain with a variety of signature item...  ...          NaN
# 394373  Grocery chain with a variety of signature item...  ...          NaN
# 394374  Grocery chain with a variety of signature item...  ...          NaN
# 394375  Grocery chain with a variety of signature item...  ...          NaN
#
#         category_14 category_15  category_16  category_17 category_18  \
# 0               NaN         NaN          NaN          NaN         NaN
# 1               NaN         NaN          NaN          NaN         NaN
# 2               NaN         NaN          NaN          NaN         NaN
# 3               NaN         NaN          NaN          NaN         NaN
# 4               NaN         NaN          NaN          NaN         NaN
# ...             ...         ...          ...          ...         ...
# 394371          NaN         NaN          NaN          NaN         NaN
# 394372          NaN         NaN          NaN          NaN         NaN
# 394373          NaN         NaN          NaN          NaN         NaN
# 394374          NaN         NaN          NaN          NaN         NaN
# 394375          NaN         NaN          NaN          NaN         NaN
#
#        category_19 category_20 category_21 general_labelling
# 0              NaN         NaN         NaN        Healthcare
# 1              NaN         NaN         NaN        Healthcare
# 2              NaN         NaN         NaN        Healthcare
# 3              NaN         NaN         NaN        Healthcare
# 4              NaN         NaN         NaN        Healthcare
# ...            ...         ...         ...               ...
# 394371         NaN         NaN         NaN        Healthcare
# 394372         NaN         NaN         NaN        Healthcare
# 394373         NaN         NaN         NaN        Healthcare
# 394374         NaN         NaN         NaN        Healthcare
# 394375         NaN         NaN         NaN        Healthcare
#
# [394376 rows x 43 columns]
