# %%
import pandas as pd

# %%
review_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/MassReview/review-Massachusetts.json"
review_df = pd.read_json(review_path, lines = True)
review_df
# Out:
#                user_id                 name           time  rating  \
# 0         1.089901e+20         Sherri Mayne  1559246854759     5.0
# 1         1.004254e+20       Adam Goodspeed  1557586283214     5.0
# 2         1.181979e+20  Christopher Sheehan  1568756947956     4.0
# 3         1.063415e+20       Katie Sullivan  1627234799114     5.0
# 4         1.024727e+20   Victoria Henderson  1619237055452     5.0
# ...                ...                  ...            ...     ...
# 10447002  1.105138e+20         Bear Gibbons  1502743686863     4.0
# 10447003  1.183557e+20        Matthew Russo  1503950061831     4.0
# 10447004  1.038805e+20              Maurice  1557424640767     5.0
# 10447005  1.084579e+20        Grant Randall  1501386851236     5.0
# 10447006  1.178361e+20      Janet Patenaude  1505644484442     5.0
#
#                                                        text  pics  resp  \
# 0         I love the people that live there, they ate th...  None  None
# 1         Stop parking in the residents spots for your d...  None  None
# 2                                                      None  None  None
# 3         Everytime I visit this $1000000. Boutique I am...  None  None
# 4         These people who do this are so special! They ...  None  None
# ...                                                     ...   ...   ...
# 10447002                                               None  None  None
# 10447003                                               None  None  None
# 10447004                                               None  None  None
# 10447005                                               None  None  None
# 10447006                                               None  None  None
#
#                                         gmap_id
# 0         0x89e4a1f2d39fb621:0xfe62e9b7266e6262
# 1         0x89e4a1f2d39fb621:0xfe62e9b7266e6262
# 2         0x89e4a1f2d39fb621:0xfe62e9b7266e6262
# 3         0x89e4a103dd188585:0xfadc47938337579f
# 4         0x89e4a103dd188585:0xfadc47938337579f
# ...                                         ...
# 10447002   0x879352bc8c0d42d1:0x23be3bed0e7f707
# 10447003   0x879352bc8c0d42d1:0x23be3bed0e7f707
# 10447004   0x879352bc8c0d42d1:0x23be3bed0e7f707
# 10447005   0x879352bc8c0d42d1:0x23be3bed0e7f707
# 10447006   0x879352bc8c0d42d1:0x23be3bed0e7f707
#
# [10447007 rows x 8 columns]

# %%
business_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/MassMeta/meta-Massachusetts.json"
business_df = pd.read_json(business_path, lines = True)
business_df
# Out:
#                                name  \
# 0        Grace Ryder Housing Center
# 1                      Sowing Seeds
# 2                       TLC Kennels
# 3           Pine Hill Sand & Gravel
# 4                      Workout Club
# ...                             ...
# 92515             Harbor View Hotel
# 92516  Prime Volvo Cars South Shore
# 92517            Georgetown Cupcake
# 92518        Angie's Food and Diner
# 92519       The Braemar Condominium
#
#                                                  address  \
# 0       Grace Ryder Housing Center, Marshfield, MA 02050
# 1       Sowing Seeds, 974 Plain St, Marshfield, MA 02050
# 2         TLC Kennels, 729 Center St, Pembroke, MA 02359
# 3      Pine Hill Sand & Gravel, 498 Old Westport Rd, ...
# 4      Workout Club, Webster Square, Marshfield, MA 0...
# ...                                                  ...
# 92515  Harbor View Hotel, 131 N Water St, Edgartown, ...
# 92516  Prime Volvo Cars South Shore, 1030 Hingham St,...
# 92517  Georgetown Cupcake, 83 Newbury St, Boston, MA ...
# 92518  Angie's Food and Diner, 7 Pleasant St, Newbury...
# 92519  The Braemar Condominium, 132 Shore Rd, North T...
#
#                                      gmap_id  \
# 0      0x89e4a1f2d39fb621:0xfe62e9b7266e6262
# 1      0x89e4a103dd188585:0xfadc47938337579f
# 2      0x89e49871023b3407:0xd93aabe6f7940a6b
# 3       0x89e4fcdcfa2fdba5:0xb10b326e00a0fd0
# 4       0x89e4a6c554aa0e59:0x45965ec598f57a3
# ...                                      ...
# 92515  0x89e52c3b7239e4f3:0x7bfe679ba2b6515a
# 92516  0x89e49e1e3393104b:0x312bf38270669fb9
# 92517   0x89e37a0b3ef49579:0x90bfa78934b0070
# 92518  0x89e2e1309f594689:0xe96ac3e0619228e0
# 92519   0x879352bc8c0d42d1:0x23be3bed0e7f707
#
#                                              description   latitude  \
# 0                                                   None  42.098673
# 1                                                   None  42.107184
# 2                                                   None  42.032471
# 3                                                   None  41.626680
# 4                                                   None  42.089767
# ...                                                  ...        ...
# 92515  Individually styled rooms in a waterfront 19th...  41.392496
# 92516                                               None  42.164748
# 92517  An extensive menu of imaginative cupcakes is t...  42.351854
# 92518  Family-owned fixture turning out homemade comf...  42.809837
# 92519                                               None  42.042705
#
#        longitude                                           category  \
# 0     -70.719751                            [Senior citizen center]
# 1     -70.757536                          [Non-profit organization]
# 2     -70.820770                                           [Kennel]
# 3     -71.022437                           [Sand & gravel supplier]
# 4     -70.708462                                              [Gym]
# ...          ...                                                ...
# 92515 -70.506566  [Hotel, Event venue, Resort hotel, Wedding venue]
# 92516 -70.898953                      [Car dealer, Used car dealer]
# 92517 -71.074840                                           [Bakery]
# 92518 -70.870880                                            [Diner]
# 92519 -70.099689                                     [Resort hotel]
#
#        avg_rating  num_of_reviews price  \
# 0             4.8               3  None
# 1             4.6               8  None
# 2             4.0               4  None
# 3             5.0               2  None
# 4             4.5               4  None
# ...           ...             ...   ...
# 92515         4.4             448  None
# 92516         4.6             438  None
# 92517         4.5             768    $$
# 92518         4.4             277     $
# 92519         4.4              78  None
#
#                                                    hours  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      [[Thursday, 5:30AM–1PM], [Friday, 5:30AM–1PM],...
# ...                                                  ...
# 92515                                               None
# 92516  [[Thursday, 9AM–7PM], [Friday, 9AM–6PM], [Satu...
# 92517  [[Thursday, 10AM–7PM], [Friday, 10AM–7PM], [Sa...
# 92518  [[Wednesday, 7AM–3PM], [Thursday, 7AM–3PM], [F...
# 92519                                               None
#
#                                                     MISC  \
# 0      {'Accessibility': ['Wheelchair accessible entr...
# 1      {'Accessibility': ['Wheelchair accessible entr...
# 2                                                   None
# 3                                                   None
# 4      {'Accessibility': ['Wheelchair accessible entr...
# ...                                                  ...
# 92515                                               None
# 92516  {'Service options': ['In-store shopping'], 'Of...
# 92517  {'Service options': ['Delivery', 'In-store pic...
# 92518  {'Service options': ['Curbside pickup', 'Deliv...
# 92519                                               None
#
#                                  state  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4      Closes soon ⋅ 1PM ⋅ Reopens 4PM
# ...                                ...
# 92515                              NaN
# 92516                              NaN
# 92517                              NaN
# 92518                              NaN
# 92519                              NaN
#
#                                         relative_results  \
# 0      [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 1      [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 2      [0x89e4a1c4b9d12e9b:0xc13185ea1dbed01a, 0x89e4...
# 3      [0x89e4fd3555b4674f:0x6d70e26b40185165, 0x89e4...
# 4      [0x89e4a6d001adbf99:0xdeb84714d054a18c, 0x89e4...
# ...                                                  ...
# 92515                                               None
# 92516  [0x89e379cc56178d2b:0x2ad26514437c4cb5, 0x89e3...
# 92517  [0x89e37bca0eea3765:0xdbafe4b43007b8d0, 0x89e3...
# 92518  [0x89e2e10b76cd6deb:0x5649f4f4df0f388b, 0x89e2...
# 92519                                               None
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 92515  https://www.google.com/maps/place//data=!4m2!3...
# 92516  https://www.google.com/maps/place//data=!4m2!3...
# 92517  https://www.google.com/maps/place//data=!4m2!3...
# 92518  https://www.google.com/maps/place//data=!4m2!3...
# 92519  https://www.google.com/maps/place//data=!4m2!3...
#
# [92520 rows x 15 columns]

# %%
# Aggregate business metadata by gmap_id before merging
business_agg = business_df.groupby("gmap_id", as_index=False).agg({
    "name": "first",  # Keep first occurrence (assumes same name per gmap_id)
    "address": "first",
    "description": "first",
    "latitude": "first",
    "longitude": "first",
    "category": lambda x: list(set(x.sum())) if x.apply(lambda v: isinstance(v, list)).any() else list(set(x)),
    "avg_rating": "mean",  # Use mean rating if multiple exist
    "num_of_reviews": "sum",
    "price": "first",
    "hours": "first",
    "MISC": "first",
    "state": "first",
    "relative_results": "first",
    "url": "first"
})

# Check if aggregation worked
print(business_agg.head())
# Out:
#                                  gmap_id                       name  \
# 0                 0x0:0x543245e44ddcd0fe              Panda Express
# 1   0x241c5fb4ec3be563:0x16d62b6ea926d21  Riggs Plumbing & Hvac LLC
# 2   0x405b8a1897d25455:0x67ee17cf7dff7a0  495 Mazda Service & Parts
# 3  0x405b8a18c164a235:0xb686becc805a5153             The Essex Room
# 4  0x405b8a1cbf09a0c5:0xfebb68a0522ae95d              Rainbow Shack
#
#                                              address  \
# 0  Panda Express, 775 Commonwealth Avenue, Boston...
# 1                                               None
# 2  495 Mazda Service & Parts, 720 Rogers St, Lowe...
# 3       The Essex Room, 125 Main St, Essex, MA 01929
# 4       Rainbow Shack, 85 Summer St, Adams, MA 01220
#
#                                          description   latitude  longitude  \
# 0  Fast-food chain for Chinese standards, includi...  42.350918 -71.108951
# 1                                               None  42.208122 -70.938240
# 2                                               None  42.631115 -71.279162
# 3                                               None  42.628741 -70.774376
# 4                                               None  42.623653 -73.113515
#
#                                             category  avg_rating  \
# 0  [Fast food restaurant, Takeout Restaurant, Chi...         3.9
# 1  [Service establishment, Plumber, HVAC contractor]         5.0
# 2  [Auto tune up service, Tire shop, Oil change s...         4.9
# 3                       [Event venue, Wedding venue]         4.7
# 4                     [Dessert shop, Ice cream shop]         4.8
#
#    num_of_reviews price                                              hours  \
# 0              88     $  [[Sunday, Closed], [Monday, 9AM–5PM], [Tuesday...
# 1              15  None  [[Monday, 8AM–4:30PM], [Tuesday, 8AM–4:30PM], ...
# 2               8  None  [[Sunday, Closed], [Monday, 8AM–7PM], [Tuesday...
# 3              16  None  [[Sunday, Closed], [Monday, 9AM–5PM], [Tuesday...
# 4              78     $  [[Friday, 4–9PM], [Saturday, 4–9PM], [Sunday, ...
#
#                                                 MISC                   state  \
# 0  {'Service options': ['Takeout', 'Dine-in'], 'P...  Closed ⋅ Opens 9AM Mon
# 1                                               None  Closed ⋅ Opens 8AM Tue
# 2  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 8AM Mon
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 9AM Mon
# 4  {'Service options': ['Takeout', 'Delivery'], '...      Closed ⋅ Opens 4PM
#
#                                     relative_results  \
# 0  [0x89e379f0ac75b559:0x99377682f52cc931, 0x89e3...
# 1                                               None
# 2  [0x89e30ceae62b0d9b:0xa3dbd07e151f5919, 0x89e3...
# 3  [0x89e3167aafcd0143:0x46687fc93ee60443, 0x89e3...
# 4  [0x89e0b81622080295:0x9e049dfff863ae3b, 0x89e0...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Merge with aggregated business data
merged_df = review_df.merge(business_agg, on="gmap_id", how="left")
merged_df
# Out:
#                user_id               name_x           time  rating  \
# 0         1.089901e+20         Sherri Mayne  1559246854759     5.0
# 1         1.004254e+20       Adam Goodspeed  1557586283214     5.0
# 2         1.181979e+20  Christopher Sheehan  1568756947956     4.0
# 3         1.063415e+20       Katie Sullivan  1627234799114     5.0
# 4         1.024727e+20   Victoria Henderson  1619237055452     5.0
# ...                ...                  ...            ...     ...
# 10447002  1.105138e+20         Bear Gibbons  1502743686863     4.0
# 10447003  1.183557e+20        Matthew Russo  1503950061831     4.0
# 10447004  1.038805e+20              Maurice  1557424640767     5.0
# 10447005  1.084579e+20        Grant Randall  1501386851236     5.0
# 10447006  1.178361e+20      Janet Patenaude  1505644484442     5.0
#
#                                                        text  pics  resp  \
# 0         I love the people that live there, they ate th...  None  None
# 1         Stop parking in the residents spots for your d...  None  None
# 2                                                      None  None  None
# 3         Everytime I visit this $1000000. Boutique I am...  None  None
# 4         These people who do this are so special! They ...  None  None
# ...                                                     ...   ...   ...
# 10447002                                               None  None  None
# 10447003                                               None  None  None
# 10447004                                               None  None  None
# 10447005                                               None  None  None
# 10447006                                               None  None  None
#
#                                         gmap_id                      name_y  \
# 0         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 1         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 2         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 3         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 4         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# ...                                         ...                         ...
# 10447002   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10447003   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10447004   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10447005   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10447006   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
#
#                                                     address  ...  longitude  \
# 0          Grace Ryder Housing Center, Marshfield, MA 02050  ... -70.719751
# 1          Grace Ryder Housing Center, Marshfield, MA 02050  ... -70.719751
# 2          Grace Ryder Housing Center, Marshfield, MA 02050  ... -70.719751
# 3          Sowing Seeds, 974 Plain St, Marshfield, MA 02050  ... -70.757536
# 4          Sowing Seeds, 974 Plain St, Marshfield, MA 02050  ... -70.757536
# ...                                                     ...  ...        ...
# 10447002  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10447003  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10447004  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10447005  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10447006  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
#
#                            category  avg_rating num_of_reviews  price  hours  \
# 0           [Senior citizen center]         4.8              6   None   None
# 1           [Senior citizen center]         4.8              6   None   None
# 2           [Senior citizen center]         4.8              6   None   None
# 3         [Non-profit organization]         4.6             16   None   None
# 4         [Non-profit organization]         4.6             16   None   None
# ...                             ...         ...            ...    ...    ...
# 10447002             [Resort hotel]         4.4             78   None   None
# 10447003             [Resort hotel]         4.4             78   None   None
# 10447004             [Resort hotel]         4.4             78   None   None
# 10447005             [Resort hotel]         4.4             78   None   None
# 10447006             [Resort hotel]         4.4             78   None   None
#
#                                                        MISC state  \
# 0         {'Accessibility': ['Wheelchair accessible entr...  None
# 1         {'Accessibility': ['Wheelchair accessible entr...  None
# 2         {'Accessibility': ['Wheelchair accessible entr...  None
# 3         {'Accessibility': ['Wheelchair accessible entr...  None
# 4         {'Accessibility': ['Wheelchair accessible entr...  None
# ...                                                     ...   ...
# 10447002                                               None  None
# 10447003                                               None  None
# 10447004                                               None  None
# 10447005                                               None  None
# 10447006                                               None  None
#
#                                            relative_results  \
# 0         [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 1         [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 2         [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 3         [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 4         [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# ...                                                     ...
# 10447002                                               None
# 10447003                                               None
# 10447004                                               None
# 10447005                                               None
# 10447006                                               None
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 2         https://www.google.com/maps/place//data=!4m2!3...
# 3         https://www.google.com/maps/place//data=!4m2!3...
# 4         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 10447002  https://www.google.com/maps/place//data=!4m2!3...
# 10447003  https://www.google.com/maps/place//data=!4m2!3...
# 10447004  https://www.google.com/maps/place//data=!4m2!3...
# 10447005  https://www.google.com/maps/place//data=!4m2!3...
# 10447006  https://www.google.com/maps/place//data=!4m2!3...
#
# [10447007 rows x 22 columns]

# %%
unmatched = review_df[~review_df['gmap_id'].isin(business_agg['gmap_id'])]
print(f"Unmatched rows: {len(unmatched)}")
print("Unique gmap_id in review_df:", review_df['gmap_id'].nunique())
print("Unique gmap_id in business_agg:", business_agg['gmap_id'].nunique())
# Out:
# Unmatched rows: 0
# Unique gmap_id in review_df: 91896
# Unique gmap_id in business_agg: 91896

# %%
#check if null values in 'text' column exist
print(merged_df['text'].isna().sum())
# Out:
# 4650780

# %%
#remove rows/records where 'text' is null
merged_df = merged_df.dropna(subset = ['text'])
merged_df
# Out:
#                user_id                  name_x           time  rating  \
# 0         1.089901e+20            Sherri Mayne  1559246854759     5.0
# 1         1.004254e+20          Adam Goodspeed  1557586283214     5.0
# 3         1.063415e+20          Katie Sullivan  1627234799114     5.0
# 4         1.024727e+20      Victoria Henderson  1619237055452     5.0
# 5         1.180340e+20           Donna Carlson  1619732714443     5.0
# ...                ...                     ...            ...     ...
# 10446973  1.084896e+20  Barbara Gatens-Pursell  1502224277318     3.0
# 10446974  1.039721e+20           Marcel Brants  1563068387459     3.0
# 10446975  1.030453e+20                  Andrea  1534216707086     4.0
# 10446976  1.076849e+20          Guido Hermanns  1530103982634     5.0
# 10446977  1.069805e+20           Marcel Vachon  1534161873445     5.0
#
#                                                        text  pics  resp  \
# 0         I love the people that live there, they ate th...  None  None
# 1         Stop parking in the residents spots for your d...  None  None
# 3         Everytime I visit this $1000000. Boutique I am...  None  None
# 4         These people who do this are so special! They ...  None  None
# 5               People run it make sure you are comfortable  None  None
# ...                                                     ...   ...   ...
# 10446973                        Average...a little rundown.  None  None
# 10446974  (Translated by Google) Fair to good holiday st...  None  None
# 10446975  (Translated by Google) A good solution to stay...  None  None
# 10446976  (Translated by Google) The Braemar is an owner...  None  None
# 10446977  (Translated by Google) Clean, lack of anything...  None  None
#
#                                         gmap_id                      name_y  \
# 0         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 1         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 3         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 4         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 5         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# ...                                         ...                         ...
# 10446973   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446974   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446975   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446976   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446977   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
#
#                                                     address  ...  longitude  \
# 0          Grace Ryder Housing Center, Marshfield, MA 02050  ... -70.719751
# 1          Grace Ryder Housing Center, Marshfield, MA 02050  ... -70.719751
# 3          Sowing Seeds, 974 Plain St, Marshfield, MA 02050  ... -70.757536
# 4          Sowing Seeds, 974 Plain St, Marshfield, MA 02050  ... -70.757536
# 5          Sowing Seeds, 974 Plain St, Marshfield, MA 02050  ... -70.757536
# ...                                                     ...  ...        ...
# 10446973  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10446974  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10446975  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10446976  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
# 10446977  The Braemar Condominium, 132 Shore Rd, North T...  ... -70.099689
#
#                            category  avg_rating num_of_reviews  price  hours  \
# 0           [Senior citizen center]         4.8              6   None   None
# 1           [Senior citizen center]         4.8              6   None   None
# 3         [Non-profit organization]         4.6             16   None   None
# 4         [Non-profit organization]         4.6             16   None   None
# 5         [Non-profit organization]         4.6             16   None   None
# ...                             ...         ...            ...    ...    ...
# 10446973             [Resort hotel]         4.4             78   None   None
# 10446974             [Resort hotel]         4.4             78   None   None
# 10446975             [Resort hotel]         4.4             78   None   None
# 10446976             [Resort hotel]         4.4             78   None   None
# 10446977             [Resort hotel]         4.4             78   None   None
#
#                                                        MISC state  \
# 0         {'Accessibility': ['Wheelchair accessible entr...  None
# 1         {'Accessibility': ['Wheelchair accessible entr...  None
# 3         {'Accessibility': ['Wheelchair accessible entr...  None
# 4         {'Accessibility': ['Wheelchair accessible entr...  None
# 5         {'Accessibility': ['Wheelchair accessible entr...  None
# ...                                                     ...   ...
# 10446973                                               None  None
# 10446974                                               None  None
# 10446975                                               None  None
# 10446976                                               None  None
# 10446977                                               None  None
#
#                                            relative_results  \
# 0         [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 1         [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 3         [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 4         [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 5         [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# ...                                                     ...
# 10446973                                               None
# 10446974                                               None
# 10446975                                               None
# 10446976                                               None
# 10446977                                               None
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 3         https://www.google.com/maps/place//data=!4m2!3...
# 4         https://www.google.com/maps/place//data=!4m2!3...
# 5         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 10446973  https://www.google.com/maps/place//data=!4m2!3...
# 10446974  https://www.google.com/maps/place//data=!4m2!3...
# 10446975  https://www.google.com/maps/place//data=!4m2!3...
# 10446976  https://www.google.com/maps/place//data=!4m2!3...
# 10446977  https://www.google.com/maps/place//data=!4m2!3...
#
# [5796227 rows x 22 columns]

# %%
#delete pics 
merged_df = merged_df.drop(columns = ['pics'])
merged_df
# Out:
#                user_id                  name_x           time  rating  \
# 0         1.089901e+20            Sherri Mayne  1559246854759     5.0
# 1         1.004254e+20          Adam Goodspeed  1557586283214     5.0
# 3         1.063415e+20          Katie Sullivan  1627234799114     5.0
# 4         1.024727e+20      Victoria Henderson  1619237055452     5.0
# 5         1.180340e+20           Donna Carlson  1619732714443     5.0
# ...                ...                     ...            ...     ...
# 10446973  1.084896e+20  Barbara Gatens-Pursell  1502224277318     3.0
# 10446974  1.039721e+20           Marcel Brants  1563068387459     3.0
# 10446975  1.030453e+20                  Andrea  1534216707086     4.0
# 10446976  1.076849e+20          Guido Hermanns  1530103982634     5.0
# 10446977  1.069805e+20           Marcel Vachon  1534161873445     5.0
#
#                                                        text  resp  \
# 0         I love the people that live there, they ate th...  None
# 1         Stop parking in the residents spots for your d...  None
# 3         Everytime I visit this $1000000. Boutique I am...  None
# 4         These people who do this are so special! They ...  None
# 5               People run it make sure you are comfortable  None
# ...                                                     ...   ...
# 10446973                        Average...a little rundown.  None
# 10446974  (Translated by Google) Fair to good holiday st...  None
# 10446975  (Translated by Google) A good solution to stay...  None
# 10446976  (Translated by Google) The Braemar is an owner...  None
# 10446977  (Translated by Google) Clean, lack of anything...  None
#
#                                         gmap_id                      name_y  \
# 0         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 1         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 3         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 4         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 5         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# ...                                         ...                         ...
# 10446973   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446974   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446975   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446976   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446977   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
#
#                                                     address description  ...  \
# 0          Grace Ryder Housing Center, Marshfield, MA 02050        None  ...
# 1          Grace Ryder Housing Center, Marshfield, MA 02050        None  ...
# 3          Sowing Seeds, 974 Plain St, Marshfield, MA 02050        None  ...
# 4          Sowing Seeds, 974 Plain St, Marshfield, MA 02050        None  ...
# 5          Sowing Seeds, 974 Plain St, Marshfield, MA 02050        None  ...
# ...                                                     ...         ...  ...
# 10446973  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446974  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446975  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446976  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446977  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
#
#           longitude                   category avg_rating  num_of_reviews  \
# 0        -70.719751    [Senior citizen center]        4.8               6
# 1        -70.719751    [Senior citizen center]        4.8               6
# 3        -70.757536  [Non-profit organization]        4.6              16
# 4        -70.757536  [Non-profit organization]        4.6              16
# 5        -70.757536  [Non-profit organization]        4.6              16
# ...             ...                        ...        ...             ...
# 10446973 -70.099689             [Resort hotel]        4.4              78
# 10446974 -70.099689             [Resort hotel]        4.4              78
# 10446975 -70.099689             [Resort hotel]        4.4              78
# 10446976 -70.099689             [Resort hotel]        4.4              78
# 10446977 -70.099689             [Resort hotel]        4.4              78
#
#           price hours                                               MISC  \
# 0          None  None  {'Accessibility': ['Wheelchair accessible entr...
# 1          None  None  {'Accessibility': ['Wheelchair accessible entr...
# 3          None  None  {'Accessibility': ['Wheelchair accessible entr...
# 4          None  None  {'Accessibility': ['Wheelchair accessible entr...
# 5          None  None  {'Accessibility': ['Wheelchair accessible entr...
# ...         ...   ...                                                ...
# 10446973   None  None                                               None
# 10446974   None  None                                               None
# 10446975   None  None                                               None
# 10446976   None  None                                               None
# 10446977   None  None                                               None
#
#          state                                   relative_results  \
# 0         None  [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 1         None  [0x89e4a6ce94008f83:0x48244c8afd7f8d76, 0x89e4...
# 3         None  [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 4         None  [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# 5         None  [0x89e4a6d00319316d:0x5d22d9b17e568648, 0x89e4...
# ...        ...                                                ...
# 10446973  None                                               None
# 10446974  None                                               None
# 10446975  None                                               None
# 10446976  None                                               None
# 10446977  None                                               None
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 3         https://www.google.com/maps/place//data=!4m2!3...
# 4         https://www.google.com/maps/place//data=!4m2!3...
# 5         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 10446973  https://www.google.com/maps/place//data=!4m2!3...
# 10446974  https://www.google.com/maps/place//data=!4m2!3...
# 10446975  https://www.google.com/maps/place//data=!4m2!3...
# 10446976  https://www.google.com/maps/place//data=!4m2!3...
# 10446977  https://www.google.com/maps/place//data=!4m2!3...
#
# [5796227 rows x 21 columns]

# %%
import ast

merged_df["category"] = merged_df["category"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Expand the list into separate columns
category_expanded = merged_df["category"].apply(pd.Series)

# Rename columns as 'category_1', 'category_2', etc.
category_expanded.columns = [f"category_{i+1}" for i in range(category_expanded.shape[1])]

# Concatenate with original dataset
merged_df = pd.concat([merged_df, category_expanded], axis=1)

# Drop original 'category' column
#cleaned_file.drop(columns=["category"], inplace=True)

merged_df
# Out:
#                user_id                  name_x           time  rating  \
# 0         1.089901e+20            Sherri Mayne  1559246854759     5.0
# 1         1.004254e+20          Adam Goodspeed  1557586283214     5.0
# 3         1.063415e+20          Katie Sullivan  1627234799114     5.0
# 4         1.024727e+20      Victoria Henderson  1619237055452     5.0
# 5         1.180340e+20           Donna Carlson  1619732714443     5.0
# ...                ...                     ...            ...     ...
# 10446973  1.084896e+20  Barbara Gatens-Pursell  1502224277318     3.0
# 10446974  1.039721e+20           Marcel Brants  1563068387459     3.0
# 10446975  1.030453e+20                  Andrea  1534216707086     4.0
# 10446976  1.076849e+20          Guido Hermanns  1530103982634     5.0
# 10446977  1.069805e+20           Marcel Vachon  1534161873445     5.0
#
#                                                        text  resp  \
# 0         I love the people that live there, they ate th...  None
# 1         Stop parking in the residents spots for your d...  None
# 3         Everytime I visit this $1000000. Boutique I am...  None
# 4         These people who do this are so special! They ...  None
# 5               People run it make sure you are comfortable  None
# ...                                                     ...   ...
# 10446973                        Average...a little rundown.  None
# 10446974  (Translated by Google) Fair to good holiday st...  None
# 10446975  (Translated by Google) A good solution to stay...  None
# 10446976  (Translated by Google) The Braemar is an owner...  None
# 10446977  (Translated by Google) Clean, lack of anything...  None
#
#                                         gmap_id                      name_y  \
# 0         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 1         0x89e4a1f2d39fb621:0xfe62e9b7266e6262  Grace Ryder Housing Center
# 3         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 4         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# 5         0x89e4a103dd188585:0xfadc47938337579f                Sowing Seeds
# ...                                         ...                         ...
# 10446973   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446974   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446975   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446976   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
# 10446977   0x879352bc8c0d42d1:0x23be3bed0e7f707     The Braemar Condominium
#
#                                                     address description  ...  \
# 0          Grace Ryder Housing Center, Marshfield, MA 02050        None  ...
# 1          Grace Ryder Housing Center, Marshfield, MA 02050        None  ...
# 3          Sowing Seeds, 974 Plain St, Marshfield, MA 02050        None  ...
# 4          Sowing Seeds, 974 Plain St, Marshfield, MA 02050        None  ...
# 5          Sowing Seeds, 974 Plain St, Marshfield, MA 02050        None  ...
# ...                                                     ...         ...  ...
# 10446973  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446974  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446975  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446976  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
# 10446977  The Braemar Condominium, 132 Shore Rd, North T...        None  ...
#
#           category_5  category_6 category_7  category_8  category_9  \
# 0                NaN         NaN        NaN         NaN         NaN
# 1                NaN         NaN        NaN         NaN         NaN
# 3                NaN         NaN        NaN         NaN         NaN
# 4                NaN         NaN        NaN         NaN         NaN
# 5                NaN         NaN        NaN         NaN         NaN
# ...              ...         ...        ...         ...         ...
# 10446973         NaN         NaN        NaN         NaN         NaN
# 10446974         NaN         NaN        NaN         NaN         NaN
# 10446975         NaN         NaN        NaN         NaN         NaN
# 10446976         NaN         NaN        NaN         NaN         NaN
# 10446977         NaN         NaN        NaN         NaN         NaN
#
#          category_10 category_11 category_12 category_13 category_14
# 0                NaN         NaN         NaN         NaN         NaN
# 1                NaN         NaN         NaN         NaN         NaN
# 3                NaN         NaN         NaN         NaN         NaN
# 4                NaN         NaN         NaN         NaN         NaN
# 5                NaN         NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...         ...
# 10446973         NaN         NaN         NaN         NaN         NaN
# 10446974         NaN         NaN         NaN         NaN         NaN
# 10446975         NaN         NaN         NaN         NaN         NaN
# 10446976         NaN         NaN         NaN         NaN         NaN
# 10446977         NaN         NaN         NaN         NaN         NaN
#
# [5796227 rows x 35 columns]

# %%
import re

from tqdm import tqdm
tqdm.pandas()

healthcare_categories = {
    "medical clinic", "women's health clinic", "home health care service", "internist", "allergist",
    "diabetes center", "doctor", "family practice physician", "optometrist", "pharmacy", "dentist",
    "medical supply store", "orthopedic surgeon", "surgeon", "psychotherapist", "dental clinic",
    "orthodontist", "physical therapist", "chiropractor", "hospital", "sleep clinic", "optician",
    "cancer treatment center", "medical center", "physical therapy clinic", "medical laboratory",
    "public health department", "psychologist", "radiologist", "podiatrist", "nursing home",
    "medical group", "x-ray lab", "dermatologist", "pediatrician", "massage therapist",
    "periodontist", "obstetrician-gynecologist", "sports medicine clinic", "psychiatric hospital",
    "orthotics & prosthetics service", "physical fitness program", "ophthalmologist", "hospice",
    "retirement home", "rehabilitation center", "pediatric dentist", "teeth whitening service",
    "dental hygienist", "endodontist", "dental implants periodontist", "cosmetic dentist",
    "emergency dental service", "urgent care center", "wellness center", "walk-in clinic",
    "general practitioner", "children's hospital", "mental health clinic", "otolaryngologist", "eye care center", 
    "ophthalmology clinic","lasik surgeon","blood donation center" ,
    "Addiction treatment center","denture care center","gym","fitness center","personal trainer", 
    "Psychiatrist", "Drug store","Vitamin & supplements store","weight loss service",
    "Pulmonologist","gymnastics center", "oral surgeon","Oral and maxillofacial surgeon","homeless service",
     "Alcoholism treatment program", "Homeless shelter", "child care agency","day care center",
     "Neurosurgeon","Vascular surgeon", "Cardiologist", "Laboratory", "Specialized clinic",
     "contact lenses supplier","massage spa","Reflexologist", "Rheumatologist", "Surgical center",
     "Mental health service", "Eating disorder treatment center", "Hair removal service", 
     "Skin care clinic","foot care","laser hair removal service","spa","medical spa",
     "sports nutrition store","pain control clinic","audiologist","plastic surgeon","pathologist",
     "Pediatric cardiologist","Sports medicine physician","Medical equipment supplier","nurse practitioner",
     "Counselor", "Family counselor", "Marriage or relationship counselor","facial spa",
     "Occupational medical physician","Urologist","Nephrologist","Endocrinologist",
     "Alternative medicine practitioner", "Holistic medicine practitioner",
     "health","massage","Dialysis center", "Local medical services", 
     "hand surgeon","Gastroenterologist","Thai massage therapist","Hearing aid store", "Hearing aid repair service"
                                        
}
# Function to check if a business belongs to the healthcare category
def classify_healthcare(row):
    for i in range(1, 16):  # Assuming category_1 to category_15 exist
        category_col = f"category_{i}"
        if category_col in row and isinstance(row[category_col], str):  # Check if column exists and is a string
            for keyword in healthcare_categories:
                if re.search(rf"\b{keyword}\b", row[category_col], re.IGNORECASE):  # Match whole word
                    return "Healthcare"  # Assign healthcare label
    return "Other"  # Default category if no match

# Apply the function to create a new 'general_labelling' column
merged_df["general_labelling"] = merged_df.progress_apply(classify_healthcare, axis=1)
# Out:
# 100%|██████████| 5796227/5796227 [3:57:37<00:00, 406.53it/s]

# %%
# Filter records where 'general_labelling' is "Healthcare"
healthcare_dataset = merged_df[merged_df["general_labelling"] == "Healthcare"]

# %%
# Define the file path to save the Healthcare dataset
mass_healthcare_dataset_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/mass_healthcare_dataset.csv"

# %%
healthcare_dataset.to_csv(mass_healthcare_dataset_path, index=False)

# %% [markdown]
# **

# %%
import pandas as pd
path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/mass_healthcare_dataset.csv"
mass_df = pd.read_csv(path)
mass_df
# Out:
# C:\Users\eliza\AppData\Local\Temp\ipykernel_1176\3229228492.py:3: DtypeWarning: Columns (18,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   mass_df = pd.read_csv(path)
#              user_id                      name_x           time  rating  \
# 0       1.162863e+20                Conor Cooper  1578257043247     5.0
# 1       1.089901e+20                Sherri Mayne  1581811822124     5.0
# 2       1.076596e+20  Yoga With Jen, Gentle Yoga  1488812343378     3.0
# 3       1.089878e+20                   James Pin  1621747934834     3.0
# 4       1.019095e+20                 Jerry Holly  1590068980200     5.0
# ...              ...                         ...            ...     ...
# 342915  1.153550e+20                 ashok reddy  1618619279392     1.0
# 342916  1.120810e+20                       Renan  1504928502522     5.0
# 342917  1.067325e+20                   Ram Kumar  1485708564104     4.0
# 342918  1.151380e+20         Pareshkumar Mandali  1581276530374     1.0
# 342919  1.061049e+20           Haidar Al-Rubie'y  1525869899240     3.0
#
#                                                      text  \
# 0       Cardio and gym equipment plus a studio with 35...
# 1                                                Loved it
# 2                                      Great instructors,
# 3       I always get my schedule canceled due to staff...
# 4       Always are thanked and appreciated. All staff ...
# ...                                                   ...
# 342915  Worst place to have anything.\nChicken entrees...
# 342916  (Translated by Google) For those who like spic...
# 342917  (Translated by Google) Food .. especially Briy...
# 342918  (Translated by Google) So restaurant\n\n(Origi...
# 342919     (Translated by Google) good\n\n(Original)\nجيد
#
#                                                      resp  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       {'time': 1621874701934, 'text': 'Hi James- Tha...
# 4                                                     NaN
# ...                                                   ...
# 342915                                                NaN
# 342916                                                NaN
# 342917                                                NaN
# 342918                                                NaN
# 342919                                                NaN
#
#                                       gmap_id  \
# 0        0x89e4a6c554aa0e59:0x45965ec598f57a3
# 1        0x89e4a6c554aa0e59:0x45965ec598f57a3
# 2        0x89e4a6c554aa0e59:0x45965ec598f57a3
# 3       0x89e3631b2f7bcee7:0xb92a5cf72c21325c
# 4       0x89e3631b2f7bcee7:0xb92a5cf72c21325c
# ...                                       ...
# 342915  0x89e36339f67d1d1d:0xa4b8e5985610158e
# 342916  0x89e36339f67d1d1d:0xa4b8e5985610158e
# 342917  0x89e36339f67d1d1d:0xa4b8e5985610158e
# 342918  0x89e36339f67d1d1d:0xa4b8e5985610158e
# 342919  0x89e36339f67d1d1d:0xa4b8e5985610158e
#
#                                                    name_y  \
# 0                                            Workout Club
# 1                                            Workout Club
# 2                                            Workout Club
# 3       Weymouth Red Cross Blood, Platelet and Plasma ...
# 4       Weymouth Red Cross Blood, Platelet and Plasma ...
# ...                                                   ...
# 342915                             BHEEMAS INDIAN CUISINE
# 342916                             BHEEMAS INDIAN CUISINE
# 342917                             BHEEMAS INDIAN CUISINE
# 342918                             BHEEMAS INDIAN CUISINE
# 342919                             BHEEMAS INDIAN CUISINE
#
#                                                   address description  ...  \
# 0       Workout Club, Webster Square, Marshfield, MA 0...         NaN  ...
# 1       Workout Club, Webster Square, Marshfield, MA 0...         NaN  ...
# 2       Workout Club, Webster Square, Marshfield, MA 0...         NaN  ...
# 3       Weymouth Red Cross Blood, Platelet and Plasma ...         NaN  ...
# 4       Weymouth Red Cross Blood, Platelet and Plasma ...         NaN  ...
# ...                                                   ...         ...  ...
# 342915  BHEEMAS INDIAN CUISINE, 271 Quincy Ave, Quincy...         NaN  ...
# 342916  BHEEMAS INDIAN CUISINE, 271 Quincy Ave, Quincy...         NaN  ...
# 342917  BHEEMAS INDIAN CUISINE, 271 Quincy Ave, Quincy...         NaN  ...
# 342918  BHEEMAS INDIAN CUISINE, 271 Quincy Ave, Quincy...         NaN  ...
# 342919  BHEEMAS INDIAN CUISINE, 271 Quincy Ave, Quincy...         NaN  ...
#
#         category_6  category_7 category_8  category_9  category_10  \
# 0              NaN         NaN        NaN         NaN          NaN
# 1              NaN         NaN        NaN         NaN          NaN
# 2              NaN         NaN        NaN         NaN          NaN
# 3              NaN         NaN        NaN         NaN          NaN
# 4              NaN         NaN        NaN         NaN          NaN
# ...            ...         ...        ...         ...          ...
# 342915         NaN         NaN        NaN         NaN          NaN
# 342916         NaN         NaN        NaN         NaN          NaN
# 342917         NaN         NaN        NaN         NaN          NaN
# 342918         NaN         NaN        NaN         NaN          NaN
# 342919         NaN         NaN        NaN         NaN          NaN
#
#        category_11 category_12 category_13 category_14 general_labelling
# 0              NaN         NaN         NaN         NaN        Healthcare
# 1              NaN         NaN         NaN         NaN        Healthcare
# 2              NaN         NaN         NaN         NaN        Healthcare
# 3              NaN         NaN         NaN         NaN        Healthcare
# 4              NaN         NaN         NaN         NaN        Healthcare
# ...            ...         ...         ...         ...               ...
# 342915         NaN         NaN         NaN         NaN        Healthcare
# 342916         NaN         NaN         NaN         NaN        Healthcare
# 342917         NaN         NaN         NaN         NaN        Healthcare
# 342918         NaN         NaN         NaN         NaN        Healthcare
# 342919         NaN         NaN         NaN         NaN        Healthcare
#
# [342920 rows x 36 columns]
