# %%
import pandas as pd

# %%
review_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/UtahReview/review-Utah.json"
review_df = pd.read_json(review_path, lines = True)
review_df
# Out:
#               user_id                      name           time  rating  \
# 0        1.057676e+20             Joel Thompson  1551454013967     1.0
# 1        1.044866e+20            Scott Davidson  1447283391185     5.0
# 2        1.057905e+20             Robert DeLong  1425428968447     5.0
# 3        1.160109e+20  Ingrid and Matt Labronte  1475392417109     5.0
# 4        1.111826e+20                Liz W Poch  1627085008811     5.0
# ...               ...                       ...            ...     ...
# 9081162  1.040284e+20             Yvette Zavala  1572567918308     2.0
# 9081163  1.036640e+20       Teaching Essentials  1555375657691     4.0
# 9081164  1.177836e+20            Adam Gustafson  1416106076493     3.0
# 9081165  1.047760e+20             Pigui Saldaña  1577303098142     4.0
# 9081166  1.177196e+20             Dillon Larsen  1455981375115     4.0
#
#                                                       text  pics  \
# 0        After confirmed booking and charged deposit, r...  None
# 1                          Best ski area in North America.  None
# 2              Spectacular skiing and outstanding service!  None
# 3                                            Amazing views  None
# 4        Paige is the best! Everyone at this branch is ...  None
# ...                                                    ...   ...
# 9081162                                               None  None
# 9081163                                               None  None
# 9081164                                               None  None
# 9081165                                               None  None
# 9081166                                               None  None
#
#                                                       resp  \
# 0        {'time': 1551468008335, 'text': 'Yes, we made ...
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9081162                                               None
# 9081163                                               None
# 9081164                                               None
# 9081165                                               None
# 9081166                                               None
#
#                                        gmap_id
# 0         0x875272d9b058dd7d:0x5ee3c2208a98570
# 1         0x875272d9b058dd7d:0x5ee3c2208a98570
# 2         0x875272d9b058dd7d:0x5ee3c2208a98570
# 3         0x875272d9b058dd7d:0x5ee3c2208a98570
# 4        0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# ...                                        ...
# 9081162  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081163  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081164  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081165  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081166  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
#
# [9081167 rows x 8 columns]

# %%
business_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/UtahMeta/meta-Utah.json"
business_df = pd.read_json(business_path, lines = True)
business_df
# Out:
#                                             name  \
# 0                     Silver Lake Accommodations
# 1                University Federal Credit Union
# 2                 Maverik Adventure's First Stop
# 3                           Granite Credit Union
# 4      HOTWORX - Salt Lake City, UT (Sugarhouse)
# ...                                          ...
# 58792                            Draper Crossing
# 58793                            Jack in the Box
# 58794                                     Conoco
# 58795                               Spanish Fork
# 58796                              Panda Express
#
#                                                  address  \
# 0      Silver Lake Accommodations, 7550 Royal St, Par...
# 1      University Federal Credit Union, 7220 S Highla...
# 2      Maverik Adventure's First Stop, 3330 S 500 W, ...
# 3      Granite Credit Union, 9151 Quarry Bend Dr, San...
# 4      HOTWORX - Salt Lake City, UT (Sugarhouse), 675...
# ...                                                  ...
# 58792   Draper Crossing, 212 E 12300 S, Draper, UT 84020
# 58793  Jack in the Box, 1596 S Convention Center Dr, ...
# 58794               Conoco, 104 W 100 N, Price, UT 84501
# 58795                           Spanish Fork, Utah 84660
# 58796   Panda Express, 64 E 12300 S St, Draper, UT 84020
#
#                                      gmap_id  \
# 0       0x875272d9b058dd7d:0x5ee3c2208a98570
# 1      0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# 2      0x87528bb7ab938cb3:0x5ee996e34cc50715
# 3      0x8752886f10e79bb9:0x28c71adea02f3862
# 4       0x87528b34a4f8738f:0x79d61042dfa75e8
# ...                                      ...
# 58792  0x87528714131dc5e1:0x57130d869abea558
# 58793  0x80ca453710952cab:0x70a40bca02898341
# 58794  0x874ebbe4a8181e5b:0xb5afc0f672d353ef
# 58795  0x874d988554dd020b:0x970e9ae918f27f17
# 58796  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
#
#                                              description   latitude  \
# 0                                                   None  40.621953
# 1                                                   None  40.620069
# 2                                                   None  40.698585
# 3                                                   None  40.585279
# 4                                                   None  40.726031
# ...                                                  ...        ...
# 58792                                               None  40.525895
# 58793  Burgers, chicken, tacos & breakfast items fill...  37.081064
# 58794                                               None  39.601229
# 58795                                               None  40.077910
# 58796  Fast-food chain for Chinese standards, includi...  40.526300
#
#         longitude                                           category  \
# 0     -111.489329  [Condominium rental agency, Property managemen...
# 1     -111.834952  [Credit union, ATM, Bank, Check cashing servic...
# 2     -111.906406  [Fuel supplier, Convenience store, Fast food r...
# 3     -111.860267                                [Credit union, ATM]
# 4     -111.872416  [Yoga studio, Fitness center, Gym, Indoor cycl...
# ...           ...                                                ...
# 58792 -111.886485                                    [Shopping mall]
# 58793 -113.582601  [Fast food restaurant, Breakfast restaurant, C...
# 58794 -110.813670                                      [Gas station]
# 58795 -111.614828                                            [River]
# 58796 -111.888824  [Chinese restaurant, Asian restaurant, Restaur...
#
#        avg_rating  num_of_reviews price  \
# 0             4.3               4  None
# 1             3.8              25  None
# 2             3.4               5  None
# 3             4.4               8  None
# 4             4.6              28  None
# ...           ...             ...   ...
# 58792         4.2            1766  None
# 58793         3.9            1145     $
# 58794         4.1              48  None
# 58795         4.5              28  None
# 58796         3.7             468     $
#
#                                                    hours  \
# 0      [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 1      [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...
# 2      [[Thursday, Open 24 hours], [Friday, Open 24 h...
# 3      [[Thursday, 9AM–7PM], [Friday, 9AM–7PM], [Satu...
# 4      [[Thursday, 11AM–8PM], [Friday, 9AM–6PM], [Sat...
# ...                                                  ...
# 58792  [[Wednesday, 10:30AM–10:30PM], [Thursday, 10:3...
# 58793  [[Wednesday, 6AM–11PM], [Thursday, 6AM–11PM], ...
# 58794                                               None
# 58795                                               None
# 58796  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
#
#                                                     MISC              state  \
# 0                                                   None  Open ⋅ Closes 5PM
# 1      {'Service options': ['Drive-through'], 'Access...  Open ⋅ Closes 6PM
# 2      {'Accessibility': ['Wheelchair accessible entr...      Open 24 hours
# 3      {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 7PM
# 4      {'Accessibility': ['Wheelchair accessible entr...  Opens soon ⋅ 11AM
# ...                                                  ...                ...
# 58792  {'Service options': ['In-store shopping'], 'Ac...                NaN
# 58793  {'Service options': ['No-contact delivery', 'D...                NaN
# 58794  {'Accessibility': ['Wheelchair accessible entr...                NaN
# 58795                                               None                NaN
# 58796  {'Service options': ['Delivery', 'Takeout', 'D...                NaN
#
#                                         relative_results  \
# 0      [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 1      [0x875261daf7d2a98d:0x9fa745d87ca27ec4, 0x8752...
# 2                                                   None
# 3      [0x8752880044fa9c0b:0xdfdd9340e032920, 0x87528...
# 4      [0x8752f55503cbf28b:0x13c5f56a40185f30, 0x8752...
# ...                                                  ...
# 58792  [0x8752876017aac1ef:0x326b132d76737626, 0x8752...
# 58793  [0x80ca452797cd904b:0x62ea5e746dc1b6ab, 0x80ca...
# 58794  [0x874ebbd93801fa27:0x3bac3369136def4d, 0x874e...
# 58795                                               None
# 58796  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 58792  https://www.google.com/maps/place//data=!4m2!3...
# 58793  https://www.google.com/maps/place//data=!4m2!3...
# 58794  https://www.google.com/maps/place//data=!4m2!3...
# 58795  https://www.google.com/maps/place/Utah+84660/d...
# 58796  https://www.google.com/maps/place//data=!4m2!3...
#
# [58797 rows x 15 columns]

# %%
# Aggregate business metadata by gmap_id before merging
business_agg = business_df.groupby("gmap_id", as_index=False).agg({
    "name": "first",  # Keep first occurrence (assumes same name per gmap_id)
    "address": "first",
    "description": "first",
    "latitude": "first",
    "longitude": "first",
    "category": lambda x: list(set(x.sum())) if x.apply(lambda v: isinstance(v, list)).any() else list(set(x)),
    "avg_rating": "mean",  # Use mean rating if multiple exist
    "num_of_reviews": "sum",
    "price": "first",
    "hours": "first",
    "MISC": "first",
    "state": "first",
    "relative_results": "first",
    "url": "first"
})

# Check if aggregation worked
print(business_agg.head())
# Out:
#                                  gmap_id                               name  \
# 0                 0x0:0xb639abc4be1471c5              Santiago's Office Inc
# 1                 0x0:0xd255223c6c0c42e6                            SEPHORA
# 2  0x14acb001b5ebc8a3:0xb880a6e85acdb0a6  Katinov Photography - Provo, Utah
# 3  0x152e17f2ebc0c523:0x42f5dc12a26572bd                       VASA Fitness
# 4  0x152e3966c08eef7d:0xc7925b64e8d42f4f        Mountainland Supply Company
#
#                                              address  \
# 0  Santiago's Office Inc, 4190 S Redwood Rd, Tayl...
# 1  SEPHORA, 50 South Main Street Space #123, Salt...
# 2  Katinov Photography - Provo, Utah, 1138 Meadow...
# 3  VASA Fitness, 484 N Mall Dr, St. George, UT 84790
# 4  Mountainland Supply Company, 525 N 3050 E #1, ...
#
#                                          description   latitude   longitude  \
# 0                                               None  40.679934 -111.939380
# 1  Retail chain with a selection of upmarket make...  40.768357 -111.891745
# 2                                               None  40.218646 -111.629042
# 3                                               None  37.116726 -113.541998
# 4                                               None  37.117539 -113.521318
#
#                                             category  avg_rating  \
# 0  [Tax preparation service, Bookkeeping service,...         4.5
# 1  [Beauty supply store, Cosmetics store, Perfume...         4.3
# 2  [Portrait studio, Wedding photographer, Photog...         5.0
# 3                                              [Gym]         4.2
# 4  [Pipe supplier, Lawn irrigation equipment supp...         4.4
#
#    num_of_reviews price                                              hours  \
# 0              14  None  [[Tuesday, 9AM–5PM], [Wednesday, 9AM–5PM], [Th...
# 1             174   $$$  [[Wednesday, 11AM–8PM], [Thursday, 11AM–8PM], ...
# 2              88  None  [[Monday, 10AM–6PM], [Tuesday, 10AM–6PM], [Wed...
# 3             778  None  [[Saturday, 5AM–10PM], [Sunday, 8AM–4PM], [Mon...
# 4               8  None  [[Friday, 7AM–5PM], [Saturday, Closed], [Sunda...
#
#                                                 MISC                    state  \
# 0  {'Service options': ['Onsite services'], 'Heal...   Closed ⋅ Opens 9AM Wed
# 1  {'Service options': ['In-store pickup', 'In-st...      Closed ⋅ Opens 11AM
# 2  {'Service options': ['Online appointments'], '...  Closed ⋅ Opens 10AM Tue
# 3  {'Accessibility': ['Wheelchair accessible entr...       Open ⋅ Closes 10PM
# 4  {'Service options': ['Curbside pickup', 'In-st...        Open ⋅ Closes 5PM
#
#                                     relative_results  \
# 0  [0x875289599afca4db:0x957a8010b6084be2, 0x8752...
# 1  [0x87528a80496dbe03:0xf2d8ec3077206023, 0x8752...
# 2  [0x14acb001dc375f13:0x3bb465ce9297769a, 0x14ac...
# 3  [0x80ca449963b05c15:0x3d3d621d48072624, 0x80ca...
# 4  [0x80ca4531d37db09f:0xac2c07c0d38616f7, 0x80ca...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Merge with aggregated business data
merged_df = review_df.merge(business_agg, on="gmap_id", how="left")
merged_df
# Out:
#               user_id                    name_x           time  rating  \
# 0        1.057676e+20             Joel Thompson  1551454013967     1.0
# 1        1.044866e+20            Scott Davidson  1447283391185     5.0
# 2        1.057905e+20             Robert DeLong  1425428968447     5.0
# 3        1.160109e+20  Ingrid and Matt Labronte  1475392417109     5.0
# 4        1.111826e+20                Liz W Poch  1627085008811     5.0
# ...               ...                       ...            ...     ...
# 9081162  1.040284e+20             Yvette Zavala  1572567918308     2.0
# 9081163  1.036640e+20       Teaching Essentials  1555375657691     4.0
# 9081164  1.177836e+20            Adam Gustafson  1416106076493     3.0
# 9081165  1.047760e+20             Pigui Saldaña  1577303098142     4.0
# 9081166  1.177196e+20             Dillon Larsen  1455981375115     4.0
#
#                                                       text  pics  \
# 0        After confirmed booking and charged deposit, r...  None
# 1                          Best ski area in North America.  None
# 2              Spectacular skiing and outstanding service!  None
# 3                                            Amazing views  None
# 4        Paige is the best! Everyone at this branch is ...  None
# ...                                                    ...   ...
# 9081162                                               None  None
# 9081163                                               None  None
# 9081164                                               None  None
# 9081165                                               None  None
# 9081166                                               None  None
#
#                                                       resp  \
# 0        {'time': 1551468008335, 'text': 'Yes, we made ...
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9081162                                               None
# 9081163                                               None
# 9081164                                               None
# 9081165                                               None
# 9081166                                               None
#
#                                        gmap_id  \
# 0         0x875272d9b058dd7d:0x5ee3c2208a98570
# 1         0x875272d9b058dd7d:0x5ee3c2208a98570
# 2         0x875272d9b058dd7d:0x5ee3c2208a98570
# 3         0x875272d9b058dd7d:0x5ee3c2208a98570
# 4        0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# ...                                        ...
# 9081162  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081163  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081164  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081165  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9081166  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
#
#                                   name_y  \
# 0             Silver Lake Accommodations
# 1             Silver Lake Accommodations
# 2             Silver Lake Accommodations
# 3             Silver Lake Accommodations
# 4        University Federal Credit Union
# ...                                  ...
# 9081162                    Panda Express
# 9081163                    Panda Express
# 9081164                    Panda Express
# 9081165                    Panda Express
# 9081166                    Panda Express
#
#                                                    address  ...   longitude  \
# 0        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 1        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 2        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 3        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 4        University Federal Credit Union, 7220 S Highla...  ... -111.834952
# ...                                                    ...  ...         ...
# 9081162   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9081163   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9081164   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9081165   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9081166   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
#
#                                                   category  avg_rating  \
# 0        [Vacation home rental agency, Condominium rent...         4.3
# 1        [Vacation home rental agency, Condominium rent...         4.3
# 2        [Vacation home rental agency, Condominium rent...         4.3
# 3        [Vacation home rental agency, Condominium rent...         4.3
# 4        [Money transfer service, Loan agency, Check ca...         3.8
# ...                                                    ...         ...
# 9081162  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9081163  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9081164  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9081165  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9081166  [Restaurant, Chinese restaurant, Asian restaur...         3.7
#
#         num_of_reviews  price  \
# 0                    8   None
# 1                    8   None
# 2                    8   None
# 3                    8   None
# 4                   50   None
# ...                ...    ...
# 9081162            468      $
# 9081163            468      $
# 9081164            468      $
# 9081165            468      $
# 9081166            468      $
#
#                                                      hours  \
# 0        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 1        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 2        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 3        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4        [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...
# ...                                                    ...
# 9081162  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9081163  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9081164  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9081165  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9081166  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
#
#                                                       MISC              state  \
# 0                                                     None  Open ⋅ Closes 5PM
# 1                                                     None  Open ⋅ Closes 5PM
# 2                                                     None  Open ⋅ Closes 5PM
# 3                                                     None  Open ⋅ Closes 5PM
# 4        {'Service options': ['Drive-through'], 'Access...  Open ⋅ Closes 6PM
# ...                                                    ...                ...
# 9081162  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9081163  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9081164  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9081165  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9081166  {'Service options': ['Delivery', 'Takeout', 'D...               None
#
#                                           relative_results  \
# 0        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 1        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 2        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 3        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 4        [0x875261daf7d2a98d:0x9fa745d87ca27ec4, 0x8752...
# ...                                                    ...
# 9081162  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9081163  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9081164  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9081165  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9081166  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 9081162  https://www.google.com/maps/place//data=!4m2!3...
# 9081163  https://www.google.com/maps/place//data=!4m2!3...
# 9081164  https://www.google.com/maps/place//data=!4m2!3...
# 9081165  https://www.google.com/maps/place//data=!4m2!3...
# 9081166  https://www.google.com/maps/place//data=!4m2!3...
#
# [9081167 rows x 22 columns]

# %%
unmatched = review_df[~review_df['gmap_id'].isin(business_agg['gmap_id'])]
print(f"Unmatched rows: {len(unmatched)}")
print("Unique gmap_id in review_df:", review_df['gmap_id'].nunique())
print("Unique gmap_id in business_agg:", business_agg['gmap_id'].nunique())
# Out:
# Unmatched rows: 0
# Unique gmap_id in review_df: 58538
# Unique gmap_id in business_agg: 58538

# %%
#check if null values in 'text' column exist
print(merged_df['text'].isna().sum())
# Out:
# 3307108

# %%
#remove rows/records where 'text' is null
merged_df = merged_df.dropna(subset = ['text'])
merged_df
# Out:
#               user_id                    name_x           time  rating  \
# 0        1.057676e+20             Joel Thompson  1551454013967     1.0
# 1        1.044866e+20            Scott Davidson  1447283391185     5.0
# 2        1.057905e+20             Robert DeLong  1425428968447     5.0
# 3        1.160109e+20  Ingrid and Matt Labronte  1475392417109     5.0
# 4        1.111826e+20                Liz W Poch  1627085008811     5.0
# ...               ...                       ...            ...     ...
# 9080971  1.067465e+20              Edgar Blanco  1581394572181     5.0
# 9080972  1.074196e+20               CachorroZMX  1569020105863     3.0
# 9080973  1.033579e+20              Ruben Chacon  1475642796673     5.0
# 9080974  1.115624e+20       Agustin Garcia-Cruz  1551835238221     5.0
# 9080975  1.103435e+20                   antares  1538960778960     4.0
#
#                                                       text  pics  \
# 0        After confirmed booking and charged deposit, r...  None
# 1                          Best ski area in North America.  None
# 2              Spectacular skiing and outstanding service!  None
# 3                                            Amazing views  None
# 4        Paige is the best! Everyone at this branch is ...  None
# ...                                                    ...   ...
# 9080971  (Translated by Google) Good food\n\n(Original)...  None
# 9080972  (Translated by Google) A lot of rice\n\n(Origi...  None
# 9080973  (Translated by Google) The food is very good a...  None
# 9080974  (Translated by Google) I really like the Panda...  None
# 9080975  (Translated by Google) Not everything should b...  None
#
#                                                       resp  \
# 0        {'time': 1551468008335, 'text': 'Yes, we made ...
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9080971                                               None
# 9080972                                               None
# 9080973                                               None
# 9080974                                               None
# 9080975                                               None
#
#                                        gmap_id  \
# 0         0x875272d9b058dd7d:0x5ee3c2208a98570
# 1         0x875272d9b058dd7d:0x5ee3c2208a98570
# 2         0x875272d9b058dd7d:0x5ee3c2208a98570
# 3         0x875272d9b058dd7d:0x5ee3c2208a98570
# 4        0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# ...                                        ...
# 9080971  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080972  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080973  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080974  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080975  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
#
#                                   name_y  \
# 0             Silver Lake Accommodations
# 1             Silver Lake Accommodations
# 2             Silver Lake Accommodations
# 3             Silver Lake Accommodations
# 4        University Federal Credit Union
# ...                                  ...
# 9080971                    Panda Express
# 9080972                    Panda Express
# 9080973                    Panda Express
# 9080974                    Panda Express
# 9080975                    Panda Express
#
#                                                    address  ...   longitude  \
# 0        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 1        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 2        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 3        Silver Lake Accommodations, 7550 Royal St, Par...  ... -111.489329
# 4        University Federal Credit Union, 7220 S Highla...  ... -111.834952
# ...                                                    ...  ...         ...
# 9080971   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9080972   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9080973   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9080974   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
# 9080975   Panda Express, 64 E 12300 S St, Draper, UT 84020  ... -111.888824
#
#                                                   category  avg_rating  \
# 0        [Vacation home rental agency, Condominium rent...         4.3
# 1        [Vacation home rental agency, Condominium rent...         4.3
# 2        [Vacation home rental agency, Condominium rent...         4.3
# 3        [Vacation home rental agency, Condominium rent...         4.3
# 4        [Money transfer service, Loan agency, Check ca...         3.8
# ...                                                    ...         ...
# 9080971  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9080972  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9080973  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9080974  [Restaurant, Chinese restaurant, Asian restaur...         3.7
# 9080975  [Restaurant, Chinese restaurant, Asian restaur...         3.7
#
#         num_of_reviews  price  \
# 0                    8   None
# 1                    8   None
# 2                    8   None
# 3                    8   None
# 4                   50   None
# ...                ...    ...
# 9080971            468      $
# 9080972            468      $
# 9080973            468      $
# 9080974            468      $
# 9080975            468      $
#
#                                                      hours  \
# 0        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 1        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 2        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 3        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4        [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...
# ...                                                    ...
# 9080971  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080972  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080973  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080974  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080975  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
#
#                                                       MISC              state  \
# 0                                                     None  Open ⋅ Closes 5PM
# 1                                                     None  Open ⋅ Closes 5PM
# 2                                                     None  Open ⋅ Closes 5PM
# 3                                                     None  Open ⋅ Closes 5PM
# 4        {'Service options': ['Drive-through'], 'Access...  Open ⋅ Closes 6PM
# ...                                                    ...                ...
# 9080971  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080972  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080973  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080974  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080975  {'Service options': ['Delivery', 'Takeout', 'D...               None
#
#                                           relative_results  \
# 0        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 1        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 2        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 3        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 4        [0x875261daf7d2a98d:0x9fa745d87ca27ec4, 0x8752...
# ...                                                    ...
# 9080971  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080972  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080973  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080974  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080975  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 9080971  https://www.google.com/maps/place//data=!4m2!3...
# 9080972  https://www.google.com/maps/place//data=!4m2!3...
# 9080973  https://www.google.com/maps/place//data=!4m2!3...
# 9080974  https://www.google.com/maps/place//data=!4m2!3...
# 9080975  https://www.google.com/maps/place//data=!4m2!3...
#
# [5774059 rows x 22 columns]

# %%
#delete pics 
merged_df = merged_df.drop(columns = ['pics'])
merged_df
# Out:
#               user_id                    name_x           time  rating  \
# 0        1.057676e+20             Joel Thompson  1551454013967     1.0
# 1        1.044866e+20            Scott Davidson  1447283391185     5.0
# 2        1.057905e+20             Robert DeLong  1425428968447     5.0
# 3        1.160109e+20  Ingrid and Matt Labronte  1475392417109     5.0
# 4        1.111826e+20                Liz W Poch  1627085008811     5.0
# ...               ...                       ...            ...     ...
# 9080971  1.067465e+20              Edgar Blanco  1581394572181     5.0
# 9080972  1.074196e+20               CachorroZMX  1569020105863     3.0
# 9080973  1.033579e+20              Ruben Chacon  1475642796673     5.0
# 9080974  1.115624e+20       Agustin Garcia-Cruz  1551835238221     5.0
# 9080975  1.103435e+20                   antares  1538960778960     4.0
#
#                                                       text  \
# 0        After confirmed booking and charged deposit, r...
# 1                          Best ski area in North America.
# 2              Spectacular skiing and outstanding service!
# 3                                            Amazing views
# 4        Paige is the best! Everyone at this branch is ...
# ...                                                    ...
# 9080971  (Translated by Google) Good food\n\n(Original)...
# 9080972  (Translated by Google) A lot of rice\n\n(Origi...
# 9080973  (Translated by Google) The food is very good a...
# 9080974  (Translated by Google) I really like the Panda...
# 9080975  (Translated by Google) Not everything should b...
#
#                                                       resp  \
# 0        {'time': 1551468008335, 'text': 'Yes, we made ...
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9080971                                               None
# 9080972                                               None
# 9080973                                               None
# 9080974                                               None
# 9080975                                               None
#
#                                        gmap_id  \
# 0         0x875272d9b058dd7d:0x5ee3c2208a98570
# 1         0x875272d9b058dd7d:0x5ee3c2208a98570
# 2         0x875272d9b058dd7d:0x5ee3c2208a98570
# 3         0x875272d9b058dd7d:0x5ee3c2208a98570
# 4        0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# ...                                        ...
# 9080971  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080972  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080973  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080974  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080975  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
#
#                                   name_y  \
# 0             Silver Lake Accommodations
# 1             Silver Lake Accommodations
# 2             Silver Lake Accommodations
# 3             Silver Lake Accommodations
# 4        University Federal Credit Union
# ...                                  ...
# 9080971                    Panda Express
# 9080972                    Panda Express
# 9080973                    Panda Express
# 9080974                    Panda Express
# 9080975                    Panda Express
#
#                                                    address  \
# 0        Silver Lake Accommodations, 7550 Royal St, Par...
# 1        Silver Lake Accommodations, 7550 Royal St, Par...
# 2        Silver Lake Accommodations, 7550 Royal St, Par...
# 3        Silver Lake Accommodations, 7550 Royal St, Par...
# 4        University Federal Credit Union, 7220 S Highla...
# ...                                                    ...
# 9080971   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080972   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080973   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080974   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080975   Panda Express, 64 E 12300 S St, Draper, UT 84020
#
#                                                description  ...   longitude  \
# 0                                                     None  ... -111.489329
# 1                                                     None  ... -111.489329
# 2                                                     None  ... -111.489329
# 3                                                     None  ... -111.489329
# 4                                                     None  ... -111.834952
# ...                                                    ...  ...         ...
# 9080971  Fast-food chain for Chinese standards, includi...  ... -111.888824
# 9080972  Fast-food chain for Chinese standards, includi...  ... -111.888824
# 9080973  Fast-food chain for Chinese standards, includi...  ... -111.888824
# 9080974  Fast-food chain for Chinese standards, includi...  ... -111.888824
# 9080975  Fast-food chain for Chinese standards, includi...  ... -111.888824
#
#                                                   category avg_rating  \
# 0        [Vacation home rental agency, Condominium rent...        4.3
# 1        [Vacation home rental agency, Condominium rent...        4.3
# 2        [Vacation home rental agency, Condominium rent...        4.3
# 3        [Vacation home rental agency, Condominium rent...        4.3
# 4        [Money transfer service, Loan agency, Check ca...        3.8
# ...                                                    ...        ...
# 9080971  [Restaurant, Chinese restaurant, Asian restaur...        3.7
# 9080972  [Restaurant, Chinese restaurant, Asian restaur...        3.7
# 9080973  [Restaurant, Chinese restaurant, Asian restaur...        3.7
# 9080974  [Restaurant, Chinese restaurant, Asian restaur...        3.7
# 9080975  [Restaurant, Chinese restaurant, Asian restaur...        3.7
#
#          num_of_reviews  price  \
# 0                     8   None
# 1                     8   None
# 2                     8   None
# 3                     8   None
# 4                    50   None
# ...                 ...    ...
# 9080971             468      $
# 9080972             468      $
# 9080973             468      $
# 9080974             468      $
# 9080975             468      $
#
#                                                      hours  \
# 0        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 1        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 2        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 3        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4        [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...
# ...                                                    ...
# 9080971  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080972  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080973  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080974  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
# 9080975  [[Wednesday, 10:30AM–9PM], [Thursday, 10:30AM–...
#
#                                                       MISC              state  \
# 0                                                     None  Open ⋅ Closes 5PM
# 1                                                     None  Open ⋅ Closes 5PM
# 2                                                     None  Open ⋅ Closes 5PM
# 3                                                     None  Open ⋅ Closes 5PM
# 4        {'Service options': ['Drive-through'], 'Access...  Open ⋅ Closes 6PM
# ...                                                    ...                ...
# 9080971  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080972  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080973  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080974  {'Service options': ['Delivery', 'Takeout', 'D...               None
# 9080975  {'Service options': ['Delivery', 'Takeout', 'D...               None
#
#                                           relative_results  \
# 0        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 1        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 2        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 3        [0x875272d9c3e70ef3:0xb3641c007684d68e, 0x8752...
# 4        [0x875261daf7d2a98d:0x9fa745d87ca27ec4, 0x8752...
# ...                                                    ...
# 9080971  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080972  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080973  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080974  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
# 9080975  [0x87528711aeb0788b:0xebb6985f3e9207cf, 0x8752...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 9080971  https://www.google.com/maps/place//data=!4m2!3...
# 9080972  https://www.google.com/maps/place//data=!4m2!3...
# 9080973  https://www.google.com/maps/place//data=!4m2!3...
# 9080974  https://www.google.com/maps/place//data=!4m2!3...
# 9080975  https://www.google.com/maps/place//data=!4m2!3...
#
# [5774059 rows x 21 columns]

# %%
import ast

merged_df["category"] = merged_df["category"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Expand the list into separate columns
category_expanded = merged_df["category"].apply(pd.Series)

# Rename columns as 'category_1', 'category_2', etc.
category_expanded.columns = [f"category_{i+1}" for i in range(category_expanded.shape[1])]

# Concatenate with original dataset
merged_df = pd.concat([merged_df, category_expanded], axis=1)

# Drop original 'category' column
#cleaned_file.drop(columns=["category"], inplace=True)

merged_df
# Out:
#               user_id                    name_x           time  rating  \
# 0        1.057676e+20             Joel Thompson  1551454013967     1.0
# 1        1.044866e+20            Scott Davidson  1447283391185     5.0
# 2        1.057905e+20             Robert DeLong  1425428968447     5.0
# 3        1.160109e+20  Ingrid and Matt Labronte  1475392417109     5.0
# 4        1.111826e+20                Liz W Poch  1627085008811     5.0
# ...               ...                       ...            ...     ...
# 9080971  1.067465e+20              Edgar Blanco  1581394572181     5.0
# 9080972  1.074196e+20               CachorroZMX  1569020105863     3.0
# 9080973  1.033579e+20              Ruben Chacon  1475642796673     5.0
# 9080974  1.115624e+20       Agustin Garcia-Cruz  1551835238221     5.0
# 9080975  1.103435e+20                   antares  1538960778960     4.0
#
#                                                       text  \
# 0        After confirmed booking and charged deposit, r...
# 1                          Best ski area in North America.
# 2              Spectacular skiing and outstanding service!
# 3                                            Amazing views
# 4        Paige is the best! Everyone at this branch is ...
# ...                                                    ...
# 9080971  (Translated by Google) Good food\n\n(Original)...
# 9080972  (Translated by Google) A lot of rice\n\n(Origi...
# 9080973  (Translated by Google) The food is very good a...
# 9080974  (Translated by Google) I really like the Panda...
# 9080975  (Translated by Google) Not everything should b...
#
#                                                       resp  \
# 0        {'time': 1551468008335, 'text': 'Yes, we made ...
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9080971                                               None
# 9080972                                               None
# 9080973                                               None
# 9080974                                               None
# 9080975                                               None
#
#                                        gmap_id  \
# 0         0x875272d9b058dd7d:0x5ee3c2208a98570
# 1         0x875272d9b058dd7d:0x5ee3c2208a98570
# 2         0x875272d9b058dd7d:0x5ee3c2208a98570
# 3         0x875272d9b058dd7d:0x5ee3c2208a98570
# 4        0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# ...                                        ...
# 9080971  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080972  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080973  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080974  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
# 9080975  0x875287112eb7ef65:0x3aefb61bbcb5f2a9
#
#                                   name_y  \
# 0             Silver Lake Accommodations
# 1             Silver Lake Accommodations
# 2             Silver Lake Accommodations
# 3             Silver Lake Accommodations
# 4        University Federal Credit Union
# ...                                  ...
# 9080971                    Panda Express
# 9080972                    Panda Express
# 9080973                    Panda Express
# 9080974                    Panda Express
# 9080975                    Panda Express
#
#                                                    address  \
# 0        Silver Lake Accommodations, 7550 Royal St, Par...
# 1        Silver Lake Accommodations, 7550 Royal St, Par...
# 2        Silver Lake Accommodations, 7550 Royal St, Par...
# 3        Silver Lake Accommodations, 7550 Royal St, Par...
# 4        University Federal Credit Union, 7220 S Highla...
# ...                                                    ...
# 9080971   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080972   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080973   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080974   Panda Express, 64 E 12300 S St, Draper, UT 84020
# 9080975   Panda Express, 64 E 12300 S St, Draper, UT 84020
#
#                                                description  ...    category_5  \
# 0                                                     None  ...           NaN
# 1                                                     None  ...           NaN
# 2                                                     None  ...           NaN
# 3                                                     None  ...           NaN
# 4                                                     None  ...  Credit union
# ...                                                    ...  ...           ...
# 9080971  Fast-food chain for Chinese standards, includi...  ...           NaN
# 9080972  Fast-food chain for Chinese standards, includi...  ...           NaN
# 9080973  Fast-food chain for Chinese standards, includi...  ...           NaN
# 9080974  Fast-food chain for Chinese standards, includi...  ...           NaN
# 9080975  Fast-food chain for Chinese standards, includi...  ...           NaN
#
#               category_6 category_7  category_8  category_9 category_10  \
# 0                    NaN        NaN         NaN         NaN         NaN
# 1                    NaN        NaN         NaN         NaN         NaN
# 2                    NaN        NaN         NaN         NaN         NaN
# 3                    NaN        NaN         NaN         NaN         NaN
# 4        Mortgage lender        ATM         NaN         NaN         NaN
# ...                  ...        ...         ...         ...         ...
# 9080971              NaN        NaN         NaN         NaN         NaN
# 9080972              NaN        NaN         NaN         NaN         NaN
# 9080973              NaN        NaN         NaN         NaN         NaN
# 9080974              NaN        NaN         NaN         NaN         NaN
# 9080975              NaN        NaN         NaN         NaN         NaN
#
#         category_11 category_12 category_13 category_14
# 0               NaN         NaN         NaN         NaN
# 1               NaN         NaN         NaN         NaN
# 2               NaN         NaN         NaN         NaN
# 3               NaN         NaN         NaN         NaN
# 4               NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...
# 9080971         NaN         NaN         NaN         NaN
# 9080972         NaN         NaN         NaN         NaN
# 9080973         NaN         NaN         NaN         NaN
# 9080974         NaN         NaN         NaN         NaN
# 9080975         NaN         NaN         NaN         NaN
#
# [5774059 rows x 35 columns]

# %%
import re

from tqdm import tqdm
tqdm.pandas()

healthcare_categories = {
    "medical clinic", "women's health clinic", "home health care service", "internist", "allergist",
    "diabetes center", "doctor", "family practice physician", "optometrist", "pharmacy", "dentist",
    "medical supply store", "orthopedic surgeon", "surgeon", "psychotherapist", "dental clinic",
    "orthodontist", "physical therapist", "chiropractor", "hospital", "sleep clinic", "optician",
    "cancer treatment center", "medical center", "physical therapy clinic", "medical laboratory",
    "public health department", "psychologist", "radiologist", "podiatrist", "nursing home",
    "medical group", "x-ray lab", "dermatologist", "pediatrician", "massage therapist",
    "periodontist", "obstetrician-gynecologist", "sports medicine clinic", "psychiatric hospital",
    "orthotics & prosthetics service", "physical fitness program", "ophthalmologist", "hospice",
    "retirement home", "rehabilitation center", "pediatric dentist", "teeth whitening service",
    "dental hygienist", "endodontist", "dental implants periodontist", "cosmetic dentist",
    "emergency dental service", "urgent care center", "wellness center", "walk-in clinic",
    "general practitioner", "children's hospital", "mental health clinic", "otolaryngologist", "eye care center", 
    "ophthalmology clinic","lasik surgeon","blood donation center" ,
    "Addiction treatment center","denture care center","gym","fitness center","personal trainer", 
    "Psychiatrist", "Drug store","Vitamin & supplements store","weight loss service",
    "Pulmonologist","gymnastics center", "oral surgeon","Oral and maxillofacial surgeon","homeless service",
     "Alcoholism treatment program", "Homeless shelter", "child care agency","day care center",
     "Neurosurgeon","Vascular surgeon", "Cardiologist", "Laboratory", "Specialized clinic",
     "contact lenses supplier","massage spa","Reflexologist", "Rheumatologist", "Surgical center",
     "Mental health service", "Eating disorder treatment center", "Hair removal service", 
     "Skin care clinic","foot care","laser hair removal service","spa","medical spa",
     "sports nutrition store","pain control clinic","audiologist","plastic surgeon","pathologist",
     "Pediatric cardiologist","Sports medicine physician","Medical equipment supplier","nurse practitioner",
     "Counselor", "Family counselor", "Marriage or relationship counselor","facial spa",
     "Occupational medical physician","Urologist","Nephrologist","Endocrinologist",
     "Alternative medicine practitioner", "Holistic medicine practitioner",
     "health","massage","Dialysis center", "Local medical services", 
     "hand surgeon","Gastroenterologist","Thai massage therapist","Hearing aid store", "Hearing aid repair service"
                                        
}
# Function to check if a business belongs to the healthcare category
def classify_healthcare(row):
    for i in range(1, 16):  # Assuming category_1 to category_15 exist
        category_col = f"category_{i}"
        if category_col in row and isinstance(row[category_col], str):  # Check if column exists and is a string
            for keyword in healthcare_categories:
                if re.search(rf"\b{keyword}\b", row[category_col], re.IGNORECASE):  # Match whole word
                    return "Healthcare"  # Assign healthcare label
    return "Other"  # Default category if no match

# Apply the function to create a new 'general_labelling' column
merged_df["general_labelling"] = merged_df.progress_apply(classify_healthcare, axis=1)
# Out:
# 100%|██████████| 5774059/5774059 [4:00:03<00:00, 400.89it/s]

# %%
# Filter records where 'general_labelling' is "Healthcare"
healthcare_dataset = merged_df[merged_df["general_labelling"] == "Healthcare"]

# %%
utah_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/utah_healthcare_dataset.csv"

# %%
healthcare_dataset.to_csv(utah_path, index=False)

# %%
utah_path =  "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/utah_healthcare_dataset.csv"
utah_df = pd.read_csv(utah_path)
utah_df
# Out:
# C:\Users\eliza\AppData\Local\Temp\ipykernel_11516\2556229336.py:2: DtypeWarning: Columns (18,30,31,32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   utah_df = pd.read_csv(utah_path)
#              user_id           name_x           time  rating  \
# 0       1.166025e+20        Not Known  1625156912049     1.0
# 1       1.049144e+20      Ben Buehler  1604546353368     5.0
# 2       1.119606e+20    Elsie Huefner  1609204691046     5.0
# 3       1.150229e+20       Meg Wilson  1630285218169     5.0
# 4       1.089899e+20     Lisa Kireiev  1614962448388     5.0
# ...              ...              ...            ...     ...
# 551563  1.101002e+20       Max Curtis  1556582595538     5.0
# 551564  1.180303e+20   Helga Pfeiffer  1568944927924     5.0
# 551565  1.169216e+20       Sean Moran  1554167909683     4.0
# 551566  1.146525e+20   Darin Costello  1504137645542     4.0
# 551567  1.115631e+20  Cristian Franco  1464012219798     3.0
#
#                                                      text  \
# 0       Predatory cancellation practices override all ...
# 1       1.  The Staff is awesome!  2.  I needed to be ...
# 2       This place is the best. Excellent self care an...
# 3       Love this place, your result become your motiv...
# 4       I am ADDICTED!!!!! The best workout I have eve...
# ...                                                   ...
# 551563    (Translated by Google) Yeet\n\n(Original)\nYeet
# 551564  (Translated by Google) Best doner kebab in tow...
# 551565  (Translated by Google) Dang shabang!\n\n(Origi...
# 551566  (Translated by Google) Derrliciouz\n\n(Origina...
# 551567  (Translated by Google) I like the place\n\n(Or...
#
#                                                      resp  \
# 0       {'time': 1625258671101, 'text': "HOTWORX natio...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       {'time': 1614973635021, 'text': 'So glad you a...
# ...                                                   ...
# 551563                                                NaN
# 551564                                                NaN
# 551565                                                NaN
# 551566                                                NaN
# 551567                                                NaN
#
#                                       gmap_id  \
# 0        0x87528b34a4f8738f:0x79d61042dfa75e8
# 1        0x87528b34a4f8738f:0x79d61042dfa75e8
# 2        0x87528b34a4f8738f:0x79d61042dfa75e8
# 3        0x87528b34a4f8738f:0x79d61042dfa75e8
# 4        0x87528b34a4f8738f:0x79d61042dfa75e8
# ...                                       ...
# 551563  0x8752f51029e13e6b:0x90eb9d424eee1cf0
# 551564  0x8752f51029e13e6b:0x90eb9d424eee1cf0
# 551565  0x8752f51029e13e6b:0x90eb9d424eee1cf0
# 551566  0x8752f51029e13e6b:0x90eb9d424eee1cf0
# 551567  0x8752f51029e13e6b:0x90eb9d424eee1cf0
#
#                                                    name_y  \
# 0               HOTWORX - Salt Lake City, UT (Sugarhouse)
# 1               HOTWORX - Salt Lake City, UT (Sugarhouse)
# 2               HOTWORX - Salt Lake City, UT (Sugarhouse)
# 3               HOTWORX - Salt Lake City, UT (Sugarhouse)
# 4               HOTWORX - Salt Lake City, UT (Sugarhouse)
# ...                                                   ...
# 551563  Spitz - Downtown Salt Lake City - Mediterranea...
# 551564  Spitz - Downtown Salt Lake City - Mediterranea...
# 551565  Spitz - Downtown Salt Lake City - Mediterranea...
# 551566  Spitz - Downtown Salt Lake City - Mediterranea...
# 551567  Spitz - Downtown Salt Lake City - Mediterranea...
#
#                                                   address description  ...  \
# 0       HOTWORX - Salt Lake City, UT (Sugarhouse), 675...         NaN  ...
# 1       HOTWORX - Salt Lake City, UT (Sugarhouse), 675...         NaN  ...
# 2       HOTWORX - Salt Lake City, UT (Sugarhouse), 675...         NaN  ...
# 3       HOTWORX - Salt Lake City, UT (Sugarhouse), 675...         NaN  ...
# 4       HOTWORX - Salt Lake City, UT (Sugarhouse), 675...         NaN  ...
# ...                                                   ...         ...  ...
# 551563  Spitz - Downtown Salt Lake City - Mediterranea...         NaN  ...
# 551564  Spitz - Downtown Salt Lake City - Mediterranea...         NaN  ...
# 551565  Spitz - Downtown Salt Lake City - Mediterranea...         NaN  ...
# 551566  Spitz - Downtown Salt Lake City - Mediterranea...         NaN  ...
# 551567  Spitz - Downtown Salt Lake City - Mediterranea...         NaN  ...
#
#              category_6  category_7                category_8  \
# 0                   NaN         NaN                       NaN
# 1                   NaN         NaN                       NaN
# 2                   NaN         NaN                       NaN
# 3                   NaN         NaN                       NaN
# 4                   NaN         NaN                       NaN
# ...                 ...         ...                       ...
# 551563  Gyro restaurant  Kebab shop  Mediterranean restaurant
# 551564  Gyro restaurant  Kebab shop  Mediterranean restaurant
# 551565  Gyro restaurant  Kebab shop  Mediterranean restaurant
# 551566  Gyro restaurant  Kebab shop  Mediterranean restaurant
# 551567  Gyro restaurant  Kebab shop  Mediterranean restaurant
#
#                    category_9       category_10 category_11 category_12  \
# 0                         NaN               NaN         NaN         NaN
# 1                         NaN               NaN         NaN         NaN
# 2                         NaN               NaN         NaN         NaN
# 3                         NaN               NaN         NaN         NaN
# 4                         NaN               NaN         NaN         NaN
# ...                       ...               ...         ...         ...
# 551563  Vegetarian restaurant  Vegan restaurant         NaN         NaN
# 551564  Vegetarian restaurant  Vegan restaurant         NaN         NaN
# 551565  Vegetarian restaurant  Vegan restaurant         NaN         NaN
# 551566  Vegetarian restaurant  Vegan restaurant         NaN         NaN
# 551567  Vegetarian restaurant  Vegan restaurant         NaN         NaN
#
#        category_13 category_14 general_labelling
# 0              NaN         NaN        Healthcare
# 1              NaN         NaN        Healthcare
# 2              NaN         NaN        Healthcare
# 3              NaN         NaN        Healthcare
# 4              NaN         NaN        Healthcare
# ...            ...         ...               ...
# 551563         NaN         NaN        Healthcare
# 551564         NaN         NaN        Healthcare
# 551565         NaN         NaN        Healthcare
# 551566         NaN         NaN        Healthcare
# 551567         NaN         NaN        Healthcare
#
# [551568 rows x 36 columns]
