# %%
import pandas as pd

# %%
review_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/WinReview/review-Wisconsin.json"
review_df = pd.read_json(review_path, lines = True)

review_df
# Out:
#                user_id              name           time  rating  \
# 0         1.089909e+20    Jeremy Schafer  1607033857358     1.0
# 1         1.176803e+20  Cheyanne Hackett  1593531807123     1.0
# 2         1.079238e+20        Inga Graul  1494962746838     5.0
# 3         1.019522e+20      April Gander  1467114524010     5.0
# 4         1.020304e+20       Ben Kieffer  1465290214975     5.0
# ...                ...               ...            ...     ...
# 10246680  1.041459e+20        Beth Hawes  1525457036603     5.0
# 10246681  1.182145e+20    Brendaline Fri  1541332943383     5.0
# 10246682  1.121515e+20         Adam Duke  1553525290506     5.0
# 10246683  1.153207e+20    winn shweihart  1541996780973     5.0
# 10246684  1.155496e+20     Keith Knuffke  1588593689038     5.0
#
#                                                        text  pics  resp  \
# 0         Iv never had so many problems order glasses or...  None  None
# 1         When the appointment was made (over a month pr...  None  None
# 2         Dr rickles did a fantastic job  on my eye exam...  None  None
# 3         Dr. N is fantastic. Takes time to answer all U...  None  None
# 4                                                      None  None  None
# ...                                                     ...   ...   ...
# 10246680                                               None  None  None
# 10246681                                               None  None  None
# 10246682                                               None  None  None
# 10246683                                               None  None  None
# 10246684                                               None  None  None
#
#                                         gmap_id
# 0         0x87fd659afd0ca105:0xa54d270b133ae891
# 1         0x87fd659afd0ca105:0xa54d270b133ae891
# 2         0x87fd659afd0ca105:0xa54d270b133ae891
# 3         0x87fd659afd0ca105:0xa54d270b133ae891
# 4         0x87fd659afd0ca105:0xa54d270b133ae891
# ...                                         ...
# 10246680  0x88065648e7bfffff:0x7a233a2a55976285
# 10246681  0x88065648e7bfffff:0x7a233a2a55976285
# 10246682  0x88065648e7bfffff:0x7a233a2a55976285
# 10246683  0x88065648e7bfffff:0x7a233a2a55976285
# 10246684  0x88065648e7bfffff:0x7a233a2a55976285
#
# [10246685 rows x 8 columns]

# %%
business_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/WinMeta/meta-Wisconsin.json"
business_df = pd.read_json(business_path, lines = True)

# %%
business_df
# Out:
#                                            name  \
# 0          SSM Health Davis Duehr Dean Eye Care
# 1                        Montfort Swimming Pool
# 2                Gobin & Allion Flooring Center
# 3                          Dodgeville Arboretum
# 4                                 The Bar Stool
# ...                                         ...
# 92036                   O'Neil Creek Campground
# 92037               Chippewa Valley Expo Center
# 92038                 East Town Kitchen and Bar
# 92039                Steiner Turf Equipment Inc
# 92040  Fairway Independent Mortgage Corporation
#
#                                                  address  \
# 0      SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 1      Montfort Swimming Pool, S Madison St, Montfort...
# 2      Gobin & Allion Flooring Center, 1245 US-151 BU...
# 3      Dodgeville Arboretum, 721-725 W Chapel St, Dod...
# 4         The Bar Stool, 618 Main St, Highland, WI 53543
# ...                                                  ...
# 92036  O'Neil Creek Campground, 14912 105th Ave, Chip...
# 92037  Chippewa Valley Expo Center, 5150 Old Mill Pla...
# 92038  East Town Kitchen and Bar, 323 E Wisconsin Ave...
# 92039  Steiner Turf Equipment Inc, 1 Bobcat Ln, Johns...
# 92040  Fairway Independent Mortgage Corporation, 4801...
#
#                                      gmap_id  \
# 0      0x87fd659afd0ca105:0xa54d270b133ae891
# 1      0x87fd108d3f915a5f:0x2b7132092901f4df
# 2      0x87fd2530c7abeb33:0x9de082772cafeeea
# 3      0x87fd658c947d136d:0x388a54de418dc7ff
# 4      0x87fd0e70c5f5d87b:0xdf340eeb75040ef3
# ...                                      ...
# 92036  0x52acad55f5594825:0x7b00e7f06dfd585f
# 92037  0x87f899e15694ea35:0xef0d9dca252fe836
# 92038  0x880519a77a1769cd:0xe1fb47360141a7e3
# 92039  0x8805d6114cc78343:0x4da552911e41f5f5
# 92040  0x88065648e7bfffff:0x7a233a2a55976285
#
#                                              description   latitude  \
# 0                                                   None  42.973156
# 1                                                   None  42.971340
# 2                                                   None  42.731703
# 3                                                   None  42.962555
# 4                                                   None  43.046428
# ...                                                  ...        ...
# 92036                                               None  44.997081
# 92037                                               None  44.845101
# 92038  Stylish tavern featuring meat & cheese boards,...  43.038505
# 92039                                               None  43.082206
# 92040                                               None  43.149600
#
#        longitude                                           category  \
# 0     -90.138310  [Optometrist, Eye care center, Lasik surgeon, ...
# 1     -90.432458                                    [Swimming pool]
# 2     -90.458456                                   [Flooring store]
# 3     -90.143799                                        [Arboretum]
# 4     -90.380139                                              [Bar]
# ...          ...                                                ...
# 92036 -91.365702                              [Campground, RV park]
# 92037 -91.585644                    [Auditorium, Conference center]
# 92038 -87.906973             [American restaurant, Bar, Restaurant]
# 92039 -88.770533                             [Turf supplier, Store]
# 92040 -89.292366    [Mortgage lender, Loan agency, Mortgage broker]
#
#        avg_rating  num_of_reviews price  \
# 0             3.7               6  None
# 1             3.5              14  None
# 2             5.0               8  None
# 3             4.7               3  None
# 4             4.5              18  None
# ...           ...             ...   ...
# 92036         4.6             227  None
# 92037         4.4              58    $$
# 92038         4.5             516    $$
# 92039         1.5               4  None
# 92040         5.0            6695  None
#
#                                                    hours  \
# 0      [[Thursday, 8:30AM–5PM], [Friday, 8:30AM–5PM],...
# 1                                                   None
# 2      [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 92036                                               None
# 92037                                               None
# 92038                                               None
# 92039  [[Thursday, 9AM–4:30PM], [Friday, 9AM–4:30PM],...
# 92040  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
#
#                                                     MISC              state  \
# 0      {'Accessibility': ['Wheelchair accessible elev...  Open ⋅ Closes 5PM
# 1                                                   None               None
# 2      {'Service options': ['Delivery', 'In-store sho...  Open ⋅ Closes 5PM
# 3                       {'Amenities': ['Good for kids']}           Open now
# 4      {'Service options': ['Dine-in', 'Delivery'], '...               None
# ...                                                  ...                ...
# 92036  {'Accessibility': ['Wheelchair accessible entr...                NaN
# 92037  {'Accessibility': ['Wheelchair accessible entr...                NaN
# 92038  {'Service options': ['Takeout'], 'Highlights':...                NaN
# 92039  {'Accessibility': ['Wheelchair accessible entr...                NaN
# 92040  {'Accessibility': ['Wheelchair accessible entr...                NaN
#
#                                         relative_results  \
# 0      [0x87fd65a437c4fef7:0xe80fe0ce3a4fbdeb, 0x87fd...
# 1      [0x87fda7e86ef0e1cf:0xff2eea8f853582fd, 0x87fc...
# 2      [0x87fd25742a887169:0x8f3aa27dcb282087, 0x87fc...
# 3      [0x87fd65bb923e8e97:0xcdaffc2a4d0e8d75, 0x87fd...
# 4      [0x87fd0e70dc5eeb3d:0x7f3ce1daba0a5f24, 0x87fd...
# ...                                                  ...
# 92036                                               None
# 92037  [0x87f8be9f4857e60d:0x50c0b779b669ed7c, 0x87f8...
# 92038  [0x8805190831a15e91:0x7c45573971d7d02a, 0x8805...
# 92039  [0x8805d60d0545ba41:0xd2a30b624c970504, 0x8805...
# 92040  [0x880653345c9a94ff:0x96031163f5815a4a, 0x8806...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 92036  https://www.google.com/maps/place//data=!4m2!3...
# 92037  https://www.google.com/maps/place//data=!4m2!3...
# 92038  https://www.google.com/maps/place//data=!4m2!3...
# 92039  https://www.google.com/maps/place//data=!4m2!3...
# 92040  https://www.google.com/maps/place//data=!4m2!3...
#
# [92041 rows x 15 columns]

# %%
# Aggregate business metadata by gmap_id before merging
business_agg = business_df.groupby("gmap_id", as_index=False).agg({
    "name": "first",  # Keep first occurrence (assumes same name per gmap_id)
    "address": "first",
    "description": "first",
    "latitude": "first",
    "longitude": "first",
    "category": lambda x: list(set(x.sum())) if x.apply(lambda v: isinstance(v, list)).any() else list(set(x)),
    "avg_rating": "mean",  # Use mean rating if multiple exist
    "num_of_reviews": "sum",
    "price": "first",
    "hours": "first",
    "MISC": "first",
    "state": "first",
    "relative_results": "first",
    "url": "first"
})

# Check if aggregation worked
print(business_agg.head())
# Out:
#                                  gmap_id                         name  \
# 0                 0x0:0xce269ab7e7e61a7f            Midstate Lock LLC
# 1                  0x0:0xde4ab363e58baf8   Back 40 Dining & Cocktails
# 2                 0x0:0xe7151bf980f4e99d            Rustique Pizzeria
# 3  0x152041c8606e7f87:0x341c13ba31e8aa85  Holy Resurrection Monastery
# 4  0x40542453f3580e67:0xcf21f363d5d18665       Saputo Cheese USA Inc.
#
#                                              address  \
# 0  Midstate Lock LLC, 3525 Patch St ste b, Steven...
# 1  Back 40 Dining & Cocktails, 19037 WI-40, Bloom...
# 2  Rustique Pizzeria, 13201 Velp Ave, Suamico, WI...
# 3  Holy Resurrection Monastery, 300 S 2nd Ave, St...
# 4  Saputo Cheese USA Inc., 13190 Velp Ave, Green ...
#
#                                          description   latitude  longitude  \
# 0                                               None  44.511700 -89.550400
# 1                                               None  45.120739 -91.448845
# 2  Rustic-chic restaurant featuring brick-oven pi...  44.630070 -88.056323
# 3                                               None  44.004247 -87.923883
# 4                                               None  44.628738 -88.056396
#
#                                             category  avg_rating  \
# 0                                        [Locksmith]         4.4
# 1            [Event venue, Bar, Restaurant, Caterer]         4.2
# 2  [Lounge, Sandwich shop, Italian restaurant, Re...         4.7
# 3                                        [Monastery]         4.8
# 4                [Manufacturer, Cheese manufacturer]         4.2
#
#    num_of_reviews price                                              hours  \
# 0              48  None  [[Saturday, Open 24 hours], [Sunday, Open 24 h...
# 1             138     $  [[Tuesday, Closed], [Wednesday, 11AM–9PM], [Th...
# 2             745    $$  [[Sunday, 11AM–9PM], [Monday, Closed], [Tuesda...
# 3              25  None                                               None
# 4              27  None  [[Friday, 8AM–4PM], [Saturday, Closed], [Sunda...
#
#                                                 MISC                    state  \
# 0                                               None            Open 24 hours
# 1  {'Service options': ['Curbside pickup', 'Takeo...  Closed ⋅ Opens 11AM Wed
# 2  {'Service options': ['Outdoor seating', 'Curbs...      Closed ⋅ Opens 11AM
# 3  {'Accessibility': ['Wheelchair accessible entr...                     None
# 4  {'Accessibility': ['Wheelchair accessible entr...        Open ⋅ Closes 4PM
#
#                                     relative_results  \
# 0  [0x8800842fb712fbcf:0x8b56e0d47b5b4bdd, 0x8800...
# 1  [0x52acb6ffce65dec1:0x4ce967c7006e2cbe, 0x52ac...
# 2  [0x8802f3b45c94526f:0xb85e23047e1ab981, 0x8802...
# 3  [0x880320c0910de073:0x5b9e156995d1598f, 0x8803...
# 4  [0x8802faab69f48cfb:0x4b80499930284d6, 0x88025...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
business_agg
# Out:
#                                      gmap_id  \
# 0                     0x0:0xce269ab7e7e61a7f
# 1                      0x0:0xde4ab363e58baf8
# 2                     0x0:0xe7151bf980f4e99d
# 3      0x152041c8606e7f87:0x341c13ba31e8aa85
# 4      0x40542453f3580e67:0xcf21f363d5d18665
# ...                                      ...
# 91518  0x89d270442de3a21f:0xdf0ad3eae51b8b2c
# 91519  0x89e45dc89f8a4fb7:0x2667a55ca87d1c1c
# 91520  0x89e8106b4e893513:0x30ca9102124fb288
# 91521  0x89e81f618f80a403:0x6084c622b6216292
# 91522  0x89e876021400a329:0xd008acb9406c0db6
#
#                                                name  \
# 0                                 Midstate Lock LLC
# 1                        Back 40 Dining & Cocktails
# 2                                 Rustique Pizzeria
# 3                       Holy Resurrection Monastery
# 4                            Saputo Cheese USA Inc.
# ...                                             ...
# 91518                                   ABF Freight
# 91519                                  Pink Dove Co
# 91520                                       Chico's
# 91521  Norwalk 24 Hour Towing & Roadside Assistance
# 91522                                   ABF Freight
#
#                                                  address  \
# 0      Midstate Lock LLC, 3525 Patch St ste b, Steven...
# 1      Back 40 Dining & Cocktails, 19037 WI-40, Bloom...
# 2      Rustique Pizzeria, 13201 Velp Ave, Suamico, WI...
# 3      Holy Resurrection Monastery, 300 S 2nd Ave, St...
# 4      Saputo Cheese USA Inc., 13190 Velp Ave, Green ...
# ...                                                  ...
# 91518   ABF Freight, 1210 S 10th St, Sheboygan, WI 53081
# 91519                                               None
# 91520    Chico's, 2500 N Mayfair Rd, Wauwatosa, WI 53226
# 91521                                               None
# 91522    ABF Freight, 3905 Woodduck Ln, Wausau, WI 54401
#
#                                              description   latitude  \
# 0                                                   None  44.511700
# 1                                                   None  45.120739
# 2      Rustic-chic restaurant featuring brick-oven pi...  44.630070
# 3                                                   None  44.004247
# 4                                                   None  44.628738
# ...                                                  ...        ...
# 91518                                               None  43.741765
# 91519                                               None  45.598021
# 91520  Clothing chain offering women's fashions inclu...  43.063835
# 91521                                               None  44.487626
# 91522                                               None  44.921545
#
#        longitude                                           category  \
# 0     -89.550400                                        [Locksmith]
# 1     -91.448845            [Event venue, Bar, Caterer, Restaurant]
# 2     -88.056323  [Sandwich shop, Fast food restaurant, Restaura...
# 3     -87.923883                                        [Monastery]
# 4     -88.056396                [Manufacturer, Cheese manufacturer]
# ...          ...                                                ...
# 91518 -87.716655                                 [Trucking company]
# 91519 -88.997277     [Surgical supply store, Service establishment]
# 91520 -88.044561  [Jeans shop, Dress store, Women's clothing sto...
# 91521 -87.789400            [Service establishment, Towing service]
# 91522 -89.648893                                 [Trucking company]
#
#        avg_rating  num_of_reviews price  \
# 0             4.4              48  None
# 1             4.2             138     $
# 2             4.7             745    $$
# 3             4.8              25  None
# 4             4.2              27  None
# ...           ...             ...   ...
# 91518         4.4              10  None
# 91519         5.0              25  None
# 91520         4.2              18    $$
# 91521         4.8               5  None
# 91522         3.3               3  None
#
#                                                    hours  \
# 0      [[Saturday, Open 24 hours], [Sunday, Open 24 h...
# 1      [[Tuesday, Closed], [Wednesday, 11AM–9PM], [Th...
# 2      [[Sunday, 11AM–9PM], [Monday, Closed], [Tuesda...
# 3                                                   None
# 4      [[Friday, 8AM–4PM], [Saturday, Closed], [Sunda...
# ...                                                  ...
# 91518                                               None
# 91519  [[Wednesday, Open 24 hours], [Thursday, Open 2...
# 91520  [[Friday, 10AM–8PM], [Saturday, 10AM–8PM], [Su...
# 91521  [[Friday, Open 24 hours], [Saturday, Open 24 h...
# 91522                                               None
#
#                                                     MISC  \
# 0                                                   None
# 1      {'Service options': ['Curbside pickup', 'Takeo...
# 2      {'Service options': ['Outdoor seating', 'Curbs...
# 3      {'Accessibility': ['Wheelchair accessible entr...
# 4      {'Accessibility': ['Wheelchair accessible entr...
# ...                                                  ...
# 91518                                               None
# 91519  {'From the business': ['Identifies as women-le...
# 91520  {'Service options': ['In-store shopping', 'Del...
# 91521                                               None
# 91522                                               None
#
#                          state  \
# 0                Open 24 hours
# 1      Closed ⋅ Opens 11AM Wed
# 2          Closed ⋅ Opens 11AM
# 3                         None
# 4            Open ⋅ Closes 4PM
# ...                        ...
# 91518                     None
# 91519            Open 24 hours
# 91520        Open ⋅ Closes 8PM
# 91521            Open 24 hours
# 91522                     None
#
#                                         relative_results  \
# 0      [0x8800842fb712fbcf:0x8b56e0d47b5b4bdd, 0x8800...
# 1      [0x52acb6ffce65dec1:0x4ce967c7006e2cbe, 0x52ac...
# 2      [0x8802f3b45c94526f:0xb85e23047e1ab981, 0x8802...
# 3      [0x880320c0910de073:0x5b9e156995d1598f, 0x8803...
# 4      [0x8802faab69f48cfb:0x4b80499930284d6, 0x88025...
# ...                                                  ...
# 91518  [0x8804a68bfd899bb1:0x26c1567ad67f4ce3, 0x8804...
# 91519                                               None
# 91520  [0x8805048c42a74035:0x421571bfb5d7de7b, 0x8805...
# 91521                                               None
# 91522  [0x880023a5f4bf8b13:0x26bd156dbc32c112, 0x8800...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 91518  https://www.google.com/maps/place//data=!4m2!3...
# 91519  https://www.google.com/maps/place//data=!4m2!3...
# 91520  https://www.google.com/maps/place//data=!4m2!3...
# 91521  https://www.google.com/maps/place//data=!4m2!3...
# 91522  https://www.google.com/maps/place//data=!4m2!3...
#
# [91523 rows x 15 columns]

# %%
# Merge with aggregated business data
merged_df = review_df.merge(business_agg, on="gmap_id", how="left")

# %%
#remove rows/records where 'text' is null
merged_df = merged_df.dropna(subset = ['text'])
#check if null values in 'text' column still exist
print(merged_df['text'].isna().sum())
# Out:
# 0

# %%
#delete pics 
merged_df = merged_df.drop(columns = ['pics'])

# %%
merged_df
# Out:
#                user_id                                 name_x           time  \
# 0         1.089909e+20                         Jeremy Schafer  1607033857358
# 1         1.176803e+20                       Cheyanne Hackett  1593531807123
# 2         1.079238e+20                             Inga Graul  1494962746838
# 3         1.019522e+20                           April Gander  1467114524010
# 6         1.107740e+20                          Aaron Bomkamp  1629773180921
# ...                ...                                    ...            ...
# 10243958  1.121470e+20        karina del carmen ocando garcia  1574863496646
# 10243959  1.113218e+20                     Patricia Hernandez  1565133955230
# 10243960  1.183028e+20  Did I ever get a name ? :O wdym no ??  1531224912009
# 10243961  1.153612e+20                           Irma Mendoza  1542471767181
# 10243962  1.137663e+20                   Russ and Alena Smith  1533599035163
#
#           rating                                               text  resp  \
# 0            1.0  Iv never had so many problems order glasses or...  None
# 1            1.0  When the appointment was made (over a month pr...  None
# 2            5.0  Dr rickles did a fantastic job  on my eye exam...  None
# 3            5.0  Dr. N is fantastic. Takes time to answer all U...  None
# 6            5.0             Didn't swim, just a nice atmosphere...  None
# ...          ...                                                ...   ...
# 10243958     5.0  (Translated by Google) Jesus Cruz of Fairway, ...  None
# 10243959     5.0  (Translated by Google) Very good place..profes...  None
# 10243960     5.0  (Translated by Google) Excellent professional ...  None
# 10243961     5.0  (Translated by Google) Excellent staff. very g...  None
# 10243962     5.0  (Translated by Google) Pat Kleiwer was awesome...  None
#
#                                         gmap_id  \
# 0         0x87fd659afd0ca105:0xa54d270b133ae891
# 1         0x87fd659afd0ca105:0xa54d270b133ae891
# 2         0x87fd659afd0ca105:0xa54d270b133ae891
# 3         0x87fd659afd0ca105:0xa54d270b133ae891
# 6         0x87fd108d3f915a5f:0x2b7132092901f4df
# ...                                         ...
# 10243958  0x88065648e7bfffff:0x7a233a2a55976285
# 10243959  0x88065648e7bfffff:0x7a233a2a55976285
# 10243960  0x88065648e7bfffff:0x7a233a2a55976285
# 10243961  0x88065648e7bfffff:0x7a233a2a55976285
# 10243962  0x88065648e7bfffff:0x7a233a2a55976285
#
#                                             name_y  \
# 0             SSM Health Davis Duehr Dean Eye Care
# 1             SSM Health Davis Duehr Dean Eye Care
# 2             SSM Health Davis Duehr Dean Eye Care
# 3             SSM Health Davis Duehr Dean Eye Care
# 6                           Montfort Swimming Pool
# ...                                            ...
# 10243958  Fairway Independent Mortgage Corporation
# 10243959  Fairway Independent Mortgage Corporation
# 10243960  Fairway Independent Mortgage Corporation
# 10243961  Fairway Independent Mortgage Corporation
# 10243962  Fairway Independent Mortgage Corporation
#
#                                                     address description  ...  \
# 0         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 1         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 2         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 3         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 6         Montfort Swimming Pool, S Madison St, Montfort...        None  ...
# ...                                                     ...         ...  ...
# 10243958  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243959  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243960  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243961  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243962  Fairway Independent Mortgage Corporation, 4801...        None  ...
#
#           longitude                                           category  \
# 0        -90.138310  [Eye care center, Ophthalmology clinic, Optome...
# 1        -90.138310  [Eye care center, Ophthalmology clinic, Optome...
# 2        -90.138310  [Eye care center, Ophthalmology clinic, Optome...
# 3        -90.138310  [Eye care center, Ophthalmology clinic, Optome...
# 6        -90.432458                                    [Swimming pool]
# ...             ...                                                ...
# 10243958 -89.292366    [Mortgage broker, Mortgage lender, Loan agency]
# 10243959 -89.292366    [Mortgage broker, Mortgage lender, Loan agency]
# 10243960 -89.292366    [Mortgage broker, Mortgage lender, Loan agency]
# 10243961 -89.292366    [Mortgage broker, Mortgage lender, Loan agency]
# 10243962 -89.292366    [Mortgage broker, Mortgage lender, Loan agency]
#
#          avg_rating  num_of_reviews  price  \
# 0               3.7              12   None
# 1               3.7              12   None
# 2               3.7              12   None
# 3               3.7              12   None
# 6               3.5              28   None
# ...             ...             ...    ...
# 10243958        5.0            6695   None
# 10243959        5.0            6695   None
# 10243960        5.0            6695   None
# 10243961        5.0            6695   None
# 10243962        5.0            6695   None
#
#                                                       hours  \
# 0         [[Thursday, 8:30AM–5PM], [Friday, 8:30AM–5PM],...
# 1         [[Thursday, 8:30AM–5PM], [Friday, 8:30AM–5PM],...
# 2         [[Thursday, 8:30AM–5PM], [Friday, 8:30AM–5PM],...
# 3         [[Thursday, 8:30AM–5PM], [Friday, 8:30AM–5PM],...
# 6                                                      None
# ...                                                     ...
# 10243958  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 10243959  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 10243960  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 10243961  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
# 10243962  [[Thursday, 8AM–6PM], [Friday, 8AM–6PM], [Satu...
#
#                                                        MISC  \
# 0         {'Accessibility': ['Wheelchair accessible elev...
# 1         {'Accessibility': ['Wheelchair accessible elev...
# 2         {'Accessibility': ['Wheelchair accessible elev...
# 3         {'Accessibility': ['Wheelchair accessible elev...
# 6                                                      None
# ...                                                     ...
# 10243958  {'Accessibility': ['Wheelchair accessible entr...
# 10243959  {'Accessibility': ['Wheelchair accessible entr...
# 10243960  {'Accessibility': ['Wheelchair accessible entr...
# 10243961  {'Accessibility': ['Wheelchair accessible entr...
# 10243962  {'Accessibility': ['Wheelchair accessible entr...
#
#                       state  \
# 0         Open ⋅ Closes 5PM
# 1         Open ⋅ Closes 5PM
# 2         Open ⋅ Closes 5PM
# 3         Open ⋅ Closes 5PM
# 6                      None
# ...                     ...
# 10243958               None
# 10243959               None
# 10243960               None
# 10243961               None
# 10243962               None
#
#                                            relative_results  \
# 0         [0x87fd65a437c4fef7:0xe80fe0ce3a4fbdeb, 0x87fd...
# 1         [0x87fd65a437c4fef7:0xe80fe0ce3a4fbdeb, 0x87fd...
# 2         [0x87fd65a437c4fef7:0xe80fe0ce3a4fbdeb, 0x87fd...
# 3         [0x87fd65a437c4fef7:0xe80fe0ce3a4fbdeb, 0x87fd...
# 6         [0x87fda7e86ef0e1cf:0xff2eea8f853582fd, 0x87fc...
# ...                                                     ...
# 10243958  [0x880653345c9a94ff:0x96031163f5815a4a, 0x8806...
# 10243959  [0x880653345c9a94ff:0x96031163f5815a4a, 0x8806...
# 10243960  [0x880653345c9a94ff:0x96031163f5815a4a, 0x8806...
# 10243961  [0x880653345c9a94ff:0x96031163f5815a4a, 0x8806...
# 10243962  [0x880653345c9a94ff:0x96031163f5815a4a, 0x8806...
#
#                                                         url
# 0         https://www.google.com/maps/place//data=!4m2!3...
# 1         https://www.google.com/maps/place//data=!4m2!3...
# 2         https://www.google.com/maps/place//data=!4m2!3...
# 3         https://www.google.com/maps/place//data=!4m2!3...
# 6         https://www.google.com/maps/place//data=!4m2!3...
# ...                                                     ...
# 10243958  https://www.google.com/maps/place//data=!4m2!3...
# 10243959  https://www.google.com/maps/place//data=!4m2!3...
# 10243960  https://www.google.com/maps/place//data=!4m2!3...
# 10243961  https://www.google.com/maps/place//data=!4m2!3...
# 10243962  https://www.google.com/maps/place//data=!4m2!3...
#
# [5851334 rows x 21 columns]

# %%
import ast

merged_df["category"] = merged_df["category"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Expand the list into separate columns
category_expanded = merged_df["category"].apply(pd.Series)

# Rename columns as 'category_1', 'category_2', etc.
category_expanded.columns = [f"category_{i+1}" for i in range(category_expanded.shape[1])]

# Concatenate with original dataset
merged_df = pd.concat([merged_df, category_expanded], axis=1)

# Drop original 'category' column
#cleaned_file.drop(columns=["category"], inplace=True)

merged_df
# Out:
#                user_id                                 name_x           time  \
# 0         1.089909e+20                         Jeremy Schafer  1607033857358
# 1         1.176803e+20                       Cheyanne Hackett  1593531807123
# 2         1.079238e+20                             Inga Graul  1494962746838
# 3         1.019522e+20                           April Gander  1467114524010
# 6         1.107740e+20                          Aaron Bomkamp  1629773180921
# ...                ...                                    ...            ...
# 10243958  1.121470e+20        karina del carmen ocando garcia  1574863496646
# 10243959  1.113218e+20                     Patricia Hernandez  1565133955230
# 10243960  1.183028e+20  Did I ever get a name ? :O wdym no ??  1531224912009
# 10243961  1.153612e+20                           Irma Mendoza  1542471767181
# 10243962  1.137663e+20                   Russ and Alena Smith  1533599035163
#
#           rating                                               text  resp  \
# 0            1.0  Iv never had so many problems order glasses or...  None
# 1            1.0  When the appointment was made (over a month pr...  None
# 2            5.0  Dr rickles did a fantastic job  on my eye exam...  None
# 3            5.0  Dr. N is fantastic. Takes time to answer all U...  None
# 6            5.0             Didn't swim, just a nice atmosphere...  None
# ...          ...                                                ...   ...
# 10243958     5.0  (Translated by Google) Jesus Cruz of Fairway, ...  None
# 10243959     5.0  (Translated by Google) Very good place..profes...  None
# 10243960     5.0  (Translated by Google) Excellent professional ...  None
# 10243961     5.0  (Translated by Google) Excellent staff. very g...  None
# 10243962     5.0  (Translated by Google) Pat Kleiwer was awesome...  None
#
#                                         gmap_id  \
# 0         0x87fd659afd0ca105:0xa54d270b133ae891
# 1         0x87fd659afd0ca105:0xa54d270b133ae891
# 2         0x87fd659afd0ca105:0xa54d270b133ae891
# 3         0x87fd659afd0ca105:0xa54d270b133ae891
# 6         0x87fd108d3f915a5f:0x2b7132092901f4df
# ...                                         ...
# 10243958  0x88065648e7bfffff:0x7a233a2a55976285
# 10243959  0x88065648e7bfffff:0x7a233a2a55976285
# 10243960  0x88065648e7bfffff:0x7a233a2a55976285
# 10243961  0x88065648e7bfffff:0x7a233a2a55976285
# 10243962  0x88065648e7bfffff:0x7a233a2a55976285
#
#                                             name_y  \
# 0             SSM Health Davis Duehr Dean Eye Care
# 1             SSM Health Davis Duehr Dean Eye Care
# 2             SSM Health Davis Duehr Dean Eye Care
# 3             SSM Health Davis Duehr Dean Eye Care
# 6                           Montfort Swimming Pool
# ...                                            ...
# 10243958  Fairway Independent Mortgage Corporation
# 10243959  Fairway Independent Mortgage Corporation
# 10243960  Fairway Independent Mortgage Corporation
# 10243961  Fairway Independent Mortgage Corporation
# 10243962  Fairway Independent Mortgage Corporation
#
#                                                     address description  ...  \
# 0         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 1         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 2         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 3         SSM Health Davis Duehr Dean Eye Care, 305 Elai...        None  ...
# 6         Montfort Swimming Pool, S Madison St, Montfort...        None  ...
# ...                                                     ...         ...  ...
# 10243958  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243959  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243960  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243961  Fairway Independent Mortgage Corporation, 4801...        None  ...
# 10243962  Fairway Independent Mortgage Corporation, 4801...        None  ...
#
#           category_4   category_5 category_6  category_7  category_8  \
# 0           Optician  Optometrist        NaN         NaN         NaN
# 1           Optician  Optometrist        NaN         NaN         NaN
# 2           Optician  Optometrist        NaN         NaN         NaN
# 3           Optician  Optometrist        NaN         NaN         NaN
# 6                NaN          NaN        NaN         NaN         NaN
# ...              ...          ...        ...         ...         ...
# 10243958         NaN          NaN        NaN         NaN         NaN
# 10243959         NaN          NaN        NaN         NaN         NaN
# 10243960         NaN          NaN        NaN         NaN         NaN
# 10243961         NaN          NaN        NaN         NaN         NaN
# 10243962         NaN          NaN        NaN         NaN         NaN
#
#          category_9 category_10 category_11 category_12 category_13
# 0               NaN         NaN         NaN         NaN         NaN
# 1               NaN         NaN         NaN         NaN         NaN
# 2               NaN         NaN         NaN         NaN         NaN
# 3               NaN         NaN         NaN         NaN         NaN
# 6               NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 10243958        NaN         NaN         NaN         NaN         NaN
# 10243959        NaN         NaN         NaN         NaN         NaN
# 10243960        NaN         NaN         NaN         NaN         NaN
# 10243961        NaN         NaN         NaN         NaN         NaN
# 10243962        NaN         NaN         NaN         NaN         NaN
#
# [5851334 rows x 34 columns]

# %%
import re

healthcare_categories = {
    "medical clinic", "women's health clinic", "home health care service", "internist", "allergist",
    "diabetes center", "doctor", "family practice physician", "optometrist", "pharmacy", "dentist",
    "medical supply store", "orthopedic surgeon", "surgeon", "psychotherapist", "dental clinic",
    "orthodontist", "physical therapist", "chiropractor", "hospital", "sleep clinic", "optician",
    "cancer treatment center", "medical center", "physical therapy clinic", "medical laboratory",
    "public health department", "psychologist", "radiologist", "podiatrist", "nursing home",
    "medical group", "x-ray lab", "dermatologist", "pediatrician", "massage therapist",
    "periodontist", "obstetrician-gynecologist", "sports medicine clinic", "psychiatric hospital",
    "orthotics & prosthetics service", "physical fitness program", "ophthalmologist", "hospice",
    "retirement home", "rehabilitation center", "pediatric dentist", "teeth whitening service",
    "dental hygienist", "endodontist", "dental implants periodontist", "cosmetic dentist",
    "emergency dental service", "urgent care center", "wellness center", "walk-in clinic",
    "general practitioner", "children's hospital", "mental health clinic", "otolaryngologist", "eye care center", 
    "ophthalmology clinic","lasik surgeon","blood donation center" ,"Family practice physician",
    "Addiction treatment center","denture care center","gym","fitness center","personal trainer", 
    "Psychiatrist","Pharmacy", "Drug store","Vitamin & supplements store","weight loss service",
    "Pulmonologist","gymnastics center", "oral surgeon","Oral and maxillofacial surgeon","homeless service",
     "Alcoholism treatment program", "Homeless shelter", "child care agency","day care center",
     "Neurosurgeon","Vascular surgeon", "Cardiologist", "Laboratory", "Specialized clinic",
     "contact lenses supplier","massage spa","Reflexologist", "Rheumatologist", "Surgical center",
     "Mental health service", "Eating disorder treatment center", "Hair removal service", 
     "Skin care clinic","foot care","laser hair removal service","spa","medical spa",
     "sports nutrition store","pain control clinic","audiologist","plastic surgeon","pathologist",
     "Pediatric cardiologist","Sports medicine physician","Medical equipment supplier","nurse practitioner",
     "Psychotherapist","Counselor", "Family counselor", "Marriage or relationship counselor","facial spa",
     "Occupational medical physician","Urologist","Nephrologist","Endocrinologist",
     "Alternative medicine practitioner", "Holistic medicine practitioner","pain control clinic",
     "Psychologist","health","massage","Dialysis center", "Local medical services", "Medical Center",
     "vascular surgeon","hand surgeon","Gastroenterologist","Thai massage therapist","Hearing aid store", "Hearing aid repair service"
                                        
}
# Function to check if a business belongs to the healthcare category
def classify_healthcare(row):
    for i in range(1, 16):  # Assuming category_1 to category_15 exist
        category_col = f"category_{i}"
        if category_col in row and isinstance(row[category_col], str):  # Check if column exists and is a string
            for keyword in healthcare_categories:
                if re.search(rf"\b{keyword}\b", row[category_col], re.IGNORECASE):  # Match whole word
                    return "Healthcare"  # Assign healthcare label
    return "Other"  # Default category if no match

# Apply the function to create a new 'general_labelling' column
merged_df["general_labelling"] = merged_df.apply(classify_healthcare, axis=1)

# %%
# Filter records where 'general_labelling' is "Healthcare"
healthcare_dataset = merged_df[merged_df["general_labelling"] == "Healthcare"]

# %%
healthcare_dataset
# Out:
#                user_id            name_x           time  rating  \
# 0         1.089909e+20    Jeremy Schafer  1607033857358     1.0
# 1         1.176803e+20  Cheyanne Hackett  1593531807123     1.0
# 2         1.079238e+20        Inga Graul  1494962746838     5.0
# 3         1.019522e+20      April Gander  1467114524010     5.0
# 413       1.173840e+20       Jim Learned  1630415926492     5.0
# ...                ...               ...            ...     ...
# 10142458  1.080106e+20          Logan R.  1490229517655     5.0
# 10142459  1.057430e+20    Drew Halverson  1504389127885     5.0
# 10142460  1.095396e+20     Chris Bennett  1489754557796     3.0
# 10142461  1.000039e+20              M Wu  1593843586229     4.0
# 10142462  1.155844e+20         lian lian  1536120742275     5.0
#
#                                                        text  \
# 0         Iv never had so many problems order glasses or...
# 1         When the appointment was made (over a month pr...
# 2         Dr rickles did a fantastic job  on my eye exam...
# 3         Dr. N is fantastic. Takes time to answer all U...
# 413       Dr.Muth is the best.  When she's with you she ...
# ...                                                     ...
# 10142458                                   Fantastic Curry!
# 10142459                         Best Thai food in Madison.
# 10142460  Friendly wait staff, a little loud, but that w...
# 10142461  (Translated by Google) The taste is not bad. G...
# 10142462  (Translated by Google) Thai food for the first...
#
#                                                        resp  \
# 0                                                      None
# 1                                                      None
# 2                                                      None
# 3                                                      None
# 413                                                    None
# ...                                                     ...
# 10142458                                               None
# 10142459  {'time': 1504425090767, 'text': 'Thank you so ...
# 10142460                                               None
# 10142461                                               None
# 10142462                                               None
#
#                                         gmap_id  \
# 0         0x87fd659afd0ca105:0xa54d270b133ae891
# 1         0x87fd659afd0ca105:0xa54d270b133ae891
# 2         0x87fd659afd0ca105:0xa54d270b133ae891
# 3         0x87fd659afd0ca105:0xa54d270b133ae891
# 413       0x8805af2f4d025ecd:0xaaca3fd5bba41290
# ...                                         ...
# 10142458  0x8807ae63de380577:0xe14cd71be131cbcc
# 10142459  0x8807ae63de380577:0xe14cd71be131cbcc
# 10142460  0x8807ae63de380577:0xe14cd71be131cbcc
# 10142461  0x8807ae63de380577:0xe14cd71be131cbcc
# 10142462  0x8807ae63de380577:0xe14cd71be131cbcc
#
#                                         name_y  \
# 0         SSM Health Davis Duehr Dean Eye Care
# 1         SSM Health Davis Duehr Dean Eye Care
# 2         SSM Health Davis Duehr Dean Eye Care
# 3         SSM Health Davis Duehr Dean Eye Care
# 413                Serenity Health Care Center
# ...                                        ...
# 10142458                          Sa-Bai Thong
# 10142459                          Sa-Bai Thong
# 10142460                          Sa-Bai Thong
# 10142461                          Sa-Bai Thong
# 10142462                          Sa-Bai Thong
#
#                                                     address  \
# 0         SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 1         SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 2         SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 3         SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 413       Serenity Health Care Center, 1708 Paramount Ct...
# ...                                                     ...
# 10142458     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 10142459     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 10142460     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 10142461     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 10142462     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
#
#                                                 description  ...  \
# 0                                                      None  ...
# 1                                                      None  ...
# 2                                                      None  ...
# 3                                                      None  ...
# 413                                                    None  ...
# ...                                                     ...  ...
# 10142458  An extensive menu of classic & uncommon Thai d...  ...
# 10142459  An extensive menu of classic & uncommon Thai d...  ...
# 10142460  An extensive menu of classic & uncommon Thai d...  ...
# 10142461  An extensive menu of classic & uncommon Thai d...  ...
# 10142462  An extensive menu of classic & uncommon Thai d...  ...
#
#                category_5        category_6  category_7        category_8  \
# 0             Optometrist               NaN         NaN               NaN
# 1             Optometrist               NaN         NaN               NaN
# 2             Optometrist               NaN         NaN               NaN
# 3             Optometrist               NaN         NaN               NaN
# 413                   NaN               NaN         NaN               NaN
# ...                   ...               ...         ...               ...
# 10142458  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 10142459  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 10142460  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 10142461  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 10142462  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
#
#                      category_9 category_10 category_11 category_12  \
# 0                           NaN         NaN         NaN         NaN
# 1                           NaN         NaN         NaN         NaN
# 2                           NaN         NaN         NaN         NaN
# 3                           NaN         NaN         NaN         NaN
# 413                         NaN         NaN         NaN         NaN
# ...                         ...         ...         ...         ...
# 10142458  Vegetarian restaurant         NaN         NaN         NaN
# 10142459  Vegetarian restaurant         NaN         NaN         NaN
# 10142460  Vegetarian restaurant         NaN         NaN         NaN
# 10142461  Vegetarian restaurant         NaN         NaN         NaN
# 10142462  Vegetarian restaurant         NaN         NaN         NaN
#
#          category_13 general_labelling
# 0                NaN        Healthcare
# 1                NaN        Healthcare
# 2                NaN        Healthcare
# 3                NaN        Healthcare
# 413              NaN        Healthcare
# ...              ...               ...
# 10142458         NaN        Healthcare
# 10142459         NaN        Healthcare
# 10142460         NaN        Healthcare
# 10142461         NaN        Healthcare
# 10142462         NaN        Healthcare
#
# [284628 rows x 35 columns]

# %%
# Define the file path to save the Healthcare dataset
wis_healthcare_dataset_path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/wis_healthcare_dataset.csv"

# Save the filtered dataset to CSV
healthcare_dataset.to_csv(wis_healthcare_dataset_path, index=False)

# %%
import pandas as pd
path = "C:/Users/eliza/Documents/Semester V/Sentiment Analysis/wis_healthcare_dataset.csv"
wis_df = pd.read_csv(path)
wis_df
# Out:
# C:\Users\eliza\AppData\Local\Temp\ipykernel_29664\2295382326.py:3: DtypeWarning: Columns (18,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   wis_df = pd.read_csv(path)
#              user_id            name_x           time  rating  \
# 0       1.089909e+20    Jeremy Schafer  1607033857358     1.0
# 1       1.176803e+20  Cheyanne Hackett  1593531807123     1.0
# 2       1.079238e+20        Inga Graul  1494962746838     5.0
# 3       1.019522e+20      April Gander  1467114524010     5.0
# 4       1.173840e+20       Jim Learned  1630415926492     5.0
# ...              ...               ...            ...     ...
# 284623  1.080106e+20          Logan R.  1490229517655     5.0
# 284624  1.057430e+20    Drew Halverson  1504389127885     5.0
# 284625  1.095396e+20     Chris Bennett  1489754557796     3.0
# 284626  1.000039e+20              M Wu  1593843586229     4.0
# 284627  1.155844e+20         lian lian  1536120742275     5.0
#
#                                                      text  \
# 0       Iv never had so many problems order glasses or...
# 1       When the appointment was made (over a month pr...
# 2       Dr rickles did a fantastic job  on my eye exam...
# 3       Dr. N is fantastic. Takes time to answer all U...
# 4       Dr.Muth is the best.  When she's with you she ...
# ...                                                   ...
# 284623                                   Fantastic Curry!
# 284624                         Best Thai food in Madison.
# 284625  Friendly wait staff, a little loud, but that w...
# 284626  (Translated by Google) The taste is not bad. G...
# 284627  (Translated by Google) Thai food for the first...
#
#                                                      resp  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 284623                                                NaN
# 284624  {'time': 1504425090767, 'text': 'Thank you so ...
# 284625                                                NaN
# 284626                                                NaN
# 284627                                                NaN
#
#                                       gmap_id  \
# 0       0x87fd659afd0ca105:0xa54d270b133ae891
# 1       0x87fd659afd0ca105:0xa54d270b133ae891
# 2       0x87fd659afd0ca105:0xa54d270b133ae891
# 3       0x87fd659afd0ca105:0xa54d270b133ae891
# 4       0x8805af2f4d025ecd:0xaaca3fd5bba41290
# ...                                       ...
# 284623  0x8807ae63de380577:0xe14cd71be131cbcc
# 284624  0x8807ae63de380577:0xe14cd71be131cbcc
# 284625  0x8807ae63de380577:0xe14cd71be131cbcc
# 284626  0x8807ae63de380577:0xe14cd71be131cbcc
# 284627  0x8807ae63de380577:0xe14cd71be131cbcc
#
#                                       name_y  \
# 0       SSM Health Davis Duehr Dean Eye Care
# 1       SSM Health Davis Duehr Dean Eye Care
# 2       SSM Health Davis Duehr Dean Eye Care
# 3       SSM Health Davis Duehr Dean Eye Care
# 4                Serenity Health Care Center
# ...                                      ...
# 284623                          Sa-Bai Thong
# 284624                          Sa-Bai Thong
# 284625                          Sa-Bai Thong
# 284626                          Sa-Bai Thong
# 284627                          Sa-Bai Thong
#
#                                                   address  \
# 0       SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 1       SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 2       SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 3       SSM Health Davis Duehr Dean Eye Care, 305 Elai...
# 4       Serenity Health Care Center, 1708 Paramount Ct...
# ...                                                   ...
# 284623     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 284624     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 284625     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 284626     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
# 284627     Sa-Bai Thong, 6802 Odana Rd, Madison, WI 53719
#
#                                               description  ...  \
# 0                                                     NaN  ...
# 1                                                     NaN  ...
# 2                                                     NaN  ...
# 3                                                     NaN  ...
# 4                                                     NaN  ...
# ...                                                   ...  ...
# 284623  An extensive menu of classic & uncommon Thai d...  ...
# 284624  An extensive menu of classic & uncommon Thai d...  ...
# 284625  An extensive menu of classic & uncommon Thai d...  ...
# 284626  An extensive menu of classic & uncommon Thai d...  ...
# 284627  An extensive menu of classic & uncommon Thai d...  ...
#
#              category_5        category_6  category_7        category_8  \
# 0           Optometrist               NaN         NaN               NaN
# 1           Optometrist               NaN         NaN               NaN
# 2           Optometrist               NaN         NaN               NaN
# 3           Optometrist               NaN         NaN               NaN
# 4                   NaN               NaN         NaN               NaN
# ...                 ...               ...         ...               ...
# 284623  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 284624  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 284625  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 284626  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
# 284627  Thai restaurant  Vegan restaurant  Restaurant  Asian restaurant
#
#                    category_9 category_10 category_11 category_12 category_13  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1                         NaN         NaN         NaN         NaN         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN         NaN         NaN         NaN         NaN
# ...                       ...         ...         ...         ...         ...
# 284623  Vegetarian restaurant         NaN         NaN         NaN         NaN
# 284624  Vegetarian restaurant         NaN         NaN         NaN         NaN
# 284625  Vegetarian restaurant         NaN         NaN         NaN         NaN
# 284626  Vegetarian restaurant         NaN         NaN         NaN         NaN
# 284627  Vegetarian restaurant         NaN         NaN         NaN         NaN
#
#        general_labelling
# 0             Healthcare
# 1             Healthcare
# 2             Healthcare
# 3             Healthcare
# 4             Healthcare
# ...                  ...
# 284623        Healthcare
# 284624        Healthcare
# 284625        Healthcare
# 284626        Healthcare
# 284627        Healthcare
#
# [284628 rows x 35 columns]
