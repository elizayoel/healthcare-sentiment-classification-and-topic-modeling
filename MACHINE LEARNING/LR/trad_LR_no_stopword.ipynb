# %% [markdown]
# **LOAD DATASET**

# %%
import pandas as pd
train_df = pd.read_csv("data/train_res.csv")
test_df = pd.read_csv("data/test.csv")

# %%
train_df
# Out:
#              user_id             username  rating  \
# 0       1.018822e+20    WandaRose Edwards     5.0
# 1       1.027946e+20         Nancy Nguyen     1.0
# 2       1.171415e+20        Nikki Lenning     5.0
# 3       1.050229e+20       jessica little     5.0
# 4       1.027384e+20  Megan Paulus-Bonney     2.0
# ...              ...                  ...     ...
# 628387  1.122890e+20          Sara Kirner     5.0
# 628388  1.071383e+20           Zheng Yong     1.0
# 628389  1.168988e+20         Bonnie Smith     1.0
# 628390  1.122568e+20          Julie Brock     5.0
# 628391  1.182691e+20       Jill Crofcheck     5.0
#
#                                             original_text  \
# 0       hair. cuts are great  perms are yo so bo to Fa...
# 1       This place is the diaster. They never picked u...
# 2       Me and my husband had a great experience! It w...
# 3                                      Always best prices
# 4       The price is great but expect the type of serv...
# ...

# %%
train_df['label'].value_counts()
# Out:
# label
# 1    314196
# 0    314196
# Name: count, dtype: int64

# %%
test_df
# Out:
#              user_id                    username  rating  \
# 0       1.088392e+20  Shayla “The Savage” Herrón     1.0
# 1       1.020402e+20          ___Luckygirl___ 96     5.0
# 2       1.098990e+20              Karetha Strand     1.0
# 3       1.031164e+20                 Jerry Wanty     5.0
# 4       1.090251e+20             Breeze Carvajal     3.0
# ...              ...                         ...     ...
# 244593  1.070690e+20               Life of Danno     5.0
# 244594  1.001145e+20                  Paul Drees     4.0
# 244595  1.165976e+20             Tesalina Meador     5.0
# 244596  1.183965e+20                Alycia Smith     1.0
# 244597  1.168229e+20                Tykira Ebron     1.0
#
#                                             original_text  \
# 0       I was given medicine with aluminum in it while...
# 1       Dr.Ashley is amazing as a person and as a prof...
# 2       I am gonna go ahead and say this was the worst...
# ...

# %%
test_df['label'].value_counts()
# Out:
# label
# 1    146411
# 0     98187
# Name: count, dtype: int64

# %% [markdown]
# **EXTRACT FEATURES AND LABELS**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

#extract features and labels
X_train_texts = train_df['final_no_stopword'].astype(str).tolist()
y_train = train_df['label'].values
X_test_texts = test_df['final_no_stopword'].astype(str).tolist()
y_test = test_df['label'].values

#text vectorization
tfidf = TfidfVectorizer(max_features=10000, ngram_range=(1,2))
X_train_tfidf = tfidf.fit_transform(X_train_texts)
X_test_tfidf = tfidf.transform(X_test_texts)

#save vectorizer
import pickle
with open("tfidf_vectorizer_nosw.pkl", "wb") as f:
    pickle.dump(tfidf, f)

# %% [markdown]
# **IMPORT AND TRAIN MODEL**

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the model
lr_model = LogisticRegression(max_iter=1000)

# Train the model
lr_model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# save the model
with open("model_LR_no_stopword.pkl","wb") as f:
    pickle.dump(lr_model, f)

# %% [markdown]
# **MAKE PREDICTIONS ON TEST SET**

# %%
#predict class label
y_pred = lr_model.predict(X_test_tfidf)
#predict class probabilities for log loss
y_proba = lr_model.predict_proba(X_test_tfidf)

# %% [markdown]
# **EVALUATE THE MODEL**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, log_loss
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def evaluate_model_sklearn(model, X, y, label="Test Set"):
    # Predict probabilities and round to binary (0 or 1)
    y_pred_prob = model.predict(X)
    y_pred = (y_pred_prob > 0.5).astype("int32")

    # Metrics
    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred)
    rec = recall_score(y, y_pred)
    f1 = f1_score(y, y_pred)
    logloss = log_loss(y, y_pred_prob)

    print(f" {label} Evaluation")
    print(f"  Accuracy : {acc:.4f}")
    print(f"  Precision: {prec:.4f}")
    print(f"  Recall   : {rec:.4f}")
    print(f"  F1 Score : {f1:.4f}")
    print("\nClassification Report:")
    print(classification_report(y, y_pred, digits=4))

    # Confusion Matrix
    cm = confusion_matrix(y, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"{label} Confusion Matrix")
    plt.show()

evaluate_model_sklearn(lr_model, X_train_tfidf, y_train, label="Train Set")
evaluate_model_sklearn(lr_model, X_test_tfidf, y_test, label="Test Set")
# Out:
#  Train Set Evaluation
#   Accuracy : 0.9424
#   Precision: 0.9465
#   Recall   : 0.9378
#   F1 Score : 0.9421
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9384    0.9470    0.9427    314196
#            1     0.9465    0.9378    0.9421    314196
#
#     accuracy                         0.9424    628392
#    macro avg     0.9424    0.9424    0.9424    628392
# weighted avg     0.9424    0.9424    0.9424    628392
#  Test Set Evaluation
#   Accuracy : 0.9405
#   Precision: 0.9629
#   Recall   : 0.9366
#   F1 Score : 0.9496
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9092    0.9462    0.9273     98187
#            1     0.9629    0.9366    0.9496    146411
#
#     accuracy                         0.9405    244598
#    macro avg     0.9360    0.9414    0.9384    244598
# weighted avg     0.9413    0.9405    0.9406    244598

# %%
# Load the model
with open("model_lr_no_stopword.pkl", "rb") as f:
    best_model = pickle.load(f)

# %%
evaluate_model_sklearn(best_model, X_train_tfidf, y_train, label="Train Set")
evaluate_model_sklearn(best_model, X_test_tfidf, y_test, label="Test Set")
# Out:
#  Train Set Evaluation
#   Accuracy : 0.9424
#   Precision: 0.9465
#   Recall   : 0.9378
#   F1 Score : 0.9421
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9384    0.9470    0.9427    314196
#            1     0.9465    0.9378    0.9421    314196
#
#     accuracy                         0.9424    628392
#    macro avg     0.9424    0.9424    0.9424    628392
# weighted avg     0.9424    0.9424    0.9424    628392
#  Test Set Evaluation
#   Accuracy : 0.9405
#   Precision: 0.9629
#   Recall   : 0.9366
#   F1 Score : 0.9496
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9092    0.9462    0.9273     98187
#            1     0.9629    0.9366    0.9496    146411
#
#     accuracy                         0.9405    244598
#    macro avg     0.9360    0.9414    0.9384    244598
# weighted avg     0.9413    0.9405    0.9406    244598
